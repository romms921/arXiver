# %%
import pandas as pd
data = pd.read_csv("../gemini_affil_output.csv")
data.head()
# Out:
#    original_index    arxiv_id  \
# 0               0  2501.00089
# 1               1  2501.12788
# 2               3  2501.12767
# 3               4  2501.12760
# 4               5  2501.12758
#
#                                    extracted_authors  \
# 0                                     ["John F. Wu"]
# 1  ["Patrick O'Neill", "Adam Ingram", "Edward Nat...
# 2  ["G. Peron", "G. Morlino", "S. Gabici", "E. Am...
# 3               ["Jie Liu", "Zhi Li", "Juntai Shen"]
# 4  ["Xiaolong He", "Guoliang L\textasciicircum u"...
#
#                               extracted_affiliations  \
# 0  ["Space Telescope Science Institute, 3700 San ...
# 1  ["School of Mathematics, Statistics and Physic...
# 2  ["Istituto Nazionale di Astrofisica -- Osserva...
# 3  ["Shanghai Astronomical Observatory, Chinese A...
# 4  ["School of Physical Science and Technology, X...
#
#                                  extracted_countries first_author_country
# ...

# %%
data.shape
# Out:
# (5765, 6)
