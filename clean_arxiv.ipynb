# %% [markdown]
# ## Phase 1

# %% [markdown]
# ### Retrieve articles related ot topic from Arxiv

# %%
import arxiv
import json
import pandas as pd
import urllib.request as libreq
import certifi
import os
import xml.etree.ElementTree as ET
from dotenv import load_dotenv
load_dotenv()
from datetime import datetime, timedelta
from tqdm import tqdm
from IPython.display import display, Latex
from bs4 import BeautifulSoup
import re
import PyPDF2
import io
os.environ['SSL_CERT_FILE'] = certifi.where()

# %% [markdown]
# #### Fuzzy Search

# %%
client = arxiv.Client()

# Search for the 10 most recent articles matching the keyword "quantum."
search = arxiv.Search(
  query = "Computational Finance",
  max_results = 10,
  sort_by = arxiv.SortCriterion.SubmittedDate
)

results = client.results(search)

# `results` is a generator; you can iterate over its elements one by one...
for r in client.results(search):
  print(r.title)
  print(r.authors)
# Out:
# PERSE: Personalized 3D Generative Avatars from A Single Portrait
# [arxiv.Result.Author('Hyunsoo Cha'), arxiv.Result.Author('Inhee Lee'), arxiv.Result.Author('Hanbyul Joo')]
# Action-Agnostic Point-Level Supervision for Temporal Action Detection
# [arxiv.Result.Author('Shuhei M. Yoshida'), arxiv.Result.Author('Takashi Shibata'), arxiv.Result.Author('Makoto Terao'), arxiv.Result.Author('Takayuki Okatani'), arxiv.Result.Author('Masashi Sugiyama')]
# Branes Screening Quarks and Defect Operators
# [arxiv.Result.Author('Andreas Karch'), arxiv.Result.Author('Marcos Riojas')]
# SoS Certificates for Sparse Singular Values and Their Applications: Robust Statistics, Subspace Distortion, and More
# [arxiv.Result.Author('Ilias Diakonikolas'), arxiv.Result.Author('Samuel B. Hopkins'), arxiv.Result.Author('Ankit Pensia'), arxiv.Result.Author('Stefan Tiegel')]
# Distributed Mixture-of-Agents for Edge Inference with Large Language Models
# [arxiv.Result.Author('Purbesh Mitra'), arxiv.Result.Author('Priyanka Kaswan'), arxiv.Result.Author('Sennur Ulukus')]
# HumanEval Pro and MBPP Pro: Evaluating Large Language Models on Self-invoking Code Generation
# [arxiv.Result.Author('Zhaojian Yu'), arxiv.Result.Author('Yilun Zhao'), arxiv.Result.Author('Arman Cohan'), arxiv.Result.Author('Xiao-Ping Zhang')]
# A Large-Scale Study on Video Action Dataset Condensation
# [arxiv.Result.Author('Yang Chen'), arxiv.Result.Author('Sheng Guo'), arxiv.Result.Author('Limin Wang')]
# Rough differential equations for volatility
# [arxiv.Result.Author('Ofelia Bonesini'), arxiv.Result.Author('Emilio Ferrucci'), arxiv.Result.Author('Ioannis Gasteratos'), arxiv.Result.Author('Antoine Jacquier')]
# Sparse chaos in cortical circuits
# [arxiv.Result.Author('Rainer Engelken'), arxiv.Result.Author('Michael Monteforte'), arxiv.Result.Author('Fred Wolf')]
# Do NOT Think That Much for 2+3=? On the Overthinking of o1-Like LLMs
# [arxiv.Result.Author('Xingyu Chen'), arxiv.Result.Author('Jiahao Xu'), arxiv.Result.Author('Tian Liang'), arxiv.Result.Author('Zhiwei He'), arxiv.Result.Author('Jianhui Pang'), arxiv.Result.Author('Dian Yu'), arxiv.Result.Author('Linfeng Song'), arxiv.Result.Author('Qiuzhi Liu'), arxiv.Result.Author('Mengfei Zhou'), arxiv.Result.Author('Zhuosheng Zhang'), arxiv.Result.Author('Rui Wang'), arxiv.Result.Author('Zhaopeng Tu'), arxiv.Result.Author('Haitao Mi'), arxiv.Result.Author('Dong Yu')]

# %% [markdown]
# #### GIGA CLASS

# %%
class ArxivDataframe:
    def __init__(self, subject):
        self.subject = subject.lower()
        self.client = arxiv.Client()
        self.bs4_client = BeautifulSoup
    
    def _retrieve_html(self):
        base_url = f'https://arxiv.org/list/{self.subject}/new'
        page = libreq.urlopen(base_url)
        html = page.read().decode('utf-8')
        return html
    
    def _remove_brackets(self, text):
        """Remove content within brackets from text"""
        return re.sub(r'\(.*?\)', '', text).strip()
    
    def _clean_subjects(self, df):
        """Clean primary and secondary subjects"""
        df['primary_subject'] = df['primary_subject'].map(self._remove_brackets)
        df['secondary_subjects'] = df['secondary_subjects'].map(
            lambda x: [self._remove_brackets(subject) for subject in x] if isinstance(x, list) else x,
            na_action='ignore'
        )
        return df
    
    def _clean_journal(self, df):
        """Clean journal information"""
        df['submitted_journal'] = df['submitted_journal'].str.split(r'[,;:.]').str[0]
        return df
    
    def _extract_affiliations(self, pdf_reader, authors, max_pages=2):
        """
        Extract author affiliations from PDF using a simplified approach with better logging
        """
        print("\n=== Starting Affiliation Extraction ===")
        print(f"Processing authors: {authors}")
        
        affiliations = [None] * len(authors)
        
        try:
            # Get text from first pages
            full_text = ""
            for page_num in range(min(max_pages, len(pdf_reader.pages))):
                try:
                    page_text = pdf_reader.pages[page_num].extract_text()
                    full_text += page_text + "\n"
                    print(f"Successfully read page {page_num + 1}")
                except Exception as e:
                    print(f"Error reading page {page_num + 1}: {str(e)}")
                    continue

            # Clean text
            full_text = re.sub(r'\s+', ' ', full_text)
            
            # Truncate text at common section markers
            section_markers = ['Abstract', 'Introduction', 'Keywords', 'I.', '1.', 'Methods']
            for marker in section_markers:
                pos = full_text.find(marker)
                if pos != -1:
                    full_text = full_text[:pos]
                    print(f"Truncated text at marker: {marker}")
            
            print("\nLooking for affiliation blocks...")
            
            # Simple pattern to find potential affiliation blocks
            affiliation_patterns = [
                # Look for institutional addresses
                r'(?i)(?:Department|University|Institute|Laboratory|School|Center|Centre)[^.]*(?:[^.]*(?:University|Institute|Laboratory|School|Center|Centre)[^.]*)*\.',
            ]
            
            potential_affiliations = []
            for pattern in affiliation_patterns:
                matches = re.finditer(pattern, full_text)
                for match in matches:
                    aff = match.group(0).strip()
                    if len(aff) > 20:  # Filter out very short matches
                        potential_affiliations.append(aff)
                        print(f"Found potential affiliation: {aff}")
            
            # Remove duplicates while preserving order
            potential_affiliations = list(dict.fromkeys(potential_affiliations))
            
            print(f"\nFound {len(potential_affiliations)} unique potential affiliations")
            
            # For each author, try to find their affiliation
            for i, author in enumerate(authors):
                try:
                    author_name = author.split()[-1]  # Get last name
                    print(f"\nProcessing author: {author} (searching for: {author_name})")
                    
                    # Look for affiliations near author name
                    author_pos = full_text.find(author)
                    if author_pos != -1:
                        # Look at text chunk around author mention
                        window = 500  # Increased window size
                        start = max(0, author_pos - window//2)
                        end = min(len(full_text), author_pos + window//2)
                        nearby_text = full_text[start:end]
                        
                        author_affiliations = []
                        for aff in potential_affiliations:
                            if aff in nearby_text:
                                author_affiliations.append(aff)
                                print(f"Found matching affiliation: {aff}")
                        
                        if author_affiliations:
                            affiliations[i] = author_affiliations
                        else:
                            print(f"No affiliations found near author {author}")
                    else:
                        print(f"Could not find author {author} in text")
                
                except Exception as e:
                    print(f"Error processing author {author}: {str(e)}")
                    continue
            
            print("\n=== Affiliation Extraction Complete ===")
            print(f"Final affiliations: {affiliations}")
            return affiliations
            
        except Exception as e:
            print(f"Error in affiliation extraction: {str(e)}")
            return [None] * len(authors)
        
    def _extract_pdf_metrics(self, pdf_reader):
        """Extract metrics (pages, figures, tables) from PDF"""
        metrics = {
            'pages': len(pdf_reader.pages),
            'figures': 0,
            'tables': 0
        }
        
        for page in pdf_reader.pages:
            text = page.extract_text()
            # Find figures
            figure_numbers = re.findall(r'(?i)(?:Figure|Fig.|Figure.|Fig})\s+(\d+)', text)
            if figure_numbers:
                metrics['figures'] = max(metrics['figures'], max(map(int, figure_numbers)))
            
            # Find tables
            table_numbers = re.findall(r'(?i)(?:Table|Table.})\s+(\d+)', text)
            if table_numbers:
                metrics['tables'] = max(metrics['tables'], max(map(int, table_numbers)))
                
        return metrics
    
    def _process_pdf(self, pdf_link, current_metrics=None, authors=None):
        """Process PDF to extract metrics, keywords, and affiliations"""
        try:
            pdf_response = libreq.urlopen('https://' + pdf_link)
            pdf_file = pdf_response.read()
            pdf_reader = PyPDF2.PdfReader(io.BytesIO(pdf_file))
            
            # Extract metrics if needed
            metrics = self._extract_pdf_metrics(pdf_reader)
            
            # Only update metrics that are currently NaN
            if current_metrics:
                for key in metrics:
                    if pd.isna(current_metrics[key]):
                        current_metrics[key] = metrics[key]
                metrics = current_metrics
            
            # Extract keywords
            keywords = self._extract_keywords(pdf_reader)
            
            # Extract affiliations if authors are provided
            affiliations = None
            if authors:
                affiliations = self._extract_affiliations(pdf_reader, authors)
            
            return {**metrics, 'keywords': keywords, 'affiliations': affiliations}
            
        except Exception as e:
            print(f"Error processing PDF {pdf_link}: {str(e)}")
            return None
        
    def _extract_keywords(self, pdf_reader, max_pages=5):
        """
        Extract keywords from PDF with improved accuracy and efficiency across subjects
        Args:
            pdf_reader: PyPDF2.PdfReader object
            max_pages: Maximum number of pages to search (default: 5, as keywords are usually at the start)
        Returns:
            list: Extracted keywords
        """
        keywords = []
        patterns = [
            r'(?i)(?:key[ -]?words?|index terms)[:.]?\s*(.*?)(?:[.;]|\n|(?=\n\n)|$)',
            r'(?i)(?:PACS numbers?|Mathematics Subject Classification|AMS subject classifications?'
            r'|Computing Classification System|ACM CCS|MeSH terms)[:.]?\s*(.*?)(?:[.;]|\n|(?=\n\n)|$)',
            r'(?i)(?:subject headings?|thesaurus terms?|subject terms?|descriptors?)[:.]?\s*(.*?)(?:[.;]|\n|(?=\n\n)|$)',
            r'(?i)(?:mots[- ]?cl[ée]s?|schlüsselwörter|palabras[- ]?clave)[:.]?\s*(.*?)(?:[.;]|\n|(?=\n\n)|$)'
        ]

        # Common section headers that indicate the end of front matter
        section_markers = [
            '1. Introduction', '1 Introduction', 'Introduction', 
            'Background', 'Literature Review', 'Methods',
            'Methodology', 'Results', 'Discussion',
            'I. ', 'II. ', 'Section 1', 'Section 2'
        ]
        
        try:
            # Only search first few pages for efficiency
            pages_to_search = min(max_pages, len(pdf_reader.pages))          
            for page_num in range(pages_to_search):
                try:
                    text = pdf_reader.pages[page_num].extract_text()
                    if not text:
                        continue
                        
                    # Clean text while preserving important separators
                    text = re.sub(r'\s+', ' ', text)
                    text = re.sub(r'(?<=[.,;])\s*(?=[A-Z])', '\n', text)  # Add breaks at major punctuation
                    
                    # Check for section markers and truncate text
                    for marker in section_markers:
                        marker_pos = text.find(marker)
                        if marker_pos != -1:
                            text = text[:marker_pos]
                            break
                    
                    # Extract keywords using patterns
                    for pattern in patterns:
                        matches = re.findall(pattern, text, re.DOTALL | re.IGNORECASE)
                        for match in matches:
                            # Handle both string and tuple matches
                            match_text = match[0] if isinstance(match, tuple) else match
                            
                            # Clean and split the matched text
                            cleaned_keywords = match_text.strip()
                            # Split on common keyword separators
                            for separator in [';', ',', '•', '·', '—', '-', '\n']:
                                if separator in cleaned_keywords:
                                    keywords.extend([k.strip() for k in cleaned_keywords.split(separator)])
                                    break
                            else:
                                keywords.append(cleaned_keywords)
                            
                except Exception as e:
                    print(f"Error processing page {page_num}: {str(e)}")
                    continue
                
            # Post-processing of keywords
            processed_keywords = []
            for keyword in keywords:
                # Skip if too short or too long
                if not keyword or len(keyword) < 3 or len(keyword) > 100:
                    continue
                # Clean up the keyword
                cleaned = re.sub(r'^\W+|\W+$', '', keyword)  # Remove leading/trailing non-word chars
                cleaned = re.sub(r'\s+', ' ', cleaned)       # Normalize whitespace
                cleaned = cleaned.strip()               
                if cleaned and len(cleaned) >= 3:
                    processed_keywords.append(cleaned)
            
            # Remove duplicates while preserving order
            seen = set()
            final_keywords = []
            for keyword in processed_keywords:
                lower_keyword = keyword.lower()
                if lower_keyword not in seen:
                    seen.add(lower_keyword)
                    final_keywords.append(keyword)
            
            return final_keywords[:10]  # Limit to top 10 keywords
            
        except Exception as e:
            print(f"Error in keyword extraction: {str(e)}")
            return []
    
    def _metadata(self, xml_part):
        soup = self.bs4_client(xml_part, 'html.parser')
        title_tag = soup.find('div', class_='list-title mathjax')
        title = title_tag.get_text(strip=True).replace('Title:', '').strip() if title_tag else None

        # abstract
        abstract_tag = soup.find('p', class_='mathjax')
        abstract = abstract_tag.get_text(strip=True) if abstract_tag else None

        # authors
        authors_section = soup.find('div', class_='list-authors')
        authors = [author.get_text(strip=True) for author in authors_section.find_all('a')] if authors_section else []

        # comments
        comments_tag = soup.find('div', class_='list-comments mathjax')
        comments = comments_tag.get_text(strip=True).replace('Comments:', '').strip() if comments_tag else ''
        
        # figures, pages, tables
        figures_match = re.search(r'(\d+)\s+figures', comments)
        figures = int(figures_match.group(1)) if figures_match else None
        pages_match = re.search(r'(\d+)\s+pages', comments)
        pages = int(pages_match.group(1)) if pages_match else None
        tables_match = re.search(r'(\d+)\s+table[s]?', comments)
        tables = int(tables_match.group(1)) if tables_match else None

        # PDF link
        pdf_tag = soup.find('a', title='Download PDF')
        pdf_link = pdf_tag['href'] if pdf_tag else None

        # primary subject
        primary_subject_tag = soup.find('span', class_='primary-subject')
        primary_subject = primary_subject_tag.get_text(strip=True) if primary_subject_tag else None

        # secondary subjects
        subjects_section = soup.find('div', class_='list-subjects')
        if subjects_section:
            subjects_text = subjects_section.get_text(strip=True)
            subjects_split = subjects_text.split(';')
            secondary_subjects = [subject.strip() for subject in subjects_split[1:]] if len(subjects_split) > 1 else None
        else:
            secondary_subjects = None

        # journal
        submitted_journal = None
        if comments:
            for prefix in ['Submitted to ', 'Accepted to ', 'Accepted for publication in ', 'Accepted by ', 'Submitted by ']:
                if prefix in comments:
                    submitted_journal = comments.split(prefix)[-1]
                    break

        # published
        published_tag = soup.find('div', class_='list-journal-ref')
        published_journal = published_tag.get_text(strip=True).replace('Journal-ref:', '').strip() if published_tag else None

        return {
            'title': title,
            'abstract': abstract,
            'authors': authors,
            'figures': figures,
            'pages': pages,
            'tables': tables,
            'pdf_link': f'arxiv.org{pdf_link}' if pdf_link else None,
            'primary_subject': primary_subject,
            'secondary_subjects': secondary_subjects,
            'submitted_journal': submitted_journal,
            'published_journal': published_journal
        }
    
    def process_dataframe(self, df):
        """Process the dataframe to add all additional features"""
        # Clean subjects and journal information
        df = self._clean_subjects(df)
        df = self._clean_journal(df)
        
        # Initialize keywords column
        df['keywords'] = None
        df['affiliations'] = None
    
        # Process each paper
        for i in tqdm(range(len(df)), desc='Processing PDFs, for metrics, keywords and affiliations'):
            current_metrics = {
                'pages': df['pages'][i],
                'figures': df['figures'][i],
                'tables': df['tables'][i]
            }
            
            # Only process PDF if we're missing any data
            if (pd.isna(current_metrics['pages']) or 
                pd.isna(current_metrics['figures']) or 
                pd.isna(current_metrics['tables']) or 
                pd.isna(df['keywords'][i]) or
                pd.isna(df['affiliations'][i])):
                
                pdf_data = self._process_pdf(
                    df['pdf_link'][i], 
                    current_metrics,
                    authors=df['authors'][i] if 'authors' in df else None
                )
                
                if pdf_data:
                    df.at[i, 'pages'] = pdf_data['pages']
                    df.at[i, 'figures'] = pdf_data['figures']
                    df.at[i, 'tables'] = pdf_data['tables']
                    df.at[i, 'keywords'] = pdf_data['keywords']
                    if pdf_data['affiliations']:
                        df.at[i, 'affiliations'] = pdf_data['affiliations']
        
        return df
    
    def construct_dataframe(self):
        """Construct and process the complete dataframe"""
        # Get initial data
        html = self._retrieve_html()
        soup = self.bs4_client(html, 'html.parser')
        
        h3_tag = soup.find('h3', string=lambda x: x and 'New submissions' in x)
        
        if not h3_tag:
            print("New submissions header not found")
            return pd.DataFrame()
            
        try:
            number_of_papers = int(h3_tag.string.split('(')[1].split()[1])
            print(f"Number of papers: {number_of_papers}")
        except (IndexError, ValueError):
            print("Could not extract number of papers")
            return pd.DataFrame()
            
        # Get metadata for all papers
        items = soup.find_all('a', attrs={'name': True})
        if not items:
            print("No paper items found")
            return pd.DataFrame()
            
        all_metadata = []
        
        # Process papers except the last one
        for i in tqdm(range(number_of_papers-1),desc='Processing Papers'):
            start = items[i]
            end = items[i + 1]
            start_index = str(soup).find(str(start))
            end_index = str(soup).find(str(end))
            xml_part = str(soup)[start_index:end_index]
            metadata = self._metadata(xml_part)
            all_metadata.append(metadata)
            
        # Process the last paper
        last_item = items[-1]
        start_index = str(soup).find(str(last_item))
        xml_part = str(soup)[start_index:]
        metadata = self._metadata(xml_part)
        all_metadata.append(metadata)
        
        # Create and process dataframe
        df = pd.DataFrame(all_metadata) 
        return self.process_dataframe(df)

# %%
arxiv_data = ArxivDataframe('astro-ph')
# Get processed dataframe with all features
df = arxiv_data.construct_dataframe()
# Out:
# Number of papers: 55
# Processing Papers: 100%|██████████| 54/54 [00:06<00:00,  8.65it/s]
# Processing PDFs, for metrics, keywords and affiliations:   2%|▏         | 1/55 [00:03<03:04,  3.41s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['John F. Wu']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: Institute, 3700 San Martin Dr, Baltimore, MD 21218 2Department of Physics & Astronomy, Johns Hopkins University, 3400 N Charles St, Baltimore, MD 21218 3Department of Computer Science, Johns Hopkins University, 3400 N Charles St, Baltimore, MD 21218 ABSTRACT Galaxy appearances reveal the physics of how they formed and evolved.
#
# Found 1 unique potential affiliations
#
# Processing author: John F. Wu (searching for: Wu)
# No affiliations found near author John F. Wu
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None]
# Processing PDFs, for metrics, keywords and affiliations:   4%|▎         | 2/55 [00:10<05:02,  5.70s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Shi-Ju Kang', 'Shan-Shan Ren', 'Yong-Gang Zheng', 'Qingwen Wu']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: School of Physics and Electrical Engineering, Liupanshui Normal University, Liupanshui, Guizhou, 553004, People’s Republic of China 2Institute of Space Sciences, Shandong University, Weihai, Shandong, 264209, People’s Republic of China 3Department of Physics, Yunnan Normal University, Kunming, Yunnan, 650092, People’s Republic of China 4Department of Astronomy, School of Physics, Huazhong University of Science and Technology, Wuhan, Hubei, 430074, People’s Republic of China (Received March 1, 2021; Revised April 1, 2021; Accepted January 3, 2025; Published January 3, 2025) Submitted to ApJ ABSTRACT The changing-look blazars (CLBs) are the blazars that their optical spectral lines at different epochs show a significant changes and present a clear transition between the standard FSRQ and BL Lac types.
#
# Found 1 unique potential affiliations
#
# Processing author: Shi-Ju Kang (searching for: Kang)
# No affiliations found near author Shi-Ju Kang
#
# Processing author: Shan-Shan Ren (searching for: Ren)
# No affiliations found near author Shan-Shan Ren
#
# Processing author: Yong-Gang Zheng (searching for: Zheng)
# No affiliations found near author Yong-Gang Zheng
#
# Processing author: Qingwen Wu (searching for: Wu)
# No affiliations found near author Qingwen Wu
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:   5%|▌         | 3/55 [00:13<03:35,  4.15s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Mathilde Mâlin', 'Anthony Boccaletti', 'Clément Perrot', 'Pierre Baudoz', 'Daniel Rouan', 'Pierre-Olivier Lagage', 'Rens Waters', 'Manuel Güdel', 'Thomas Henning', 'Bart Vandenbussche', 'Olivier Absil', 'David Barrado', 'Benjamin Charnay', 'Elodie Choquet', 'Christophe Cossou', 'Camilla Danielski', 'Leen Decin', 'Adrian M. Glauser', 'John Pye', 'Goran Olofsson', 'Alistair Glasse', 'Polychronis Patapis', 'Pierre Royer', 'Silvia Scheithauer', 'Eugene Serabyn', 'Pascal Tremblin', 'Niall Whiteford', 'Ewine F. van Dishoeck', 'Göran Ostlin', 'Tom P. Ra', 'Gillian Wright']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Introduction
# Truncated text at marker: 1.
# Truncated text at marker: Methods
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Mathilde Mâlin (searching for: Mâlin)
# No affiliations found near author Mathilde Mâlin
#
# Processing author: Anthony Boccaletti (searching for: Boccaletti)
# No affiliations found near author Anthony Boccaletti
#
# Processing author: Clément Perrot (searching for: Perrot)
# No affiliations found near author Clément Perrot
#
# Processing author: Pierre Baudoz (searching for: Baudoz)
# No affiliations found near author Pierre Baudoz
#
# Processing author: Daniel Rouan (searching for: Rouan)
# No affiliations found near author Daniel Rouan
#
# Processing author: Pierre-Olivier Lagage (searching for: Lagage)
# No affiliations found near author Pierre-Olivier Lagage
#
# Processing author: Rens Waters (searching for: Waters)
# No affiliations found near author Rens Waters
#
# Processing author: Manuel Güdel (searching for: Güdel)
# No affiliations found near author Manuel Güdel
#
# Processing author: Thomas Henning (searching for: Henning)
# No affiliations found near author Thomas Henning
#
# Processing author: Bart Vandenbussche (searching for: Vandenbussche)
# No affiliations found near author Bart Vandenbussche
#
# Processing author: Olivier Absil (searching for: Absil)
# No affiliations found near author Olivier Absil
#
# Processing author: David Barrado (searching for: Barrado)
# No affiliations found near author David Barrado
#
# Processing author: Benjamin Charnay (searching for: Charnay)
# No affiliations found near author Benjamin Charnay
#
# Processing author: Elodie Choquet (searching for: Choquet)
# No affiliations found near author Elodie Choquet
#
# Processing author: Christophe Cossou (searching for: Cossou)
# No affiliations found near author Christophe Cossou
#
# Processing author: Camilla Danielski (searching for: Danielski)
# No affiliations found near author Camilla Danielski
#
# Processing author: Leen Decin (searching for: Decin)
# No affiliations found near author Leen Decin
#
# Processing author: Adrian M. Glauser (searching for: Glauser)
# No affiliations found near author Adrian M. Glauser
#
# Processing author: John Pye (searching for: Pye)
# No affiliations found near author John Pye
#
# Processing author: Goran Olofsson (searching for: Olofsson)
# No affiliations found near author Goran Olofsson
#
# Processing author: Alistair Glasse (searching for: Glasse)
# No affiliations found near author Alistair Glasse
#
# Processing author: Polychronis Patapis (searching for: Patapis)
# No affiliations found near author Polychronis Patapis
#
# Processing author: Pierre Royer (searching for: Royer)
# No affiliations found near author Pierre Royer
#
# Processing author: Silvia Scheithauer (searching for: Scheithauer)
# No affiliations found near author Silvia Scheithauer
#
# Processing author: Eugene Serabyn (searching for: Serabyn)
# No affiliations found near author Eugene Serabyn
#
# Processing author: Pascal Tremblin (searching for: Tremblin)
# No affiliations found near author Pascal Tremblin
#
# Processing author: Niall Whiteford (searching for: Whiteford)
# No affiliations found near author Niall Whiteford
#
# Processing author: Ewine F. van Dishoeck (searching for: Dishoeck)
# No affiliations found near author Ewine F. van Dishoeck
#
# Processing author: Göran Ostlin (searching for: Ostlin)
# No affiliations found near author Göran Ostlin
#
# Processing author: Tom P. Ra (searching for: Ra)
# No affiliations found near author Tom P. Ra
#
# Processing author: Gillian Wright (searching for: Wright)
# No affiliations found near author Gillian Wright
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:   7%|▋         | 4/55 [00:13<02:17,  2.70s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['S.I. Ipatov']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
# Truncated text at marker: I.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: S.I. Ipatov (searching for: Ipatov)
# Could not find author S.I. Ipatov in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None]
# Processing PDFs, for metrics, keywords and affiliations:   9%|▉         | 5/55 [00:16<02:19,  2.79s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Somayeh Khakpash', 'Federica Bianco', 'Georgios Vernardos', 'Gregory Dobler', 'Charles Keeton']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: University–New Brunswick, Department of Physics & Astronomy, 136 Frelinghuysen Rd, Piscataway, NJ 08854, USA 2LSST-DA Catalyst Fellow 3University of Delaware Department of Physics and Astronomy 217 Sharp Lab Newark, DE 19716 USA 4University of Delaware Joseph R.
# Found potential affiliation: School of Public Policy and Administration, 184 Academy St, Newark, DE 19716 USA 5University of Delaware Data Science Institute 6Vera C.
# Found potential affiliation: Department of Physics and Astronomy, Lehman College of the City University of New York, Bronx, NY, 10468, USA 8Department of Astrophysics, American Museum of Natural History, Central Park West and 79th Street, NY, 10024, USA ABSTRACT Enhanced modeling of microlensing variations in light curves of strongly lensed quasars improves measurements of cosmological time delays, the Hubble Constant, and quasar structure.
#
# Found 3 unique potential affiliations
#
# Processing author: Somayeh Khakpash (searching for: Khakpash)
# No affiliations found near author Somayeh Khakpash
#
# Processing author: Federica Bianco (searching for: Bianco)
# Could not find author Federica Bianco in text
#
# Processing author: Georgios Vernardos (searching for: Vernardos)
# No affiliations found near author Georgios Vernardos
#
# Processing author: Gregory Dobler (searching for: Dobler)
# No affiliations found near author Gregory Dobler
#
# Processing author: Charles Keeton (searching for: Keeton)
# No affiliations found near author Charles Keeton
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  11%|█         | 6/55 [00:18<02:06,  2.58s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Hisashi Hayakawa', 'Edward W. Cliver', 'Frédéric Clette', 'Yusuke Ebihara', 'Shin Toriumi', 'Ilaria Ermolli', 'Theodosios Chatzistergos', 'Kentaro Hattori', 'Delores J. Knipp', 'Séan P. Blake', 'Gianna Cauzzi', 'Kevin Reardon', 'Philippe-A. Bourdin', 'Dorothea Just', 'Mikhail Vokhmyanin', 'Keitaro Matsumoto', 'Yoshizumi Miyoshi', 'José R. Ribeiro', 'Ana P. Correia', 'David M. Willis', 'Matthew N. Wild', 'Sam M. Silverman']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.
# Found potential affiliation: Laboratory, Harwell Campus, Didcot OX11 0QX, UK3National Solar Observatory, Boulder, CO 80303, USA; ecliver@nso.
# Found potential affiliation: Center SILSO, Observatoire Royal de Belgique, Brussels 1180, Belgium5Research Institute for Sustainable Humanosphere, Kyoto University, Uji 6100011, Japan6Unit of Synergetic Studies for Space, Kyoto University, Kyoto 6068306, Japan7Institute of Space and Astronautical Science, Japan Aerospace Exploration Agency, Sagamihara, Kanagawa 2525210, Japan8INAF, Osservatorio Astronomico di Roma, Monte Porzio Catone I-00078, Italy9Max Planck Institute for Solar System Research, Göttingen D-37077, Germany10Faculty of Societal Safety Sciences, Kansai University, Takatsuki 5691116, Japan11Smead Aerospace Engineering Sciences Department 429 UCB, University of Colorado Boulder, Boulder, CO 80309, USA12Heliophysics Science Division, NASA Goddard Space Flight Center, Greenbelt, MD, USA13Catholic University of America, Washington, DC, USA14University of Graz, Institute of Physics, Universitätsplatz 5, 8010 Graz, Austria15Institut für Weltraumforschung, Österreichische Akademie der Wissenschaften, 8042 Graz, Austria16University of Oulu, Oulu FI-90014, Finland17Escola Secundária Henrique Medina, Esposende Av.
#
# Found 3 unique potential affiliations
#
# Processing author: Hisashi Hayakawa (searching for: Hayakawa)
# No affiliations found near author Hisashi Hayakawa
#
# Processing author: Edward W. Cliver (searching for: Cliver)
# No affiliations found near author Edward W. Cliver
#
# Processing author: Frédéric Clette (searching for: Clette)
# No affiliations found near author Frédéric Clette
#
# Processing author: Yusuke Ebihara (searching for: Ebihara)
# No affiliations found near author Yusuke Ebihara
#
# Processing author: Shin Toriumi (searching for: Toriumi)
# No affiliations found near author Shin Toriumi
#
# Processing author: Ilaria Ermolli (searching for: Ermolli)
# No affiliations found near author Ilaria Ermolli
#
# Processing author: Theodosios Chatzistergos (searching for: Chatzistergos)
# No affiliations found near author Theodosios Chatzistergos
#
# Processing author: Kentaro Hattori (searching for: Hattori)
# No affiliations found near author Kentaro Hattori
#
# Processing author: Delores J. Knipp (searching for: Knipp)
# No affiliations found near author Delores J. Knipp
#
# Processing author: Séan P. Blake (searching for: Blake)
# No affiliations found near author Séan P. Blake
#
# Processing author: Gianna Cauzzi (searching for: Cauzzi)
# No affiliations found near author Gianna Cauzzi
#
# Processing author: Kevin Reardon (searching for: Reardon)
# No affiliations found near author Kevin Reardon
#
# Processing author: Philippe-A. Bourdin (searching for: Bourdin)
# No affiliations found near author Philippe-A. Bourdin
#
# Processing author: Dorothea Just (searching for: Just)
# No affiliations found near author Dorothea Just
#
# Processing author: Mikhail Vokhmyanin (searching for: Vokhmyanin)
# No affiliations found near author Mikhail Vokhmyanin
#
# Processing author: Keitaro Matsumoto (searching for: Matsumoto)
# No affiliations found near author Keitaro Matsumoto
#
# Processing author: Yoshizumi Miyoshi (searching for: Miyoshi)
# No affiliations found near author Yoshizumi Miyoshi
#
# Processing author: José R. Ribeiro (searching for: Ribeiro)
# Found matching affiliation: Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.
#
# Processing author: Ana P. Correia (searching for: Correia)
# Found matching affiliation: Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.
#
# Processing author: David M. Willis (searching for: Willis)
# Found matching affiliation: Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.
#
# Processing author: Matthew N. Wild (searching for: Wild)
# Found matching affiliation: Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.
#
# Processing author: Sam M. Silverman (searching for: Silverman)
# Found matching affiliation: Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, ['Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.'], ['Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.'], ['Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.'], ['Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.'], ['Institute for Space-Earth Environmental Research and Institute for Advanced Researches, Nagoya University, Nagoya 4648601, Japan; hisashi@nagoya-u.']]
# Processing PDFs, for metrics, keywords and affiliations:  13%|█▎        | 7/55 [00:29<04:21,  5.45s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Philippe-A. Bourdin', 'Yasuhito Narita']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Philippe-A. Bourdin (searching for: Bourdin)
# Could not find author Philippe-A. Bourdin in text
#
# Processing author: Yasuhito Narita (searching for: Narita)
# Could not find author Yasuhito Narita in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None]
# Processing PDFs, for metrics, keywords and affiliations:  15%|█▍        | 8/55 [00:42<05:58,  7.64s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Di Wu', 'Jing-Zhi Zhou', 'Yu-Ting Kuang', 'Zhi-Chao Li', 'Zhe Chang', 'Qing-Guo Huang']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: School of Fundamental Physics and Mathematical Sciences, Hangzhou Institute for Advanced Study, UCAS, Hangzhou 310024, China bCenter for Joint Quantum Studies and Department of Physics, School of Science, Tianjin University, Tianjin 300350, China cInstitute of High Energy Physics, Chinese Academy of Sciences, Beijing 100049, China dUniversity of Chinese Academy of Sciences, Beijing 100049, China eCASKeyLaboratoryofTheoreticalPhysics, InstituteofTheoreticalPhysics, ChineseAcademy of Sciences E-mail: wudi@ucas.
#
# Found 1 unique potential affiliations
#
# Processing author: Di Wu (searching for: Wu)
# No affiliations found near author Di Wu
#
# Processing author: Jing-Zhi Zhou (searching for: Zhou)
# No affiliations found near author Jing-Zhi Zhou
#
# Processing author: Yu-Ting Kuang (searching for: Kuang)
# No affiliations found near author Yu-Ting Kuang
#
# Processing author: Zhi-Chao Li (searching for: Li)
# No affiliations found near author Zhi-Chao Li
#
# Processing author: Zhe Chang (searching for: Chang)
# No affiliations found near author Zhe Chang
#
# Processing author: Qing-Guo Huang (searching for: Huang)
# No affiliations found near author Qing-Guo Huang
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  16%|█▋        | 9/55 [00:43<04:19,  5.64s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Hui Liu', 'Hui Li', 'Sizhong Zou', 'Kaifan Ji', 'Zhenyu Jin', 'Jiahui Shan', 'Jingwei Li', 'Guanglu Shi', 'Yu Huang', 'Li Feng', 'Jianchao Xue', 'Qiao Li', 'Dechao Song', 'Ying Li']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.
#
# Found 1 unique potential affiliations
#
# Processing author: Hui Liu (searching for: Liu)
# No affiliations found near author Hui Liu
#
# Processing author: Hui Li (searching for: Li)
# No affiliations found near author Hui Li
#
# Processing author: Sizhong Zou (searching for: Zou)
# No affiliations found near author Sizhong Zou
#
# Processing author: Kaifan Ji (searching for: Ji)
# Could not find author Kaifan Ji in text
#
# Processing author: Zhenyu Jin (searching for: Jin)
# No affiliations found near author Zhenyu Jin
#
# Processing author: Jiahui Shan (searching for: Shan)
# No affiliations found near author Jiahui Shan
#
# Processing author: Jingwei Li (searching for: Li)
# No affiliations found near author Jingwei Li
#
# Processing author: Guanglu Shi (searching for: Shi)
# No affiliations found near author Guanglu Shi
#
# Processing author: Yu Huang (searching for: Huang)
# No affiliations found near author Yu Huang
#
# Processing author: Li Feng (searching for: Feng)
# No affiliations found near author Li Feng
#
# Processing author: Jianchao Xue (searching for: Xue)
# No affiliations found near author Jianchao Xue
#
# Processing author: Qiao Li (searching for: Li)
# Found matching affiliation: Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.
#
# Processing author: Dechao Song (searching for: Song)
# Found matching affiliation: Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.
#
# Processing author: Ying Li (searching for: Li)
# Found matching affiliation: Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, None, None, ['Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.'], ['Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.'], ['Laboratory of Dark Matter and Space Astronomy, Purple Mountain Observatory, Chinese Academy of Sciences, Nanjing 210023, China; nj.']]
#
# === Starting Affiliation Extraction ===
# Processing authors: ['Bing Zhang']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Processing PDFs, for metrics, keywords and affiliations:  18%|█▊        | 10/55 [00:44<03:08,  4.20s/it]
# Found 0 unique potential affiliations
#
# Processing author: Bing Zhang (searching for: Zhang)
# No affiliations found near author Bing Zhang
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None]
# Processing PDFs, for metrics, keywords and affiliations:  20%|██        | 11/55 [00:51<03:36,  4.92s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Becca Spejcher', 'Noel D. Richardson', 'Herbert Pablo', 'Marina Beltran', 'Payton Butler', 'Eddie Avila']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Becca Spejcher (searching for: Spejcher)
# Could not find author Becca Spejcher in text
#
# Processing author: Noel D. Richardson (searching for: Richardson)
# Could not find author Noel D. Richardson in text
#
# Processing author: Herbert Pablo (searching for: Pablo)
# Could not find author Herbert Pablo in text
#
# Processing author: Marina Beltran (searching for: Beltran)
# Could not find author Marina Beltran in text
#
# Processing author: Payton Butler (searching for: Butler)
# Could not find author Payton Butler in text
#
# Processing author: Eddie Avila (searching for: Avila)
# Could not find author Eddie Avila in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  22%|██▏       | 12/55 [00:55<03:22,  4.70s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Sripan Mondal', 'Akash Bairagi', 'A. K. Srivastava']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India.
# Found potential affiliation: Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India 3Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India.
#
# Found 2 unique potential affiliations
#
# Processing author: Sripan Mondal (searching for: Mondal)
# Found matching affiliation: Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India.
#
# Processing author: Akash Bairagi (searching for: Bairagi)
# Found matching affiliation: Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India.
#
# Processing author: A. K. Srivastava (searching for: Srivastava)
# Could not find author A. K. Srivastava in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [['Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India.'], ['Department of Physics, Indian Institute of Technology (BHU), Varanasi-221005, India.'], None]
# Processing PDFs, for metrics, keywords and affiliations:  24%|██▎       | 13/55 [00:56<02:38,  3.77s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Takeru K. Suzuki', 'Keiichi Ohnaka', 'Yuki Yasuda']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: School of Arts & Sciences, The University of Tokyo, 3-8-1, Komaba, Meguro, Tokyo 153-8902, Japan; Department of Astronomy, The University of Tokyo, 7-3-1, Hongo, Bunkyo, Tokyo, 113-0033, Japan; Komaba Institute for Science, The University of Tokyo, 3-8-1 Komaba, Meguro, Tokyo 153-8902, Japan 2Instituto de Astrofísica, Departamento de Física y Astronomía, Facultad de Ciencias Exactas, Universidad Andrés Bello, Fernández Concha 700, Las Condes, Santiago, Chile 3Division of Physics, Faculty of Science, Kita 10 Nishi 8, Kita-ku, Hokkaido University, Sapporo 060-0810, Japan ∗E-mail: stakeru@ea.
#
# Found 1 unique potential affiliations
#
# Processing author: Takeru K. Suzuki (searching for: Suzuki)
# Could not find author Takeru K. Suzuki in text
#
# Processing author: Keiichi Ohnaka (searching for: Ohnaka)
# Could not find author Keiichi Ohnaka in text
#
# Processing author: Yuki Yasuda (searching for: Yasuda)
# Could not find author Yuki Yasuda in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  25%|██▌       | 14/55 [01:00<02:32,  3.72s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Shi Pi', 'Misao Sasaki', 'Volodymyr Takhistov', 'Jianing Wang']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: Laboratory of Theoretical Physics, Institute of Theoretical Physics, Chinese Academy of Sciences, Beijing 100190, China bCenter for High Energy Physics, Peking University, Beijing 100871, China cKavli Institute for the Physics and Mathematics of the Universe (WPI), UTIAS, The Uni- versity of Tokyo, Kashiwa, Chiba 277-8583, Japan dCenter for Gravitational Physics and Quantum Information, Yukawa Institute for Theoret- ical Physics, Kyoto University, Kyoto 606-8502, Japan eLeung Center for Cosmology and Particle Astrophysics, National Taiwan University, Taipei 10617 fInternational Center for Quantum-field Measurement Systems for Studies of the Universe and Particles (QUP,WPI), High Energy Accelerator Research Organization (KEK), Oho 1-1, Tsukuba, Ibaraki 305-0801, Japan gTheory Center, Institute of Particle and Nuclear Studies (IPNS), High Energy Accelerator Research Organization (KEK), Tsukuba 305-0801, Japan hGraduate University for Advanced Studies (SOKENDAI), 1-1 Oho, Tsukuba, Ibaraki 305- 0801, Japan iSchool of Physical Sciences, University of Chinese Academy of Sciences, Beijing 100049, China E-mail: shi.
#
# Found 1 unique potential affiliations
#
# Processing author: Shi Pi (searching for: Pi)
# No affiliations found near author Shi Pi
#
# Processing author: Misao Sasaki (searching for: Sasaki)
# No affiliations found near author Misao Sasaki
#
# Processing author: Volodymyr Takhistov (searching for: Takhistov)
# No affiliations found near author Volodymyr Takhistov
#
# Processing author: Jianing Wang (searching for: Wang)
# No affiliations found near author Jianing Wang
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  27%|██▋       | 15/55 [01:07<03:10,  4.76s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Miftahul Hilmi', 'Nicha Leethochawalit', 'Michele Trenti', 'Benjamin Metha']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Miftahul Hilmi (searching for: Hilmi)
# Could not find author Miftahul Hilmi in text
#
# Processing author: Nicha Leethochawalit (searching for: Leethochawalit)
# Could not find author Nicha Leethochawalit in text
#
# Processing author: Michele Trenti (searching for: Trenti)
# Could not find author Michele Trenti in text
#
# Processing author: Benjamin Metha (searching for: Metha)
# Could not find author Benjamin Metha in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  29%|██▉       | 16/55 [01:16<03:48,  5.86s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Qiguo Tian', 'Lei Hao', 'Yipeng Zhou', 'Xiheng Shi', 'Tuo Ji', 'Peng Jiang', 'Lin Lin', 'Zhenya Zheng', 'Hongyan Zhou']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Qiguo Tian (searching for: Tian)
# Could not find author Qiguo Tian in text
#
# Processing author: Lei Hao (searching for: Hao)
# Could not find author Lei Hao in text
#
# Processing author: Yipeng Zhou (searching for: Zhou)
# Could not find author Yipeng Zhou in text
#
# Processing author: Xiheng Shi (searching for: Shi)
# Could not find author Xiheng Shi in text
#
# Processing author: Tuo Ji (searching for: Ji)
# Could not find author Tuo Ji in text
#
# Processing author: Peng Jiang (searching for: Jiang)
# Could not find author Peng Jiang in text
#
# Processing author: Lin Lin (searching for: Lin)
# Could not find author Lin Lin in text
#
# Processing author: Zhenya Zheng (searching for: Zheng)
# Could not find author Zhenya Zheng in text
#
# Processing author: Hongyan Zhou (searching for: Zhou)
# Could not find author Hongyan Zhou in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  31%|███       | 17/55 [01:19<03:10,  5.00s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['T. Şahin', 'F. Güney', 'S.A. Şentürk', 'N. Çınar', 'M. Marışmak']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: University, Faculty of Science, Department of Space Sciences and Technologies 07058, Antalya, Türkiye 2Institute of Graduate Studies in Science, Akdeniz University, Türkiye ABSTRACT ThisstudyintroducesalinelistfortheabundanceanalysisofF-andG-typestarsacrossthe4080–9675Åwavelength range.
#
# Found 1 unique potential affiliations
#
# Processing author: T. Şahin (searching for: Şahin)
# No affiliations found near author T. Şahin
#
# Processing author: F. Güney (searching for: Güney)
# No affiliations found near author F. Güney
#
# Processing author: S.A. Şentürk (searching for: Şentürk)
# No affiliations found near author S.A. Şentürk
#
# Processing author: N. Çınar (searching for: Çınar)
# No affiliations found near author N. Çınar
#
# Processing author: M. Marışmak (searching for: Marışmak)
# No affiliations found near author M. Marışmak
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  33%|███▎      | 18/55 [01:29<04:10,  6.77s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['V. Hocdé', 'A. Matter', 'N. Nardetto', 'A. Gallenne', 'P. Kervella', 'A. Mérand', 'G. Pietrzyński', 'W. Gieren', 'J. Leftley', 'S. Robbe-Dubois', 'B. Lopez', 'M. C. Bailleul', 'G. Bras', 'R. Smolec', 'P. Wielgórski', 'G. Hajdu', 'A. Afanasiev']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Introduction
# Truncated text at marker: 1.
# Truncated text at marker: Methods
#
# Looking for affiliation blocks...
# Found potential affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
# Found potential affiliation: Laboratory for Astronomy, IRL 3386, CNRS, Casilla 36-D, Santiago, Chile 5LESIA, Observatoire de Paris, Université PSL, CNRS, Sorbonne Université, Université Paris-Cité, 5 Place Jules Janssen,92195 Meudon, France, 6European Southern Observatory, Karl-Schwarzschild-Str.
#
# Found 2 unique potential affiliations
#
# Processing author: V. Hocdé (searching for: Hocdé)
# Could not find author V. Hocdé in text
#
# Processing author: A. Matter (searching for: Matter)
# No affiliations found near author A. Matter
#
# Processing author: N. Nardetto (searching for: Nardetto)
# No affiliations found near author N. Nardetto
#
# Processing author: A. Gallenne (searching for: Gallenne)
# No affiliations found near author A. Gallenne
#
# Processing author: P. Kervella (searching for: Kervella)
# No affiliations found near author P. Kervella
#
# Processing author: A. Mérand (searching for: Mérand)
# No affiliations found near author A. Mérand
#
# Processing author: G. Pietrzyński (searching for: Pietrzyński)
# Could not find author G. Pietrzyński in text
#
# Processing author: W. Gieren (searching for: Gieren)
# No affiliations found near author W. Gieren
#
# Processing author: J. Leftley (searching for: Leftley)
# No affiliations found near author J. Leftley
#
# Processing author: S. Robbe-Dubois (searching for: Robbe-Dubois)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: B. Lopez (searching for: Lopez)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: M. C. Bailleul (searching for: Bailleul)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: G. Bras (searching for: Bras)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: R. Smolec (searching for: Smolec)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: P. Wielgórski (searching for: Wielgórski)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: G. Hajdu (searching for: Hajdu)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# Processing author: A. Afanasiev (searching for: Afanasiev)
# Found matching affiliation: Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.'], ['Centre, Polish Academy of Sciences, Bartycka 18, 00-716 Warszawa, Poland email : vhocde@camk.']]
# Processing PDFs, for metrics, keywords and affiliations:  35%|███▍      | 19/55 [01:35<03:54,  6.50s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Guanwen Fang', 'Yao Dai', 'Zesen Lin', 'Chichun Zhou', 'Jie Song', 'Yizhou Gu', 'Xiaotong Guo', 'Anqi Mao', 'Xu Kong']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Introduction
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
# Found potential affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
# Found potential affiliation: Department of Physics, The Chinese University of Hong Kong, Shatin, N.
# Found potential affiliation: School of Engineering, Dali University, Dali 671003, People’s Republic of China e-mail: zhouchichun@dali.
# Found potential affiliation: Department of Astronomy, University of Science and Technology of China, Hefei 230026, China, e-mail: xkong@ustc.
# Found potential affiliation: School of Astronomy and Space Science, University of Science and Technology of China, Hefei 230026, People’s Republic of China 6Tsung-Dao Lee Institute, and Key Laboratory for Particle Physics, Astrophysics and Cosmology, Ministry of Education, Shanghai Jiao Tong University, Shanghai 200240, China Received —; accepted — ABSTRACT By combining unsupervised and supervised machine learning methods, we have proposed a framework, called USmorph , to carry out automatic classifications of galaxy morphologies.
#
# Found 5 unique potential affiliations
#
# Processing author: Guanwen Fang (searching for: Fang)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Yao Dai (searching for: Dai)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Zesen Lin (searching for: Lin)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Chichun Zhou (searching for: Zhou)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Jie Song (searching for: Song)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Yizhou Gu (searching for: Gu)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Xiaotong Guo (searching for: Guo)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
#
# Processing author: Anqi Mao (searching for: Mao)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
# Found matching affiliation: Department of Physics, The Chinese University of Hong Kong, Shatin, N.
#
# Processing author: Xu Kong (searching for: Kong)
# Found matching affiliation: Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.
# Found matching affiliation: Department of Physics, The Chinese University of Hong Kong, Shatin, N.
#
# === Affiliation Extraction Complete ===
# Final affiliations: [['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.', 'Department of Physics, The Chinese University of Hong Kong, Shatin, N.'], ['Institute of Astronomy and Astrophysics, Anqing Normal University, Anqing 246133, People’s Republic of China, e-mail: wen@mail.', 'Department of Physics, The Chinese University of Hong Kong, Shatin, N.']]
# Processing PDFs, for metrics, keywords and affiliations:  36%|███▋      | 20/55 [01:44<04:14,  7.28s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Yanping Cong', 'Bin Yue', 'Yidong Xu', 'Furen Deng', 'Jiajun Zhang', 'Xuelei Chen']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: Laboratory of Radio Astronomy and Technology, Chinese Academy of Sciences, 20A Datun Road, Chaoyang District, Beijing 100101, China 4School of Astronomy and Space Science, University of Chinese Academy of Sciences, Beijing 100049, China ABSTRACT Loop I/North Polar Spur (NPS) is the giant arc structure above the Galactic plane observed in the radio sky.
# Found potential affiliation: Center (GC), associated with the Fermi Bubble and eROSITA X-ray bubble.
#
# Found 2 unique potential affiliations
#
# Processing author: Yanping Cong (searching for: Cong)
# No affiliations found near author Yanping Cong
#
# Processing author: Bin Yue (searching for: Yue)
# No affiliations found near author Bin Yue
#
# Processing author: Yidong Xu (searching for: Xu)
# No affiliations found near author Yidong Xu
#
# Processing author: Furen Deng (searching for: Deng)
# No affiliations found near author Furen Deng
#
# Processing author: Jiajun Zhang (searching for: Zhang)
# No affiliations found near author Jiajun Zhang
#
# Processing author: Xuelei Chen (searching for: Chen)
# No affiliations found near author Xuelei Chen
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  38%|███▊      | 21/55 [01:58<05:12,  9.18s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Tanvi Sharma', 'Wen-Ping Chen', 'Beth Biller', 'Loic Albert', 'Belinda Damian', 'Jessy Jose', 'Bhavana Lalchand', 'Michael C. Liu', 'Yumiko Oasa']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: I.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Tanvi Sharma (searching for: Sharma)
# Could not find author Tanvi Sharma in text
#
# Processing author: Wen-Ping Chen (searching for: Chen)
# Could not find author Wen-Ping Chen in text
#
# Processing author: Beth Biller (searching for: Biller)
# Could not find author Beth Biller in text
#
# Processing author: Loic Albert (searching for: Albert)
# Could not find author Loic Albert in text
#
# Processing author: Belinda Damian (searching for: Damian)
# Could not find author Belinda Damian in text
#
# Processing author: Jessy Jose (searching for: Jose)
# Could not find author Jessy Jose in text
#
# Processing author: Bhavana Lalchand (searching for: Lalchand)
# Could not find author Bhavana Lalchand in text
#
# Processing author: Michael C. Liu (searching for: Liu)
# Could not find author Michael C. Liu in text
#
# Processing author: Yumiko Oasa (searching for: Oasa)
# Could not find author Yumiko Oasa in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None]
#
# === Starting Affiliation Extraction ===
# Processing authors: ['N. K. Bhadari', 'L. K. Dewangan', 'O. R. Jadhav', 'Ariful Hoque', 'L. E. Pirogov', 'Paul F. Goldsmith', 'A. K. Maity', 'Saurabh Sharma', 'A. Haj Ismail', 'Tapas Baug']
# Successfully read page 1
# Processing PDFs, for metrics, keywords and affiliations:  40%|████      | 22/55 [02:04<04:28,  8.13s/it]
# Successfully read page 2
# Truncated text at marker: Introduction
# Truncated text at marker: 1.
# Truncated text at marker: Methods
#
# Looking for affiliation blocks...
# Found potential affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
# Found potential affiliation: Institute of Technology, Gandhinagar 382355, India 3Satyendra Nath Bose National Centre for Basic Sciences, Block-JD, Sector-III, Salt Lake, Kolkata-700 106, India 4Institute of Applied Physics of the Russian Academy of Sciences, 46 Ul’yanov Str.
# Found potential affiliation: Laboratory, California Institute of Technology, 4800 Oak Grove Drive, Pasadena, CA 91109, USA 6Aryabhatta Research Institute of Observational sciencES (ARIES), Manora Peak, Nainital 263001, India 7College of Humanities and Sciences, Ajman University, Ajman P.
#
# Found 3 unique potential affiliations
#
# Processing author: N. K. Bhadari (searching for: Bhadari)
# No affiliations found near author N. K. Bhadari
#
# Processing author: L. K. Dewangan (searching for: Dewangan)
# No affiliations found near author L. K. Dewangan
#
# Processing author: O. R. Jadhav (searching for: Jadhav)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: Ariful Hoque (searching for: Hoque)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: L. E. Pirogov (searching for: Pirogov)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: Paul F. Goldsmith (searching for: Goldsmith)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: A. K. Maity (searching for: Maity)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: Saurabh Sharma (searching for: Sharma)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: A. Haj Ismail (searching for: Ismail)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# Processing author: Tapas Baug (searching for: Baug)
# Found matching affiliation: Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.'], ['Laboratory, Ahmedabad 380009, India e-mail: bhadrinaval@gmail.']]
# Processing PDFs, for metrics, keywords and affiliations:  42%|████▏     | 23/55 [02:05<03:14,  6.06s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Tim Jenness', 'Stelios Voutsinas', 'Gregory P. Dubois-Felsmann', 'Andrei Salnikov']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: Institute of Technology, MS 100-22, Pasadena, CA 91125-2200, USA 3SLAC National Accelerator Laboratory, 2575 Sand Hill Rd.
#
# Found 1 unique potential affiliations
#
# Processing author: Tim Jenness (searching for: Jenness)
# No affiliations found near author Tim Jenness
#
# Processing author: Stelios Voutsinas (searching for: Voutsinas)
# Could not find author Stelios Voutsinas in text
#
# Processing author: Gregory P. Dubois-Felsmann (searching for: Dubois-Felsmann)
# No affiliations found near author Gregory P. Dubois-Felsmann
#
# Processing author: Andrei Salnikov (searching for: Salnikov)
# ...
# Processing authors: ['M.Rumenskikh', 'A.V.Taichenachev', 'I.F.Shaikhislamov', 'V.I.Yudin']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
# Truncated text at marker: I.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: M.Rumenskikh (searching for: M.Rumenskikh)
# No affiliations found near author M.Rumenskikh
#
# Processing author: A.V.Taichenachev (searching for: A.V.Taichenachev)
# Could not find author A.V.Taichenachev in text
#
# Processing author: I.F.Shaikhislamov (searching for: I.F.Shaikhislamov)
# Could not find author I.F.Shaikhislamov in text
#
# Processing author: V.I.Yudin (searching for: V.I.Yudin)
# Could not find author V.I.Yudin in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  85%|████████▌ | 47/55 [06:55<03:12, 24.07s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Yuji He', 'Hailong Yuan', 'Zhongrui Bai', 'Mingkuan Yang', 'Mengxin Wang', 'Yiqiao Dong', 'Xin Huang', 'Ming Zhou', 'Qian Liu', 'Xiaozhen Yang', 'Ganyu Li', 'Ziyue Jiang', 'Haotong Zhang']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
# Found potential affiliation: Laboratory of Optical Astronomy, National Astronomical Observatories, Chinese Academy of Sciences, Beijing 100101, China 2School of Astronomy and Space Science, University of Chinese Academy of Sciences, Beijing 100049, China 3Observatoire de Paris, Paris Sciences et Lettres, CNRS, Place Jules Janssen, F-92195 Meudon, France ABSTRACT We report the analysis of the detached eclipsing spectroscopic binary system LAMOST J101356.
#
# Found 1 unique potential affiliations
#
# Processing author: Yuji He (searching for: He)
# No affiliations found near author Yuji He
#
# Processing author: Hailong Yuan (searching for: Yuan)
# No affiliations found near author Hailong Yuan
#
# Processing author: Zhongrui Bai (searching for: Bai)
# No affiliations found near author Zhongrui Bai
#
# Processing author: Mingkuan Yang (searching for: Yang)
# No affiliations found near author Mingkuan Yang
#
# Processing author: Mengxin Wang (searching for: Wang)
# No affiliations found near author Mengxin Wang
#
# Processing author: Yiqiao Dong (searching for: Dong)
# No affiliations found near author Yiqiao Dong
#
# Processing author: Xin Huang (searching for: Huang)
# No affiliations found near author Xin Huang
#
# Processing author: Ming Zhou (searching for: Zhou)
# No affiliations found near author Ming Zhou
#
# Processing author: Qian Liu (searching for: Liu)
# No affiliations found near author Qian Liu
#
# Processing author: Xiaozhen Yang (searching for: Yang)
# No affiliations found near author Xiaozhen Yang
#
# Processing author: Ganyu Li (searching for: Li)
# No affiliations found near author Ganyu Li
#
# Processing author: Ziyue Jiang (searching for: Jiang)
# No affiliations found near author Ziyue Jiang
#
# Processing author: Haotong Zhang (searching for: Zhang)
# No affiliations found near author Haotong Zhang
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  87%|████████▋ | 48/55 [07:02<02:13, 19.10s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Apashanka Das', 'Biswajit Pandey']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Abstract
#
# Looking for affiliation blocks...
# Found potential affiliation: Department of Physics, Visva-Bharati University, Santiniketan, 731235, India E-mail: a.
#
# Found 1 unique potential affiliations
#
# Processing author: Apashanka Das (searching for: Das)
# Found matching affiliation: Department of Physics, Visva-Bharati University, Santiniketan, 731235, India E-mail: a.
#
# Processing author: Biswajit Pandey (searching for: Pandey)
# Found matching affiliation: Department of Physics, Visva-Bharati University, Santiniketan, 731235, India E-mail: a.
#
# === Affiliation Extraction Complete ===
# Final affiliations: [['Department of Physics, Visva-Bharati University, Santiniketan, 731235, India E-mail: a.'], ['Department of Physics, Visva-Bharati University, Santiniketan, 731235, India E-mail: a.']]
# Processing PDFs, for metrics, keywords and affiliations:  89%|████████▉ | 49/55 [07:04<01:24, 14.01s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Jing Wang', 'Dong Yang', 'Xuchen Lin', 'Qifeng Huang', 'Zhijie Qu', 'Hsiao-Wen Chen', 'Hong Guo', 'Luis C. Ho', 'Peng Jiang', 'Zezhong Liang', 'Céline Péroux', 'Lister Staveley-Smith', 'Simon Weng']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
# Found potential affiliation: Institute for Astronomy and Astrophysics, Peking University, Beijing 100871, China 2Department of Astronomy and Astrophysics, The University of Chicago, 5640 S.
# Found potential affiliation: Centre for Radio Astronomy Research, University of Western Australia, 35 Stirling Highway, Crawley, WA 6009, Australia 8ARC Centre of Excellence for All-Sky Astrophysics in 3 Dimensions (ASTRO 3D), Australia 9Sydney Institute for Astronomy, School of Physics A28, University of Sydney, NSW 2006, Australia 10ATNF , CSIRO Space and Astronomy, PO Box 76, Epping, NSW 1710, Australia ABSTRACT We present the H Isurface density ( ΣHI) radial distributions based on total-power H Iimages obtained by FAST in the FEASTS program, for 35 galaxies with inclinations lower than 72°.
#
# Found 2 unique potential affiliations
#
# Processing author: Jing Wang (searching for: Wang)
# Could not find author Jing Wang in text
#
# Processing author: Dong Yang (searching for: Yang)
# Could not find author Dong Yang in text
#
# Processing author: Xuchen Lin (searching for: Lin)
# Could not find author Xuchen Lin in text
#
# Processing author: Qifeng Huang (searching for: Huang)
# Could not find author Qifeng Huang in text
#
# Processing author: Zhijie Qu (searching for: Qu)
# Could not find author Zhijie Qu in text
#
# Processing author: Hsiao-Wen Chen (searching for: Chen)
# Could not find author Hsiao-Wen Chen in text
#
# Processing author: Hong Guo (searching for: Guo)
# Could not find author Hong Guo in text
#
# Processing author: Luis C. Ho (searching for: Ho)
# Could not find author Luis C. Ho in text
#
# Processing author: Peng Jiang (searching for: Jiang)
# Could not find author Peng Jiang in text
#
# Processing author: Zezhong Liang (searching for: Liang)
# Could not find author Zezhong Liang in text
#
# Processing author: Céline Péroux (searching for: Péroux)
# Could not find author Céline Péroux in text
#
# Processing author: Lister Staveley-Smith (searching for: Staveley-Smith)
# Could not find author Lister Staveley-Smith in text
#
# Processing author: Simon Weng (searching for: Weng)
# Could not find author Simon Weng in text
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  91%|█████████ | 50/55 [07:07<00:52, 10.59s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['P. Penil', 'A. Domínguez', 'S. Buson', 'M. Ajello', 'S. Adhikari', 'A. Rico']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: Department of Physics and Astronomy, Clemson University, Kinard Lab of Physics, Clemson, SC 29634-0978, USA 2IPARCOS and Department of EMFTEL, Universidad Complutense de Madrid, E-28040 Madrid, Spain 3Julius-Maximilians-Universit¨ at, 97070, W¨ urzburg, Germany (Accepted January 3, 2025) ABSTRACT Jetted Active Galactic Nuclei (AGN) exhibit variability across a wide range of time scales.
#
# Found 1 unique potential affiliations
#
# Processing author: P. Penil (searching for: Penil)
# Could not find author P. Penil in text
#
# Processing author: A. Domínguez (searching for: Domínguez)
# Could not find author A. Domínguez in text
#
# Processing author: S. Buson (searching for: Buson)
# No affiliations found near author S. Buson
#
# Processing author: M. Ajello (searching for: Ajello)
# No affiliations found near author M. Ajello
#
# Processing author: S. Adhikari (searching for: Adhikari)
# No affiliations found near author S. Adhikari
#
# Processing author: A. Rico (searching for: Rico)
# No affiliations found near author A. Rico
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  93%|█████████▎| 51/55 [07:10<00:33,  8.26s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Konstantin V. Getman', 'Oleg Kochukhov', 'Joe P. Ninan', 'Eric D. Feigelson', 'Vladimir S. Airapetian', 'Abygail R. Waggoner', 'L. Ilsedore Cleeves', 'Jan Forbrich', 'Sergio A. Dzib', 'Charles J. Law', 'Christian Rab', 'Daniel M. Krolikowski']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
# Found potential affiliation: Department of Astronomy & Astrophysics Pennsylvania State University 525 Davey Laboratory University Park, PA 16802, USA 2Department of Physics and Astronomy, Uppsala University, Box 516, 75120 Uppsala, Sweden 3Department of Astronomy and Astrophysics, Tata Institute of Fundamental Research, Homi Bhabha Road, Colaba, Mumbai 400005, India 4American University, 4400 Massachusetts Avenue NW, Washington, DC 20016, USA USA 5NASA/GSFC/SEEC, Greenbelt, MD 20771, USA 6University of Virginia, Charlottesville, VA 22904, USA 7Department of Astronomy, University of Wisconsin-Madison, 475 N Charter St, Madison, WI 53706 8Centre for Astrophysics Research, University of Hertfordshire, College Lane, Hatfield, AL10 9AB, UK 9Max-Planck-Institut fur Radioastronomie (MPIfR), Auf dem Hugel 69, 53121 Bonn, Germany 10University Observatory, Faculty of Physics, Ludwig-Maximilians-Universitat Munchen, Scheinerstr.
# Found potential affiliation: University of Arizona, 933 N.
#
# Found 2 unique potential affiliations
#
# Processing author: Konstantin V. Getman (searching for: Getman)
# No affiliations found near author Konstantin V. Getman
#
# Processing author: Oleg Kochukhov (searching for: Kochukhov)
# No affiliations found near author Oleg Kochukhov
#
# Processing author: Joe P. Ninan (searching for: Ninan)
# No affiliations found near author Joe P. Ninan
#
# Processing author: Eric D. Feigelson (searching for: Feigelson)
# No affiliations found near author Eric D. Feigelson
#
# Processing author: Vladimir S. Airapetian (searching for: Airapetian)
# No affiliations found near author Vladimir S. Airapetian
#
# Processing author: Abygail R. Waggoner (searching for: Waggoner)
# No affiliations found near author Abygail R. Waggoner
#
# Processing author: L. Ilsedore Cleeves (searching for: Cleeves)
# No affiliations found near author L. Ilsedore Cleeves
#
# Processing author: Jan Forbrich (searching for: Forbrich)
# No affiliations found near author Jan Forbrich
#
# Processing author: Sergio A. Dzib (searching for: Dzib)
# No affiliations found near author Sergio A. Dzib
#
# Processing author: Charles J. Law (searching for: Law)
# No affiliations found near author Charles J. Law
#
# Processing author: Christian Rab (searching for: Rab)
# No affiliations found near author Christian Rab
#
# Processing author: Daniel M. Krolikowski (searching for: Krolikowski)
# No affiliations found near author Daniel M. Krolikowski
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None, None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  95%|█████████▍| 52/55 [07:12<00:19,  6.41s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Alfredo Micera', 'Daniel Verscharen', 'Jesse T. Coburn', 'Maria Elena Innocenti']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Keywords
#
# Looking for affiliation blocks...
# Found potential affiliation: Laboratory, University College London, Dorking, UK 3Space Science Institute, Boulder, CO 80301, USA ABSTRACT In-situ observations of the solar wind have shown that the electron velocity distribution function (VDF) consists of a quasi-Maxwellian core, comprising most of the electron population, and two sparser components: the halo, which are suprathermal and quasi-isotropic electrons, and an escaping beam population, the strahl.
#
# Found 1 unique potential affiliations
#
# Processing author: Alfredo Micera (searching for: Micera)
# No affiliations found near author Alfredo Micera
#
# Processing author: Daniel Verscharen (searching for: Verscharen)
# No affiliations found near author Daniel Verscharen
#
# Processing author: Jesse T. Coburn (searching for: Coburn)
# No affiliations found near author Jesse T. Coburn
#
# Processing author: Maria Elena Innocenti (searching for: Innocenti)
# No affiliations found near author Maria Elena Innocenti
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  96%|█████████▋| 53/55 [07:20<00:13,  6.83s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Nicola Barbieri', 'Thejs Brinckmann', 'Stefano Gariazzo', 'Massimiliano Lattanzi', 'Sergio Pastor', 'Ofelia Pisanti']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: Introduction
#
# Looking for affiliation blocks...
# Found potential affiliation: Department of Physics, University of Turin, via P.
#
# Found 1 unique potential affiliations
#
# Processing author: Nicola Barbieri (searching for: Barbieri)
# No affiliations found near author Nicola Barbieri
#
# Processing author: Thejs Brinckmann (searching for: Brinckmann)
# No affiliations found near author Thejs Brinckmann
#
# Processing author: Stefano Gariazzo (searching for: Gariazzo)
# No affiliations found near author Stefano Gariazzo
#
# Processing author: Massimiliano Lattanzi (searching for: Lattanzi)
# No affiliations found near author Massimiliano Lattanzi
#
# Processing author: Sergio Pastor (searching for: Pastor)
# No affiliations found near author Sergio Pastor
#
# Processing author: Ofelia Pisanti (searching for: Pisanti)
# No affiliations found near author Ofelia Pisanti
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None, None, None, None, None]
# Processing PDFs, for metrics, keywords and affiliations:  98%|█████████▊| 54/55 [07:20<00:05,  5.05s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Chris Fox', 'Paul Wiegert']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
# Found potential affiliation: Department of Physics & Astronomy, The University of Western Ontario, London, Ontario, Canada 2Institute for Earth and Space Exploration (IESX), The University of Western Ontario, London, Ontario, Canada Submitted to the Monthly Notices of the Royal Astronomical Society, December 2024 ABSTRACT ThedebrisdiskaroundHD181327showsasignificantasymmetryinitssurfacebrightnessprofilewhenviewedinvisiblelight.
#
# Found 1 unique potential affiliations
#
# Processing author: Chris Fox (searching for: Fox)
# No affiliations found near author Chris Fox
#
# Processing author: Paul Wiegert (searching for: Wiegert)
# No affiliations found near author Paul Wiegert
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None, None]
# Processing PDFs, for metrics, keywords and affiliations: 100%|██████████| 55/55 [07:23<00:00,  8.07s/it]
# === Starting Affiliation Extraction ===
# Processing authors: ['Amelia Carolina Sparavigna']
# Successfully read page 1
# Successfully read page 2
# Truncated text at marker: 1.
#
# Looking for affiliation blocks...
#
# Found 0 unique potential affiliations
#
# Processing author: Amelia Carolina Sparavigna (searching for: Sparavigna)
# No affiliations found near author Amelia Carolina Sparavigna
#
# === Affiliation Extraction Complete ===
# Final affiliations: [None]

# %%
df
# Out:
#                                                 title  \
# 0   Insights on Galaxy Evolution from Interpretabl...
# 1   Hunting for the candidates of Changing-Look Bl...
# 2   First unambiguous detection of ammonia in the ...
# 3   Exchange of meteorites between the terrestrial...
# 4   Autoencoder Reconstruction of Cosmological Mic...
# 5   The Extreme Space Weather Event of 1872 Februa...
# 6   Electromotive field in space and astrophysical...
# 7   Can tensor-scalar induced GWs dominate PTA obs...
# 8   Improving image quality of the Solar Disk Imag...
# 9                 On the Duration of Gamma-Ray Bursts
# 10  An Investigation into the Variability of Lumin...
# 11  Dynamics and Energetics of Resistive, Thermall...
# 12  Red Giant Winds Driven by Alfv\'en Waves with ...
# 13  Primordial Black Hole Formation from Power Spe...
# 14  A novel analysis of contamination in Lyman-bre...
# 15  Metal-strong Inflows at the Outer-galactic-sca...
# 16  An Updated Line List for Spectroscopic Investi...
# 17  Circumstellar emission of Cepheids across the ...
# 18  An efficient unsupervised classification model...
# 19  Loop I/NPS morphology predictions in the ultra...
# 20  A Novel Survey for Young Substellar Objects wi...
# 21  JWST-ALMA Study of a Hub-Filament System in th...
# 22  Implementing SIAv2 Over Rubin Observatory's Da...
# 23  Fermi-LAT Discovery of a Gamma-ray Outburst fr...
# 24  Detection of H2O and CO2 in the Atmosphere of ...
# 25  Measurement of Turbulence Injection Scale Down...
# 26  Role of gravitational decoupling on theoretica...
# 27  Depolarization and polarization transfer rates...
# 28  Prospects for measuring neutrino mass with 21-...
# 29  Influence of departures from LTE on determinat...
# 30  Excess Ultraviolet Emission at High Galactic L...
# 31  Unraveling the kinematic and morphological evo...
# 32  Stellar Weak Rates and Mass Fractions of 20 Mo...
# 33  Testing the extended corona model with the opt...
# 34  An intriguing coincidence between the majority...
# 35  A metamaterial telescope at millimetre wavelen...
# 36  Chapter 15: Open Questions and Future Directio...
# 37  The Role of Electric Dominance for Particle In...
# 38  The $z \gtrsim 9$ galaxy UV luminosity functio...
# 39  On the population of electron-positron pairs i...
# 40  Photometric Objects Around Cosmic Webs (PAC). ...
# 41  Detection of "diffuse" coronal He I 1083 durin...
# 42  The angular momentum of 1.2$M_\odot$ to 2.0$M_...
# 43  SpecPT (Spectroscopy Pre-trained Transformer) ...
# 44  First Search for Pulsed CH Maser Emission Stim...
# 45  Probing exoplanetary magnetism via atomic alig...
# 46  LAMOST J101356.33+272410.7: A Detached White D...
# 47  The long road to the Green Valley: Tracing the...
# 48  FEASTS: Radial Distribution of HI surface dens...
# 49  Systematic Search for Long-Term Trends in Ferm...
# 50  Multi-Observatory Study of Young Stellar Energ...
# 51  Quasi-parallel anti-sunward propagating whistl...
# 52  Current constraints on cosmological scenarios ...
# 53  A Planet as the Possible Cause of the HD 18132...
# 54  Two Egyptian Kings, Shepseskaf and Userkaf, an...
#
#                                              abstract  \
# 0   Galaxy appearances reveal the physics of how t...
# 1   The changing-look blazars (CLBs) are the blaza...
# 2   The newly accessible mid-infrared (MIR) window...
# 3   The evolution of the orbits of bodies ejected ...
# 4   Enhanced modeling of microlensing variations i...
# 5   We review observations of solar activity, geom...
# 6   The concept of electromotive field appears in ...
# 7   Observational constraints on small-scale primo...
# 8   The in-flight calibration and performance of t...
# 9   Recently, a short-duration GRB with supernova ...
# 10  Luminous Blue Variables (LBVs) are enigmatic, ...
# 11  We study the asymmetric interaction of wave-li...
# 12  We investigate the driving mechanism of Alfvén...
# 13  Primordial Black Holes (PBHs) can form from gr...
# 14  Potential contamination from low/intermediate-...
# 15  We present an analysis of the absorption-line ...
# 16  This study introduces a line list for the abun...
# 17  The circumstellar envelopes (CSE) of Cepheids ...
# 18  In this work, we update the unsupervised machi...
# 19  Loop I/North Polar Spur (NPS) is the giant arc...
# 20  We present a study of very low-mass stars and ...
# 21  Star clusters, including high-mass stars, form...
# 22  The IVOA Simple Image Access version 2 protoco...
# 23  3C 216 is an extra-galactic radio source class...
# 24  We characterize the atmosphere of the hot supe...
# 25  The solar atmosphere displays a sharp temperat...
# 26  Advancements in theoretical simulations of mas...
# 27  This paper is a continuation of a series of st...
# 28  Both particle physics experiments and cosmolog...
# 29  The influence of departures from local thermod...
# 30  We present new observations of the cosmic ultr...
# 31  We modeled the kinematics of the Small Magella...
# 32  This work presents stellar weak rates and mass...
# 33  The illumination of the accretion disks is fre...
# 34  A significant part of the Milky Way (MW) dwarf...
# 35  In this paper we present a novel telescope com...
# 36  In this chapter we attempt to distill the very...
# 37  Magnetic reconnection in relativistic plasmas ...
# 38  The high-redshift UV luminosity function provi...
# 39  In this study we consider the possibility of t...
# 40  Star formation quenching in galaxies is a crit...
# 41  Strong He I 1083 nm atomic line signals have b...
# 42  \textit{Kepler} and \textit{Gaia} data shows a...
# 43  We introduce the Spectroscopy Pre-trained Tran...
# 44  We present the first search for pulsed CH mase...
# 45  The intrinsic magnetic fields of exoplanets af...
# 46  We report the analysis of the detached eclipsi...
# 47  We study the evolution of the progenitors of t...
# 48  We present the HI surface density ($\Sigma_{\r...
# 49  Jetted Active Galactic Nuclei (AGN) exhibit va...
# 50  We explore the empirical power-law relationshi...
# 51  In-situ observations of the solar wind have sh...
# 52  We present an updated analysis of cosmological...
# 53  The debris disk around HD 181327 shows a signi...
# 54  Recently, arXiv published a work by G. Magli a...
#
#                                               authors  figures  pages  tables  \
# 0                                        [John F. Wu]      4.0   10.0     2.0
# 1   [Shi-Ju Kang, Shan-Shan Ren, Yong-Gang Zheng, ...      7.0   13.0     3.0
# 2   [Mathilde Mâlin, Anthony Boccaletti, Clément P...      6.0   18.0     4.0
# 3                                       [S.I. Ipatov]      0.0    6.0     0.0
# 4   [Somayeh Khakpash, Federica Bianco, Georgios V...     11.0   18.0     1.0
# 5   [Hisashi Hayakawa, Edward W. Cliver, Frédéric ...     13.0   20.0     2.0
# 6              [Philippe-A. Bourdin, Yasuhito Narita]      8.0   23.0     0.0
# 7   [Di Wu, Jing-Zhi Zhou, Yu-Ting Kuang, Zhi-Chao...      7.0   19.0     1.0
# 8   [Hui Liu, Hui Li, Sizhong Zou, Kaifan Ji, Zhen...     10.0   14.0     1.0
# 9                                        [Bing Zhang]      1.0   10.0     0.0
# 10  [Becca Spejcher, Noel D. Richardson, Herbert P...      7.0   16.0     2.0
# 11   [Sripan Mondal, Akash Bairagi, A. K. Srivastava]      7.0   17.0     0.0
# 12    [Takeru K. Suzuki, Keiichi Ohnaka, Yuki Yasuda]     10.0   15.0     4.0
# 13  [Shi Pi, Misao Sasaki, Volodymyr Takhistov, Ji...     30.0   61.0     3.0
# 14  [Miftahul Hilmi, Nicha Leethochawalit, Michele...      8.0   12.0     1.0
# 15  [Qiguo Tian, Lei Hao, Yipeng Zhou, Xiheng Shi,...     15.0   17.0     2.0
# 16  [T. Şahin, F. Güney, S.A. Şentürk, N. Çınar, M...      7.0   23.0    10.0
# 17  [V. Hocdé, A. Matter, N. Nardetto, A. Gallenne...     17.0   22.0     5.0
# 18  [Guanwen Fang, Yao Dai, Zesen Lin, Chichun Zho...     12.0   12.0     1.0
# 19  [Yanping Cong, Bin Yue, Yidong Xu, Furen Deng,...      5.0   11.0     1.0
# 20  [Tanvi Sharma, Wen-Ping Chen, Beth Biller, Loi...     35.0   25.0     4.0
# 21  [N. K. Bhadari, L. K. Dewangan, O. R. Jadhav, ...     11.0   10.0     1.0
# 22  [Tim Jenness, Stelios Voutsinas, Gregory P. Du...      1.0    4.0     0.0
# 23  [Federica Giacchino, Giovanni La Mura, Stefano...      7.0   11.0     5.0
# 24  [Andrew W. Mayo, Charles D. Fortenbach, Dana R...     21.0   42.0     9.0
# 25  [Zac Bailey, Riddhi Bandyopadhyay, Shadia Habb...      5.0   13.0     0.0
# 26  [S.K.Maurya, A. Errehymy, Ksh. Newton Singh, G...     12.0   28.0     5.0
# 27             [S. Qutub, Y.N. Kalugina, M. Derouich]      7.0   12.0     1.0
# 28    [Yue Shao, Guo-Hong Du, Tian-Nuo Li, Xin Zhang]      4.0    8.0     0.0
# 29                     [S. A. Korotin, K. O. Kiselev]     11.0   14.0     4.0
# 30  [Jayant Murthy, J. Michael Shull, Marc Postman...     16.0   19.0     8.0
# 31    [S. R. Dhanush, A. Subramaniam, S. Subramanian]     13.0   18.0     2.0
# 32                       [Asim Ullah, Jameel-Un Nabi]     11.0   26.0     9.0
# 33                 [Vikram K. Jaiswal, Bożena Czerny]      9.0    9.0     2.0
# 34  [Istiak Akib, François Hammer, Yanbin Yang, Ma...      9.0    9.0     2.0
# 35  [Giorgio Savini, Peter Hargrave, Peter A.R. Ad...      9.0   24.0     4.0
# 36  [Conor A. Nixon, Natalie Carrasco, Christophe ...      5.0   75.0     1.0
# 37       [Sanya Gupta, Navin Sridhar, Lorenzo Sironi]     13.0   11.0     1.0
# 38  [Lily Whitler, Daniel P. Stark, Michael W. Top...     12.0   32.0     6.0
# 39                                  [Zaza N. Osmanov]      0.0    7.0     0.0
# 40  [Yun Zheng, Kun Xu, Donghai Zhao, Y.P. Jing, H...     11.0   16.0     1.0
# 41  [M. E. Molnar, R. Casini, P. Bryans, B. Berkey...      4.0   11.0     0.0
# 42  [u-Fu Shen, Yan Xu, Yi-Bo Wang, Xiu-Lin Huang,...     11.0   19.0     0.0
# 43  [Rohan Pattnaik, Jeyhan S. Kartaltepe, Clive B...     13.0   17.0     0.0
# 44  [Mengting Liu, Di Li, J. R. Dawson, Joel M. We...      6.0   13.0     2.0
# 45  [M.Rumenskikh, A.V.Taichenachev, I.F.Shaikhisl...      7.0   15.0     1.0
# 46  [Yuji He, Hailong Yuan, Zhongrui Bai, Mingkuan...      8.0   16.0     5.0
# 47                   [Apashanka Das, Biswajit Pandey]     15.0   27.0     0.0
# 48  [Jing Wang, Dong Yang, Xuchen Lin, Qifeng Huan...      8.0   15.0     2.0
# 49  [P. Penil, A. Domínguez, S. Buson, M. Ajello, ...      5.0   22.0     4.0
# 50  [Konstantin V. Getman, Oleg Kochukhov, Joe P. ...      9.0   25.0     3.0
# 51  [Alfredo Micera, Daniel Verscharen, Jesse T. C...      6.0   11.0     0.0
# 52  [Nicola Barbieri, Thejs Brinckmann, Stefano Ga...      9.0   15.0     3.0
# 53                          [Chris Fox, Paul Wiegert]      9.0    8.0     1.0
# 54                       [Amelia Carolina Sparavigna]      0.0   40.0     8.0
#
#                     pdf_link                               primary_subject  \
# 0   arxiv.org/pdf/2501.00089                      Astrophysics of Galaxies
# 1   arxiv.org/pdf/2501.00094           High Energy Astrophysical Phenomena
# 2   arxiv.org/pdf/2501.00104              Earth and Planetary Astrophysics
# 3   arxiv.org/pdf/2501.00134              Earth and Planetary Astrophysics
# 4   arxiv.org/pdf/2501.00153  Instrumentation and Methods for Astrophysics
# 5   arxiv.org/pdf/2501.00176                Solar and Stellar Astrophysics
# 6   arxiv.org/pdf/2501.00181                Solar and Stellar Astrophysics
# 7   arxiv.org/pdf/2501.00228        Cosmology and Nongalactic Astrophysics
# 8   arxiv.org/pdf/2501.00231                Solar and Stellar Astrophysics
# 9   arxiv.org/pdf/2501.00239           High Energy Astrophysical Phenomena
# 10  arxiv.org/pdf/2501.00240                Solar and Stellar Astrophysics
# 11  arxiv.org/pdf/2501.00255                Solar and Stellar Astrophysics
# 12  arxiv.org/pdf/2501.00294                Solar and Stellar Astrophysics
# 13  arxiv.org/pdf/2501.00295        Cosmology and Nongalactic Astrophysics
# 14  arxiv.org/pdf/2501.00301        Cosmology and Nongalactic Astrophysics
# 15  arxiv.org/pdf/2501.00311                      Astrophysics of Galaxies
# 16  arxiv.org/pdf/2501.00324                Solar and Stellar Astrophysics
# 17  arxiv.org/pdf/2501.00373                Solar and Stellar Astrophysics
# 18  arxiv.org/pdf/2501.00380                      Astrophysics of Galaxies
# 19  arxiv.org/pdf/2501.00431                      Astrophysics of Galaxies
# 20  arxiv.org/pdf/2501.00433                Solar and Stellar Astrophysics
# 21  arxiv.org/pdf/2501.00506                      Astrophysics of Galaxies
# 22  arxiv.org/pdf/2501.00544  Instrumentation and Methods for Astrophysics
# 23  arxiv.org/pdf/2501.00582           High Energy Astrophysical Phenomena
# 24  arxiv.org/pdf/2501.00609              Earth and Planetary Astrophysics
# 25  arxiv.org/pdf/2501.00676                Solar and Stellar Astrophysics
# 26  arxiv.org/pdf/2501.00735           High Energy Astrophysical Phenomena
# 27  arxiv.org/pdf/2501.00763                Solar and Stellar Astrophysics
# 28  arxiv.org/pdf/2501.00769        Cosmology and Nongalactic Astrophysics
# 29  arxiv.org/pdf/2501.00774                Solar and Stellar Astrophysics
# 30  arxiv.org/pdf/2501.00787                      Astrophysics of Galaxies
# 31  arxiv.org/pdf/2501.00788                      Astrophysics of Galaxies
# 32  arxiv.org/pdf/2501.00796                Solar and Stellar Astrophysics
# 33  arxiv.org/pdf/2501.00806                      Astrophysics of Galaxies
# 34  arxiv.org/pdf/2501.00870                      Astrophysics of Galaxies
# 35  arxiv.org/pdf/2501.00875  Instrumentation and Methods for Astrophysics
# 36  arxiv.org/pdf/2501.00971              Earth and Planetary Astrophysics
# 37  arxiv.org/pdf/2501.00979           High Energy Astrophysical Phenomena
# 38  arxiv.org/pdf/2501.00984                      Astrophysics of Galaxies
# 39  arxiv.org/pdf/2501.00985           High Energy Astrophysical Phenomena
# 40  arxiv.org/pdf/2501.00986                      Astrophysics of Galaxies
# 41  arxiv.org/pdf/2501.01009                Solar and Stellar Astrophysics
# 42  arxiv.org/pdf/2501.01035                      Astrophysics of Galaxies
# 43  arxiv.org/pdf/2501.01070  Instrumentation and Methods for Astrophysics
# 44  arxiv.org/pdf/2501.01074                      Astrophysics of Galaxies
# 45  arxiv.org/pdf/2501.01122              Earth and Planetary Astrophysics
# 46  arxiv.org/pdf/2501.01171                Solar and Stellar Astrophysics
# 47  arxiv.org/pdf/2501.01207                      Astrophysics of Galaxies
# 48  arxiv.org/pdf/2501.01289                      Astrophysics of Galaxies
# 49  arxiv.org/pdf/2501.01310           High Energy Astrophysical Phenomena
# 50  arxiv.org/pdf/2501.01321                Solar and Stellar Astrophysics
# 51  arxiv.org/pdf/2501.01331                Solar and Stellar Astrophysics
# 52  arxiv.org/pdf/2501.01369        Cosmology and Nongalactic Astrophysics
# 53  arxiv.org/pdf/2501.01387              Earth and Planetary Astrophysics
# 54  arxiv.org/pdf/2412.20407             History and Philosophy of Physics
#
#                                    secondary_subjects  \
# 0                                  [Machine Learning]
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   [Earth and Planetary Astrophysics, Geophysics,...
# 6   [Earth and Planetary Astrophysics, High Energy...
# 7   [High Energy Astrophysical Phenomena, General ...
# 8      [Instrumentation and Methods for Astrophysics]
# 9                                                None
# 10                         [Astrophysics of Galaxies]
# 11                    [Plasma Physics, Space Physics]
# 12                                               None
# 13              [High Energy Physics - Phenomenology]
# 14                                               None
# 15                                               None
# 16                                   [Atomic Physics]
# 17                         [Astrophysics of Galaxies]
# 18                                               None
# 19                                               None
# 20                         [Astrophysics of Galaxies]
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27  [Atomic Physics, Chemical Physics, Plasma Phys...
# 28  [General Relativity and Quantum Cosmology, Hig...
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                   [Nuclear Theory]
# 33              [High Energy Astrophysical Phenomena]
# 34                                               None
# 35                                           [Optics]
# 36  [Instrumentation and Methods for Astrophysics,...
# 37              [High Energy Physics - Phenomenology]
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                   [Solar and Stellar Astrophysics]
# 43                         [Astrophysics of Galaxies]
# 44                                               None
# 45                                    [Space Physics]
# 46                                               None
# 47           [Cosmology and Nongalactic Astrophysics]
# 48                                               None
# 49                                               None
# 50  [High Energy Astrophysical Phenomena, High Ene...
# 51                    [Plasma Physics, Space Physics]
# 52                                               None
# 53                                               None
# 54  [Solar and Stellar Astrophysics, Popular Physics]
#
#                                  submitted_journal  \
# 0                                     AAS Journals
# 1                                              ApJ
# 2                                              A&A
# 3                                             None
# 4                        The Astrophysical Journal
# 5                                             None
# 6                                             None
# 7                                             None
# 8                                             None
# 9                                             None
# 10                                            None
# 11                       The Astrophysical Journal
# 12                                            None
# 13                                            None
# 14                                            None
# 15                                            None
# 16                                            None
# 17                                            None
# 18                                             A&A
# 19                                            None
# 20                       The Astrophysical Journal
# 21                                     A&A Letters
# 22                                            None
# 23                                            None
# 24                                    AAS Journals
# 25                    ApJ letters on Dec 21st 2024
# 26                                            None
# 27                Astronomy & Astrophysics journal
# 28                                            None
# 29                                            None
# 30                                            None
# 31                                             ApJ
# 32                                            None
# 33                                            None
# 34                                            None
# 35                                Nature Astronomy
# 36                                            None
# 37                                            None
# 38                                            None
# 39                                            None
# 40                                             ApJ
# 41                                   Solar Physics
# 42                                            None
# 43                                             ApJ
# 44          Research in Astronomy and Astrophysics
# 45                                            None
# 46  The Astrophysical Journal (ApJ) on December 31
# 47                                            None
# 48                                            None
# 49                                            None
# 50                       The Astrophysical Journal
# 51                                            None
# 52                                            None
# 53                                            None
# 54                                            None
#
#                                     published_journal  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3   Modern astronomy: from the Early Universe to e...
# 4                                                None
# 5                              ApJ 959:23 (20pp) 2023
# 6                  Rev. Mod. Plasma Phys. 9, 1 (2025)
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Monthly Notices of the Royal Astronomical Soci...
# 15                                2024, ApJ, 977, 269
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32         Brazilian Journal of Physics, 52:13 (2022)
# 33                                               None
# 34                                               None
# 35                                               None
# 36  Chapter 15 of book: "Titan after Cassini-Huyge...
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
#
#                                              keywords  \
# 0                                     [Galaxies (573]
# 1   [Active galactic nuclei (16) – Blazars (164, B...
# 2                                 [Planetary systems]
# 3       [planets and satellites: terrestrial planets]
# 4                [Interdisciplinary astronomy(804) 1]
# 5                                                  []
# 6   [Electromotive field, Dynamo mechanism, Turbul...
# 7                                                  []
# 8   [techniques: image processing, sun: chromosphe...
# 9                                  [Gamma-ray bursts]
# 10                [Luminous blue variable stars (944]
# 11                                     [Reconnection]
# 12  [magnetohydrodynamics (MHD, waves, stars: chro...
# 13                                                 []
# 14  [thousands of galaxy candi- dates at redshift ...
# 15  [galaxies: active, quasars: absorption lines, ...
# 16  [Line: identification, Sun: abundances – Sun: ...
# 17  [Techniques : Interferometry – Infrared : CSE ...
# 18                                                 []
# 19  [Interstellar medium (847, Interstellar plasma...
# 20                                                 []
# 21  [dust, extinction – H iiregions – ISM: clouds ...
# 22  [we intend to match the AAS Facility names of ...
# 23  [gamma rays: galaxies, gamma-ray astronomy, hi...
# 24                                       [Exoplanets]
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                                                 []
# 29  [line formation, line proﬁles of stars, elemen...
# 30                      [Ultraviolet astronomy (1736]
# 31  [galaxies:) Magellanic Clouds, galaxies: star ...
# 32                                          [β-decay]
# 33  [giant planet formation – κ, mechanism – stabi...
# 34                                                 []
# 35                                        [Telescope]
# 36                                                 []
# 37  [capable of explaining the most dramatic astro...
# 38                            [Galaxy evolution (594]
# 39                                                 []
# 40                            [Galaxy evolution (594]
# 41                                           [Corona]
# 42  [moment of inertia, stellar evolutionary model...
# 43  [Convolutional Neural Network (251, Extragalac...
# 44                                                 []
# 45        [exoplanets, spectroscopy, magnetic fields]
# 46                  [Cataclysmic variable stars (203]
# 47                                                 []
# 48          [Galaxy evolution, interstellar medium 1]
# 49  [BL Lacertae objects, methods: data analysis, ...
# 50  [Pre-main sequence stars (1290, X-ray stars (1...
# 51  [Plasma Astrophysics, Solar wind, Space plasma...
# 52                                                 []
# 53  [planets and satellites: detection, methods: n...
# 54                                                 []
#
#                                          affiliations
# 0                                              [None]
# 1                            [None, None, None, None]
# 2   [None, None, None, None, None, None, None, Non...
# 3                                              [None]
# 4                      [None, None, None, None, None]
# 5   [None, None, None, None, None, None, None, Non...
# 6                                        [None, None]
# 7                [None, None, None, None, None, None]
# 8   [None, None, None, None, None, None, None, Non...
# 9                                              [None]
# 10               [None, None, None, None, None, None]
# 11  [[Department of Physics, Indian Institute of T...
# 12                                 [None, None, None]
# 13                           [None, None, None, None]
# 14                           [None, None, None, None]
# 15  [None, None, None, None, None, None, None, Non...
# 16                     [None, None, None, None, None]
# 17  [None, None, None, None, None, None, None, Non...
# 18  [[Institute of Astronomy and Astrophysics, Anq...
# 19               [None, None, None, None, None, None]
# 20  [None, None, None, None, None, None, None, Non...
# 21  [None, None, [Laboratory, Ahmedabad 380009, In...
# 22                           [None, None, None, None]
# 23               [None, None, None, None, None, None]
# 24         [None, None, None, None, None, None, None]
# 25  [[Institute for Astronomy, University of Hawai...
# 26  [None, [DepartmentofMathematicalandPhysicalSci...
# 27  [[Department, Faculty of Science, King Abdulaz...
# 28                           [None, None, None, None]
# 29                                       [None, None]
# 30  [None, None, None, None, None, None, None, Non...
# 31  [[Institute of Astrophysics, Bangalore, 560034...
# 32                                       [None, None]
# 33  [[Center for Theoretical Physics, Polish Acade...
# 34                     [None, None, None, None, None]
# 35  [[University College London, Gower Street, Lon...
# 36  [[Laboratory, NASA Goddard Space Flight Center...
# 37  [None, None, [University, 3009 Broadway, New Y...
# 38  [None, None, None, None, None, None, None, Non...
# 39                                             [None]
# 40         [None, None, None, None, None, None, None]
# 41                     [None, None, None, None, None]
# 42               [None, None, None, None, None, None]
# 43                                 [None, None, None]
# 44  [[Center for Astronomical Computing, Zhejiang ...
# 45                           [None, None, None, None]
# 46  [None, None, None, None, None, None, None, Non...
# 47  [[Department of Physics, Visva-Bharati Univers...
# 48  [None, None, None, None, None, None, None, Non...
# 49               [None, None, None, None, None, None]
# 50  [None, None, None, None, None, None, None, Non...
# 51                           [None, None, None, None]
# 52               [None, None, None, None, None, None]
# 53                                       [None, None]
# 54                                             [None]

# %%
def _extract_affiliations(self, pdf_reader, authors, max_pages=2):
        """
        Extract author affiliations from PDF by matching authors and their superscript markers
        Args:
            pdf_reader: PyPDF2.PdfReader object
            authors: List of author names
            max_pages: Maximum pages to search (usually in first 2 pages)
        Returns:
            list: List of affiliations corresponding to authors
        """
        affiliations = [None] * len(authors)
        try:
            # Only search first few pages where affiliations typically appear
            pages_to_search = min(max_pages, len(pdf_reader.pages))
            
            # Get text from first pages
            full_text = ""
            for page_num in range(pages_to_search):
                try:
                    page_text = pdf_reader.pages[page_num].extract_text()
                    full_text += page_text + "\n"
                except Exception as e:
                    print(f"Error reading page {page_num}: {str(e)}")
                    continue

            # Clean text
            full_text = re.sub(r'\s+', ' ', full_text)
            
            # Common patterns for affiliation sections
            section_markers = [
                'Abstract', 'Introduction', 'Keywords', 'I.', '1.', 
                'Methods', 'Background', 'Results'
            ]
            
            # Truncate text at first section marker
            for marker in section_markers:
                marker_pos = full_text.find(marker)
                if marker_pos != -1:
                    full_text = full_text[:marker_pos]
            
            # Extract affiliation block
            affiliation_patterns = [
                # Pattern for numbered affiliations
                r'(?:^|\n)(?:[1-9][0-9]?|[a-z])[).]\s*(.*?)(?=(?:[1-9][0-9]?|[a-z])[).]|$)',
                # Pattern for symbol-based affiliations
                r'(?:^|\n)(?:[†*§¶‡#])\s*(.*?)(?=(?:[†*§¶‡#])|$)',
                # Pattern for explicit affiliation markers
                r'(?i)(?:^|\n)(?:Affiliation|Address|Institution)[s:]?\s*(.*?)(?=\n|$)'
            ]
            
            # Find all affiliation blocks
            affiliation_blocks = []
            for pattern in affiliation_patterns:
                matches = re.finditer(pattern, full_text, re.MULTILINE | re.DOTALL)
                for match in matches:
                    affiliation_blocks.append(match.group(1).strip())
            
            # Process each author
            for i, author in enumerate(authors):
                try:
                    # Clean author name
                    clean_author = re.sub(r'[^\w\s]', '', author).strip()
                    
                    # Look for author pattern with superscript
                    author_patterns = [
                        # Number superscripts
                        rf"{clean_author}[\s{{}}]*?([1-9][0-9]?(?:,[1-9][0-9]?)*)",
                        # Symbol superscripts
                        rf"{clean_author}[\s{{}}]*?([†*§¶‡#](?:,[†*§¶‡#])*)",
                        # Letter superscripts
                        rf"{clean_author}[\s{{}}]*?([a-z](?:,[a-z])*)"
                    ]
                    
                    author_affiliations = []
                    for pattern in author_patterns:
                        matches = re.finditer(pattern, full_text, re.IGNORECASE)
                        for match in matches:
                            markers = match.group(1).split(',')
                            for marker in markers:
                                marker = marker.strip()
                                # Convert marker to index
                                if marker.isdigit():
                                    idx = int(marker) - 1
                                elif marker.isalpha():
                                    idx = ord(marker.lower()) - ord('a')
                                else:
                                    # For symbols, find matching affiliation block
                                    for block in affiliation_blocks:
                                        if block.startswith(marker):
                                            author_affiliations.append(block)
                                            continue
                                    continue
                                
                                if 0 <= idx < len(affiliation_blocks):
                                    author_affiliations.append(affiliation_blocks[idx])
                    
                    if author_affiliations:
                        affiliations[i] = list(set(author_affiliations))  # Remove duplicates
                    
                    # Fallback: If no superscript found, look for nearby affiliation
                    if not affiliations[i]:
                        author_pos = full_text.find(clean_author)
                        if author_pos != -1:
                            # Look for affiliation in next 200 characters
                            nearby_text = full_text[author_pos:author_pos + 200]
                            for block in affiliation_blocks:
                                if block in nearby_text:
                                    affiliations[i] = [block]
                                    break
                
                except Exception as e:
                    print(f"Error processing author {author}: {str(e)}")
                    continue
            
            return affiliations
            
        except Exception as e:
            print(f"Error in affiliation extraction: {str(e)}")
            return [None] * len(authors)
