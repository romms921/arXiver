# %% [markdown]
# # arXivr

# %% [markdown]
# ###
# ### arXiv metadata storage and statistics retriver
#
# #### Features:
# * Check the daily releases of the Astrophysics section of the arXive
# * Retrive metadata of the publications including authors, affiliations, etc
# * Run an LLM api to create a one line summary of the publication abstract
# * Store all this infomation as a csv retriving statistics such as highest publishing authors/universities
# * Create a column of keywords relating to the subject matter of the publication
# * Get notified everytime a publication with your specific input keyword appears
# * Automate VS Code running the code to do this every day

# %%
import pandas as pd
import numpy as np
import urllib.request as libreq
from groq import Groq
import xml.etree.ElementTree as ET
from IPython.display import display, Latex
from scholarly import ProxyGenerator, scholarly
import certifi
import os

os.environ['SSL_CERT_FILE'] = certifi.where()

pg = ProxyGenerator()
pg.FreeProxies()
# Out:
# True

# %%
query = 'search_query=cat:astro-ph*+AND+submittedDate:[20241224+TO+20241225]&start=0&max_results=5&sortBy=submittedDate&sortOrder=ascending'
base_url = 'http://export.arxiv.org/api/query?'

with libreq.urlopen(base_url + query) as url:
    r = url.read()
print(r)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<feed xmlns="http://www.w3.org/2005/Atom">\n  <link href="http://arxiv.org/api/query?search_query%3Dcat%3Aastro-ph%2A%20AND%20submittedDate%3A%5B20241224%20TO%2020241225%5D%26id_list%3D%26start%3D0%26max_results%3D5" rel="self" type="application/atom+xml"/>\n  <title type="html">ArXiv Query: search_query=cat:astro-ph* AND submittedDate:[20241224 TO 20241225]&amp;id_list=&amp;start=0&amp;max_results=5</title>\n  <id>http://arxiv.org/api/uLiwtc/WLiRO0ArARC0DwGb29PY</id>\n  <updated>2024-12-26T00:00:00-05:00</updated>\n  <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">23</opensearch:totalResults>\n  <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>\n  <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">5</opensearch:itemsPerPage>\n  <entry>\n    <id>http://arxiv.org/abs/2412.18098v1</id>\n    <updated>2024-12-24T02:15:19Z</updated>\n    <published>2024-12-24T02:15:19Z</published>\n    <title>Bar instability and formation timescale across Toomre\'s $Q$ parameter\n  and central mass concentration: slow bar formation or true stability</title>\n    <summary>  We investigate the bar formation process using $N$-body simulations across\nthe Toomre\'s parameter $Q_{min}$ and central mass concentration (CMC), focusing\nprincipally on the formation timescale. Of importance is that, as suggested by\ncosmological simulations, disk galaxies have limited time of $\\sim 8$ Gyr in\nthe Universe timeline to evolve secularly, starting when they became physically\nand kinematically steady to prompt the bar instability. By incorporating this\ntime limit, bar-unstable disks are further sub-divided into those that\nestablish a bar before and after that time, namely the normal and the slowly\nbar-forming disks. Simulations demonstrate that evolutions of bar strengths and\nconfigurations of the slowly bar-forming and the bar-stable cases are nearly\nindistinguishable prior to $8$ Gyr, albeit dynamically distinct, while\ndifferences can be noticed afterwards. Differentiating them before $8$ Gyr is\npossible by identifying the proto-bar, a signature of bar development visible\nin kinematical maps such as the Fourier spectrogram and the angular velocity\nfield, which emerges in the former group $1-2$ Gyr before the fully developed\nbar, whereas it is absent in the latter group until $8$ Gyr and such bar-stable\ndisk remains unbarred until at least $10$ Gyr. In addition, we find complicated\ninterplays between $Q_{min}$ and CMC in regulating the bar formation. Firstly,\ndisk stabilization requires both high $Q_{min}$ and CMC. Either high $Q_{min}$\nor high CMC only results in slow bar formation. Secondly, some hot disks can\nform a bar more rapidly than the colder ones in a specific range of $Q_{min}$\nand CMC.\n</summary>\n    <author>\n      <name>Tirawut Worrakitpoonpon</name>\n    </author>\n    <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">18 pages, 9 figures, 1 table, accepted for publication in ApJ</arxiv:comment>\n    <link href="http://arxiv.org/abs/2412.18098v1" rel="alternate" type="text/html"/>\n    <link title="pdf" href="http://arxiv.org/pdf/2412.18098v1" rel="related" type="application/pdf"/>\n    <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="astro-ph.GA" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="astro-ph.GA" scheme="http://arxiv.org/schemas/atom"/>\n  </entry>\n  <entry>\n    <id>http://arxiv.org/abs/2412.18146v1</id>\n    <updated>2024-12-24T04:04:30Z</updated>\n    <published>2024-12-24T04:04:30Z</published>\n    <title>Exploring variation of double-peak broad-line profile in strongly\n  variable AGNs</title>\n    <summary>  The geometry and kinematics of the broad-line region (BLR) in AGNs are still\nunclear, which is crucial for studying the physics and evolution of\nsupermassive black holes (SMBHs) and AGNs. The broad-li ...

# %%
# Parse the XML content
root = ET.fromstring(r)

# Function to print the XML in a readable format
def print_readable_xml(element, indent=""):
    for child in element:
        print(f"{indent}{child.tag}: {child.text.strip() if child.text else ''}")
        print_readable_xml(child, indent + "  ")

# Print the XML content in a readable format
print_readable_xml(root)
# Out:
# {http://www.w3.org/2005/Atom}link:
# {http://www.w3.org/2005/Atom}title: ArXiv Query: search_query=cat:astro-ph* AND submittedDate:[20241224 TO 20241225]&id_list=&start=0&max_results=5
# {http://www.w3.org/2005/Atom}id: http://arxiv.org/api/uLiwtc/WLiRO0ArARC0DwGb29PY
# {http://www.w3.org/2005/Atom}updated: 2024-12-26T00:00:00-05:00
# {http://a9.com/-/spec/opensearch/1.1/}totalResults: 23
# {http://a9.com/-/spec/opensearch/1.1/}startIndex: 0
# {http://a9.com/-/spec/opensearch/1.1/}itemsPerPage: 5
# {http://www.w3.org/2005/Atom}entry:
#   {http://www.w3.org/2005/Atom}id: http://arxiv.org/abs/2412.18098v1
#   {http://www.w3.org/2005/Atom}updated: 2024-12-24T02:15:19Z
#   {http://www.w3.org/2005/Atom}published: 2024-12-24T02:15:19Z
#   {http://www.w3.org/2005/Atom}title: Bar instability and formation timescale across Toomre's $Q$ parameter
#   and central mass concentration: slow bar formation or true stability
#   {http://www.w3.org/2005/Atom}summary: We investigate the bar formation process using $N$-body simulations across
# the Toomre's parameter $Q_{min}$ and central mass concentration (CMC), focusing
# principally on the formation timescale. Of importance is that, as suggested by
# cosmological simulations, disk galaxies have limited time of $\sim 8$ Gyr in
# the Universe timeline to evolve secularly, starting when they became physically
# and kinematically steady to prompt the bar instability. By incorporating this
# time limit, bar-unstable disks are further sub-divided into those that
# establish a bar before and after that time, namely the normal and the slowly
# bar-forming disks. Simulations demonstrate that evolutions of bar strengths and
# configurations of the slowly bar-forming and the bar-stable cases are nearly
# indistinguishable prior to $8$ Gyr, albeit dynamically distinct, while
# differences can be noticed afterwards. Differentiating them before $8$ Gyr is
# possible by identifying the proto-bar, a signature of bar development visible
# in kinematical maps such as the Fourier spectrogram and the angular velocity
# field, which emerges in the former group $1-2$ Gyr before the fully developed
# bar, whereas it is absent in the latter group until $8$ Gyr and such bar-stable
# disk remains unbarred until at least $10$ Gyr. In addition, we find complicated
# interplays between $Q_{min}$ and CMC in regulating the bar formation. Firstly,
# disk stabilization requires both high $Q_{min}$ and CMC. Either high $Q_{min}$
# or high CMC only results in slow bar formation. Secondly, some hot disks can
# form a bar more rapidly than the colder ones in a specific range of $Q_{min}$
# and CMC.
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Tirawut Worrakitpoonpon
#   {http://arxiv.org/schemas/atom}comment: 18 pages, 9 figures, 1 table, accepted for publication in ApJ
#   {http://www.w3.org/2005/Atom}link:
#   {http://www.w3.org/2005/Atom}link:
#   {http://arxiv.org/schemas/atom}primary_category:
#   {http://www.w3.org/2005/Atom}category:
# {http://www.w3.org/2005/Atom}entry:
#   {http://www.w3.org/2005/Atom}id: http://arxiv.org/abs/2412.18146v1
#   {http://www.w3.org/2005/Atom}updated: 2024-12-24T04:04:30Z
#   {http://www.w3.org/2005/Atom}published: 2024-12-24T04:04:30Z
#   {http://www.w3.org/2005/Atom}title: Exploring variation of double-peak broad-line profile in strongly
#   variable AGNs
#   {http://www.w3.org/2005/Atom}summary: The geometry and kinematics of the broad-line region (BLR) in AGNs are still
# unclear, which is crucial for studying the physics and evolution of
# supermassive black holes (SMBHs) and AGNs. The broad-line profile provides
# valuable information on BLR geometry and kinematics. In this work, we explore
# the evolution of line profiles in variable AGNs based on the BLR model of
# Czerny \& Hryniewicz, where the BLR is driven by the radiation pressure acting
# on dust at the surface layers of the accretion disk. The line profiles in the
# low-Eddington-ratio regime show a double-peak profile, which will become a
# single peak at high Eddington ratios. The high metallicity of $Z\gtrsim
# 5Z_{\odot}$ is required to reproduce the observational anti-correlation between
# the peak separation of broad lines and the Eddington ratio for a sample of
# AGNs. For the broad lines in variable AGNs, it will take several years to
# several decades to change their line profile if the disk luminosity suffers
# strong variation in a much shorter timescale. More monitoring of the broad line
# and continuum in strongly variable AGNs can shed special light on BLR physics.
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Jiancheng Wu
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Qingwen Wu
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Kaixing Lu
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Xinwu Cao
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Xiangli Lei
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Mengye Wang
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Xiao Fan
#   {http://arxiv.org/schemas/atom}comment: ApJ accepted
#   {http://www.w3.org/2005/Atom}link:
#   {http://www.w3.org/2005/Atom}link:
#   {http://arxiv.org/schemas/atom}primary_category:
#   {http://www.w3.org/2005/Atom}category:
#   {http://www.w3.org/2005/Atom}category:
# {http://www.w3.org/2005/Atom}entry:
#   {http://www.w3.org/2005/Atom}id: http://arxiv.org/abs/2412.18152v1
#   {http://www.w3.org/2005/Atom}updated: 2024-12-24T04:10:49Z
#   {http://www.w3.org/2005/Atom}published: 2024-12-24T04:10:49Z
#   {http://www.w3.org/2005/Atom}title: Extremely luminous optical afterglow of a distant and energetic
#   gamma-ray burst GRB 230204B
#   {http://www.w3.org/2005/Atom}summary: Robotic telescope networks play an important role in capturing early and
# bright optical afterglows, providing critical insights into the energetics and
# emission mechanisms of GRBs. In this study, we analyze GRB 230204B, an
# exceptionally energetic and multi-pulsed long GRB, detected by the Fermi GBM
# and MAXI detectors, with an isotropic equivalent gamma-ray energy exceeding
# 10$^{54}$ erg. Time-resolved spectral analysis reveals a transition in the
# prompt emission from hard (sub-photospheric dominated) spectra during early
# pulses to softer (synchrotron radiation dominated) spectra in later pulses,
# indicative of a hybrid jet composition. We report the discovery and
# characterization of the optical afterglow using the MASTER and BOOTES robotic
# telescope networks, alongside long-term radio observations extending to 335
# days post-burst with the ATCA. At ~1.3 ks post-burst, the optical luminosity
# was exceptionally high, surpassing even other bright GRBs, such as GRB 221009A
# (the ``BOAT"). Multi-wavelength modeling, incorporating data from MASTER,
# BOOTES, DOT, Swift/XRT, and radio observations, was conducted using an external
# ISM forward-shock top-hat jet model with afterglowpy. The results reveal a
# narrow and highly collimated jet with a circumburst density of n$_{0}$ ~ 28.12
# cm$^{-3}$, kinetic energy E$_{K}$ ~ 4.18 x 10$^{55}$ erg, and a relatively low
# value of $\epsilon_{B}$ = 2.14 x 10$^{-6}$, indicating shock-compression of the
# magnetic field in the surrounding interstellar medium. We constrained a low
# radiative efficiency of ~ 4.3 %. This study highlights the indispensable
# contribution of robotic networks to early afterglow observations and advances
# our understanding of GRB 230204B unique characteristics and underlying jet
# physics.
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Rahul Gupta
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Judith Racusin
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Vladimir Lipunov
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Y. -D. Hu
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Ashna Gulati
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Alberto J. Castro-Tirado
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Tara Murphy
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Motoko Serino
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Kirill Zhirkov
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: S. Shilling
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Samantha R. Oates
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: James K. Leung
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: T. Parsotan
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Amit K. Ror
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Shashi B. Pandey
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: S. Iyyani
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: V. Sharma
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: A. Aryan
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Jin-Ming Bai
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Pavel Balanutsa
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: David Buckley
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: María D. Caballero-García
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: I. M. Carrasco-García
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: A. Castellón
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Sebastián Castillo
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Chen-Zhou Cui
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Yu-Feng Fan
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Emilio Fernández-García
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Guillermo García-Segura
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Maria Gritsevich
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Sergiy Guziy
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: David Hiriart
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: William H. Lee
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Soomin Jeong
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Carlos Jesus Pérez del Pulgar
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Ignacio Olivares
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: I. H. Park
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Ignacio Pérez-García
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: S. Razzaque
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Rubén Sánchez-Ramírez
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Nataly Tyurina
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Vladislav Topolev
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Chuan-Jun Wang
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Si-Yu Wu
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Yu-Xin Xin
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Ding-Rong Xiong
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Xiao-Hong Zhao
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Jirong Mao
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Bao-Li Lun
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Ye Kai
#   {http://arxiv.org/schemas/atom}comment: 27 pages, 12 figures, 8 tables, submitted
#   {http://www.w3.org/2005/Atom}link:
#   {http://www.w3.org/2005/Atom}link:
#   {http://arxiv.org/schemas/atom}primary_category:
#   {http://www.w3.org/2005/Atom}category:
# {http://www.w3.org/2005/Atom}entry:
#   {http://www.w3.org/2005/Atom}id: http://arxiv.org/abs/2412.18167v1
#   {http://www.w3.org/2005/Atom}updated: 2024-12-24T04:59:24Z
#   {http://www.w3.org/2005/Atom}published: 2024-12-24T04:59:24Z
#   {http://www.w3.org/2005/Atom}title: Dependence of the estimated electric potential in thunderstorms observed
#   at GRAPES-3 on the hadronic interaction generators used in simulations
#   {http://www.w3.org/2005/Atom}summary: A potential difference of 1.3 Giga-Volts (GV) was inferred across a
# thundercloud using data from the GRAPES-3 muon telescope (G3MT). This was the
# first-ever estimation of gigavolt potential in thunderstorms, confirming
# prediction of C.T.R. Wilson almost a century ago. To infer the thundercloud
# potential required acceleration of muons in atmospheric electric field to be
# incorporated in the Monte Carlo simulation software CORSIKA. The G3MT records
# over 4 billion muons daily that are grouped into 169 directions covering 2.3 sr
# sky. This enabled changes as small as 0.1% in the muon flux on minute
# timescale, caused by thunderstorms to be accurately measured. But that requires
# high statistics simulation of muon fluxes in thunderstorm electric fields. The
# CORSIKA offers a choice of several generators for low- (FLUKA, GHEISHA, and
# UrQMD) and high-energy (SIBYLL, EPOS-LHC, and QGSJETII) hadronic interactions.
# Since it is unclear which combination of the low- and high-energy generators
# provides the correct description of hadronic interactions, all nine
# combinations of generators were explored, and they yielded thundercloud
# potentials ranging from 1.3 GV to 1.6 GV for the event recorded on 1 December
# 2014. The result of SIBYLL-FLUKA combination yielded the lowest electric
# potential of 1.3 GV was reported. Furthermore, another seven major thunderstorm
# events recorded between April 2011 and December 2020 were analyzed to measure
# the dependence of their thundercloud potential on the hadronic interaction
# generators. It is observed that the low-energy generators produce larger
# variation ($\sim$14%) in thundercloud potential than the high-energy generators
# ($\sim$8%). This probably reflects the fact that the GeV muons are
# predominantly produced in low-energy ($<$80 GeV) interactions, which
# effectively magnifies the differences in the meson production cross-sections
# among the low-energy generators.
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: B. Hariharan
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: S. K. Gupta
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Y. Hayashi
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: P. Jagadeesan
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: A. Jain
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: S. Kawakami
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: H. Kojima
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: P. K. Mohanty
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Y. Muraki
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: P. K. Nayak
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: A. Oshima
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: M. Rameez
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: K. Ramesh
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: L. V. Reddy
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: S. Shibata
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: M. Zuberi
#   {http://www.w3.org/2005/Atom}link:
#   {http://www.w3.org/2005/Atom}link:
#   {http://arxiv.org/schemas/atom}primary_category:
#   {http://www.w3.org/2005/Atom}category:
# {http://www.w3.org/2005/Atom}entry:
#   {http://www.w3.org/2005/Atom}id: http://arxiv.org/abs/2412.18203v1
#   {http://www.w3.org/2005/Atom}updated: 2024-12-24T06:17:49Z
#   {http://www.w3.org/2005/Atom}published: 2024-12-24T06:17:49Z
#   {http://www.w3.org/2005/Atom}title: Comparison of Relative Magnetic Helicity Flux Calculation Results Based
#   on the Line-of-Sight Magnetograms of ASO-S/FMG and SDO/HMI
#   {http://www.w3.org/2005/Atom}summary: Magnetic helicity is a key geometrical parameter to describe the structure
# and evolution of solar coronal magnetic fields. The accumulation of magnetic
# helicity is correlated with the non-potential magnetic field energy, which is
# released in the solar eruptions. Moreover, the relative magnetic helicity
# fluxes can be estimated only relying on the line-of-sight magnetic field (e.g.,
# Demoulin and Berger Sol. Phys. 215, 203, 2003). The payload Full-disk
# MagnetoGraph (FMG) on the Advanced Space-based Solar Observatory (ASO-S)
# currently has been supplying the continuous evolution of line-of-sight
# magnetograms for the solar active regions, which can be used to estimate the
# magnetic helicity flux. In this study, we useeight hours line-of-sight
# magnetograms of NOAA 13273, when at which the Sun-Earth direction speed of the
# satellite is zero to avoid the oscillation of the magnetic field caused by the
# Doppler effect on polarization measurements. We obtain the helicity flux by
# applying Fast Fourier Transforms (FFT) and local correlation tracking (LCT)
# methods to obtain the horizontal vector potential field and the motions of the
# ine-sf-sight polarities. We also compare the helicity flux derived using data
# from the Heliosesmic and Magnetic Imager (HMI) on board the Solar Dynamics
# Observatory (SDO) and the same method. It is found that the flux has the same
# sign and the correlation between measurements is 0.98. The difference of the
# absolute magnetic helicity normalized to themagnetic flux is less than 4%. This
# comparison demonstrates the reliability of ASO-S/FMG data and that it can be
# reliably used in future studies
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Shangbin Yang
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Suo Liu
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Jiangtao Su
#   {http://www.w3.org/2005/Atom}author:
#     {http://www.w3.org/2005/Atom}name: Yuanyong Deng
#   {http://arxiv.org/schemas/atom}comment: accepted by Solar Physics
#   {http://www.w3.org/2005/Atom}link:
#   {http://www.w3.org/2005/Atom}link:
#   {http://arxiv.org/schemas/atom}primary_category:
#   {http://www.w3.org/2005/Atom}category:

# %%
# Extract the abstract from the XML content
namespace = {'atom': 'http://www.w3.org/2005/Atom'}
abstract = root.find('.//atom:entry/atom:summary', namespace).text.strip()

print(abstract)
# Out:
# We investigate the bar formation process using $N$-body simulations across
# the Toomre's parameter $Q_{min}$ and central mass concentration (CMC), focusing
# principally on the formation timescale. Of importance is that, as suggested by
# cosmological simulations, disk galaxies have limited time of $\sim 8$ Gyr in
# the Universe timeline to evolve secularly, starting when they became physically
# and kinematically steady to prompt the bar instability. By incorporating this
# time limit, bar-unstable disks are further sub-divided into those that
# establish a bar before and after that time, namely the normal and the slowly
# bar-forming disks. Simulations demonstrate that evolutions of bar strengths and
# configurations of the slowly bar-forming and the bar-stable cases are nearly
# indistinguishable prior to $8$ Gyr, albeit dynamically distinct, while
# differences can be noticed afterwards. Differentiating them before $8$ Gyr is
# possible by identifying the proto-bar, a signature of bar development visible
# in kinematical maps such as the Fourier spectrogram and the angular velocity
# field, which emerges in the former group $1-2$ Gyr before the fully developed
# bar, whereas it is absent in the latter group until $8$ Gyr and such bar-stable
# disk remains unbarred until at least $10$ Gyr. In addition, we find complicated
# interplays between $Q_{min}$ and CMC in regulating the bar formation. Firstly,
# disk stabilization requires both high $Q_{min}$ and CMC. Either high $Q_{min}$
# or high CMC only results in slow bar formation. Secondly, some hot disks can
# form a bar more rapidly than the colder ones in a specific range of $Q_{min}$
# and CMC.

# %%
# Display the abstract with LaTeX interpretation
display(Latex(abstract))
# Out:
# We investigate the bar formation process using $N$-body simulations across
# the Toomre's parameter $Q_{min}$ and central mass concentration (CMC), focusing
# principally on the formation timescale. Of importance is that, as suggested by
# cosmological simulations, disk galaxies have limited time of $\sim 8$ Gyr in
# the Universe timeline to evolve secularly, starting when they became physically
# and kinematically steady to prompt the bar instability. By incorporating this
# time limit, bar-unstable disks are further sub-divided into those that
# establish a bar before and after that time, namely the normal and the slowly
# bar-forming disks. Simulations demonstrate that evolutions of bar strengths and
# configurations of the slowly bar-forming and the bar-stable cases are nearly
# indistinguishable prior to $8$ Gyr, albeit dynamically distinct, while
# differences can be noticed afterwards. Differentiating them before $8$ Gyr is
# possible by identifying the proto-bar, a signature of bar development visible
# in kinematical maps such as the Fourier spectrogram and the angular velocity
# field, which emerges in the former group $1-2$ Gyr before the fully developed
# bar, whereas it is absent in the latter group until $8$ Gyr and such bar-stable
# disk remains unbarred until at least $10$ Gyr. In addition, we find complicated
# interplays between $Q_{min}$ and CMC in regulating the bar formation. Firstly,
# disk stabilization requires both high $Q_{min}$ and CMC. Either high $Q_{min}$
# or high CMC only results in slow bar formation. Secondly, some hot disks can
# form a bar more rapidly than the colder ones in a specific range of $Q_{min}$
# and CMC.

# %%
data = pd.DataFrame(columns=['title', 'abstract', 'authors', 'published', 'link'])

entries = []
for entry in root.findall('atom:entry', namespace):
    title = entry.find('atom:title', namespace).text.strip()
    abstract = entry.find('atom:summary', namespace).text.strip()
    authors = ', '.join([author.find('atom:name', namespace).text.strip() for author in entry.findall('atom:author', namespace)])
    published = entry.find('atom:published', namespace).text.strip()
    link = entry.find('atom:link[@rel="alternate"]', namespace).attrib['href']
    
    entries.append({'title': title, 'abstract': abstract, 'authors': authors, 'published': published, 'link': link})

data = pd.concat([data, pd.DataFrame(entries)], ignore_index=True)

print(data)
# Out:
#                                                title  \
# 0  Bar instability and formation timescale across...
# 1  Exploring variation of double-peak broad-line ...
# 2  Extremely luminous optical afterglow of a dist...
# 3  Dependence of the estimated electric potential...
# 4  Comparison of Relative Magnetic Helicity Flux ...
#
#                                             abstract  \
# 0  We investigate the bar formation process using...
# 1  The geometry and kinematics of the broad-line ...
# 2  Robotic telescope networks play an important r...
# 3  A potential difference of 1.3 Giga-Volts (GV) ...
# 4  Magnetic helicity is a key geometrical paramet...
#
#                                              authors             published  \
# 0                            Tirawut Worrakitpoonpon  2024-12-24T02:15:19Z
# 1  Jiancheng Wu, Qingwen Wu, Kaixing Lu, Xinwu Ca...  2024-12-24T04:04:30Z
# 2  Rahul Gupta, Judith Racusin, Vladimir Lipunov,...  2024-12-24T04:10:49Z
# 3  B. Hariharan, S. K. Gupta, Y. Hayashi, P. Jaga...  2024-12-24T04:59:24Z
# 4  Shangbin Yang, Suo Liu, Jiangtao Su, Yuanyong ...  2024-12-24T06:17:49Z
#
#                                 link
# 0  http://arxiv.org/abs/2412.18098v1
# 1  http://arxiv.org/abs/2412.18146v1
# 2  http://arxiv.org/abs/2412.18152v1
# 3  http://arxiv.org/abs/2412.18167v1
# 4  http://arxiv.org/abs/2412.18203v1

# %%
data
# Out:
#                                                title  \
# 0  Bar instability and formation timescale across...
# 1  Exploring variation of double-peak broad-line ...
# 2  Extremely luminous optical afterglow of a dist...
# 3  Dependence of the estimated electric potential...
# 4  Comparison of Relative Magnetic Helicity Flux ...
#
#                                             abstract  \
# 0  We investigate the bar formation process using...
# 1  The geometry and kinematics of the broad-line ...
# 2  Robotic telescope networks play an important r...
# 3  A potential difference of 1.3 Giga-Volts (GV) ...
# 4  Magnetic helicity is a key geometrical paramet...
#
#                                              authors             published  \
# 0                            Tirawut Worrakitpoonpon  2024-12-24T02:15:19Z
# 1  Jiancheng Wu, Qingwen Wu, Kaixing Lu, Xinwu Ca...  2024-12-24T04:04:30Z
# 2  Rahul Gupta, Judith Racusin, Vladimir Lipunov,...  2024-12-24T04:10:49Z
# 3  B. Hariharan, S. K. Gupta, Y. Hayashi, P. Jaga...  2024-12-24T04:59:24Z
# 4  Shangbin Yang, Suo Liu, Jiangtao Su, Yuanyong ...  2024-12-24T06:17:49Z
#
#                                 link
# 0  http://arxiv.org/abs/2412.18098v1
# 1  http://arxiv.org/abs/2412.18146v1
# 2  http://arxiv.org/abs/2412.18152v1
# 3  http://arxiv.org/abs/2412.18167v1
# 4  http://arxiv.org/abs/2412.18203v1

# %%
content = "Abstract:" + data.loc[0, 'abstract']

# %%
client_summary = Groq(
    api_key="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",
)

summary = client_summary.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You need to provide a one line summary of the provided abstract. You should not fabricate any information. Please do not include any other text other than the requested content.",
        },
        
        {
            "role": "user",
            "content": content,
        }
    ],
    model="llama3-8b-8192",
    stream=False,
)

print(summary.choices[0].message.content)
# Out:
# A study using N-body simulations found that the formation timescale of bars in disk galaxies is limited to approximately 8 billion years, with two types of bars forming before and after this time, and that the interaction between Toomre's parameter and central mass concentration regulates bar formation.

# %%
title = "Title:" + data.loc[0, 'title']

# %%
client_keywords = Groq(
    api_key="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",
)

keywords = client_keywords.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You need to pick out 2-3 keywords from the provided title that are relevnt to the topic of the paper. Please do not include any other text explaining what is the response other than the requested content itself. No need to number the keywords.",
        },
        
        {
            "role": "user",
            "content": title,
        }
    ],
    model="llama3-8b-8192",
    stream=False,
)

print(keywords.choices[0].message.content)
# Out:
# Toomre's Q, bar formation, mass concentration

# %%
data['summary'] = summary.choices[0].message.content
data['keywords'] = keywords.choices[0].message.content

# %%
data
# Out:
#                                                title  \
# 0  Bar instability and formation timescale across...
# 1  Exploring variation of double-peak broad-line ...
# 2  Extremely luminous optical afterglow of a dist...
# 3  Dependence of the estimated electric potential...
# 4  Comparison of Relative Magnetic Helicity Flux ...
#
#                                             abstract  \
# 0  We investigate the bar formation process using...
# 1  The geometry and kinematics of the broad-line ...
# 2  Robotic telescope networks play an important r...
# 3  A potential difference of 1.3 Giga-Volts (GV) ...
# 4  Magnetic helicity is a key geometrical paramet...
#
#                                              authors             published  \
# 0                            Tirawut Worrakitpoonpon  2024-12-24T02:15:19Z
# 1  Jiancheng Wu, Qingwen Wu, Kaixing Lu, Xinwu Ca...  2024-12-24T04:04:30Z
# 2  Rahul Gupta, Judith Racusin, Vladimir Lipunov,...  2024-12-24T04:10:49Z
# 3  B. Hariharan, S. K. Gupta, Y. Hayashi, P. Jaga...  2024-12-24T04:59:24Z
# 4  Shangbin Yang, Suo Liu, Jiangtao Su, Yuanyong ...  2024-12-24T06:17:49Z
#
#                                 link  \
# 0  http://arxiv.org/abs/2412.18098v1
# 1  http://arxiv.org/abs/2412.18146v1
# 2  http://arxiv.org/abs/2412.18152v1
# 3  http://arxiv.org/abs/2412.18167v1
# 4  http://arxiv.org/abs/2412.18203v1
#
#                                              summary  \
# 0  A study using N-body simulations found that th...
# 1  A study using N-body simulations found that th...
# 2  A study using N-body simulations found that th...
# 3  A study using N-body simulations found that th...
# 4  A study using N-body simulations found that th...
#
#                                         keywords
# 0  Toomre's Q, bar formation, mass concentration
# 1  Toomre's Q, bar formation, mass concentration
# 2  Toomre's Q, bar formation, mass concentration
# 3  Toomre's Q, bar formation, mass concentration
# 4  Toomre's Q, bar formation, mass concentration

# %%
data['published'] = pd.to_datetime(data['published'])
data['published'] = data['published'].dt.date

# %%
data
# Out:
#                                                title  \
# 0  Bar instability and formation timescale across...
# 1  Exploring variation of double-peak broad-line ...
# 2  Extremely luminous optical afterglow of a dist...
# 3  Dependence of the estimated electric potential...
# 4  Comparison of Relative Magnetic Helicity Flux ...
#
#                                             abstract  \
# 0  We investigate the bar formation process using...
# 1  The geometry and kinematics of the broad-line ...
# 2  Robotic telescope networks play an important r...
# 3  A potential difference of 1.3 Giga-Volts (GV) ...
# 4  Magnetic helicity is a key geometrical paramet...
#
#                                              authors   published  \
# 0                            Tirawut Worrakitpoonpon  2024-12-24
# 1  Jiancheng Wu, Qingwen Wu, Kaixing Lu, Xinwu Ca...  2024-12-24
# 2  Rahul Gupta, Judith Racusin, Vladimir Lipunov,...  2024-12-24
# 3  B. Hariharan, S. K. Gupta, Y. Hayashi, P. Jaga...  2024-12-24
# 4  Shangbin Yang, Suo Liu, Jiangtao Su, Yuanyong ...  2024-12-24
#
#                                 link  \
# 0  http://arxiv.org/abs/2412.18098v1
# 1  http://arxiv.org/abs/2412.18146v1
# 2  http://arxiv.org/abs/2412.18152v1
# 3  http://arxiv.org/abs/2412.18167v1
# 4  http://arxiv.org/abs/2412.18203v1
#
#                                              summary  \
# 0  A study using N-body simulations found that th...
# 1  A study using N-body simulations found that th...
# 2  A study using N-body simulations found that th...
# 3  A study using N-body simulations found that th...
# 4  A study using N-body simulations found that th...
#
#                                         keywords
# 0  Toomre's Q, bar formation, mass concentration
# 1  Toomre's Q, bar formation, mass concentration
# 2  Toomre's Q, bar formation, mass concentration
# 3  Toomre's Q, bar formation, mass concentration
# 4  Toomre's Q, bar formation, mass concentration

# %%
# Stats 
# Authors
authors = data['authors'].str.split(', ', expand=True).stack().value_counts()
authors
# Out:
# Tirawut Worrakitpoonpon    1
# Vladislav Topolev          1
# Bao-Li Lun                 1
# Jirong Mao                 1
# Xiao-Hong Zhao             1
#                           ..
# A. Aryan                   1
# V. Sharma                  1
# S. Iyyani                  1
# Shashi B. Pandey           1
# Yuanyong Deng              1
# Name: count, Length: 78, dtype: int64

# %%
print(authors.index[0])
# Out:
# Tirawut Worrakitpoonpon

# %%
# This needs to be done only once per session
scholarly.use_proxy(pg)

search_query = scholarly.search_author('Jia Wang')

# Retrieve all the details for the author
author = scholarly.fill(next(search_query))
scholarly.pprint(author)

# Get the author's affiliation
affiliation = author['affiliation']
# Out:
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 search_query = scholarly.search_author('Jia Wang')
#       6 # Retrieve all the details for the author
# ----> 7 author = scholarly.fill(next(search_query))
#       8 scholarly.pprint(author)
#      10 # Get the author's affiliation
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_scholarly.py:233, in _Scholarly.fill(self, object, sections, sortby, publication_limit)
#     231 if object['container_type'] == "Author":
#     232     author_parser = AuthorParser(self.__nav)
# --> 233     object = author_parser.fill(object, sections, sortby, publication_limit)
#     234     if object is False:
#     235         raise ValueError("Incorrect input")
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/author_parser.py:462, in AuthorParser.fill(self, author, sections, sortby, publication_limit)
#     460                 author['filled'].append(i)
#     461 except Exception as e:
# --> 462     raise(e)
#     464 return author
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/author_parser.py:454, in AuthorParser.fill(self, author, sections, sortby, publication_limit)
#     452     for i in self._sections:
#     453         if i not in author['filled']:
# --> 454             (getattr(self, f'_fill_{i}')(soup, author) if i != 'publications' else getattr(self, f'_fill_{i}')(soup, author, publication_limit, sortby_str))
#     455             author['filled'].append(i)
#     456 else:
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/author_parser.py:195, in AuthorParser._fill_publications(self, soup, author, publication_limit, sortby_str)
#     192     pubstart += _PAGESIZE
#     193     url = '{0}&cstart={1}&pagesize={2}'.format(
#     194         url_citations, pubstart, _PAGESIZE)
# --> 195     soup = self.nav._get_soup(url)
#     196 else:
#     197     break
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_navigator.py:239, in Navigator._get_soup(self, url)
#     237 def _get_soup(self, url: str) -> BeautifulSoup:
#     238     """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239     html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240     html = html.replace(u'\xa0', u' ')
#     241     res = BeautifulSoup(html, 'html.parser')
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_navigator.py:188, in Navigator._get_page(self, pagerequest, premium)
#     186 # If secondary proxy does not work, try again primary proxy.
#     187 if not premium:
# --> 188     return self._get_page(pagerequest, True)
#     189 else:
#     190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_navigator.py:190, in Navigator._get_page(self, pagerequest, premium)
#     188     return self._get_page(pagerequest, True)
#     189 else:
# --> 190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# MaxTriesExceededException: Cannot Fetch from Google Scholar.

# %%
position, affiliation = affiliation.split(', ')
print(position)
print(affiliation)
# Out:
# Lecturer
# Suranaree University of Technology
