# %%
import pandas as pd
import numpy as np
import urllib.request as libreq
from groq import Groq
import xml.etree.ElementTree as ET
from IPython.display import display, Latex
from scholarly import ProxyGenerator, scholarly
import certifi
import os
from datetime import datetime
from tqdm import tqdm
from dotenv import load_dotenv
load_dotenv()

os.environ['SSL_CERT_FILE'] = certifi.where()

# %%
todays_date = datetime.today().strftime('%Y%m%d')
print(todays_date)
yesterdays_date = (datetime.today() - pd.Timedelta(days=1)).strftime('%Y%m%d')
print(yesterdays_date)
todays_date = '20241231'
yesterdays_date = '20241230'
# Out:
# 20250102
# 20250101

# %%
query = 'search_query=cat:cs*+AND+submittedDate:[' + str(yesterdays_date) + '+TO+' + str(todays_date) + ']&start=0&max_results=50&sortBy=submittedDate&sortOrder=ascending'
print(query)
base_url = 'http://export.arxiv.org/api/query?'

with libreq.urlopen(base_url + query) as url:
    r = url.read()
print(r)

# Parse the XML content
root = ET.fromstring(r)

# Function to print the XML in a readable format
def print_readable_xml(element, indent=""):
    for child in element:
        print(f"{indent}{child.tag}: {child.text.strip() if child.text else ''}")
        print_readable_xml(child, indent + "  ")
# Out:
# search_query=cat:cs*+AND+submittedDate:[20241230+TO+20241231]&start=0&max_results=50&sortBy=submittedDate&sortOrder=ascending
# b'<?xml version="1.0" encoding="UTF-8"?>\n<feed xmlns="http://www.w3.org/2005/Atom">\n  <link href="http://arxiv.org/api/query?search_query%3Dcat%3Acs%2A%20AND%20submittedDate%3A%5B20241230%20TO%2020241231%5D%26id_list%3D%26start%3D0%26max_results%3D50" rel="self" type="application/atom+xml"/>\n  <title type="html">ArXiv Query: search_query=cat:cs* AND submittedDate:[20241230 TO 20241231]&amp;id_list=&amp;start=0&amp;max_results=50</title>\n  <id>http://arxiv.org/api/fbaYJmFEKyiMDiaDZQ3ckj88AEI</id>\n  <updated>2025-01-01T00:00:00-05:00</updated>\n  <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">243</opensearch:totalResults>\n  <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>\n  <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">50</opensearch:itemsPerPage>\n  <entry>\n    <id>http://arxiv.org/abs/2412.20630v1</id>\n    <updated>2024-12-30T00:39:57Z</updated>\n    <published>2024-12-30T00:39:57Z</published>\n    <title>Computing with D-Algebraic Sequences</title>\n    <summary>  A sequence is difference algebraic (or D-algebraic) if finitely many shifts\nof its general term satisfy a polynomial relationship; that is, they are the\ncoordinates of a generic point on an affine hypersurface. The corresponding\nequations are called algebraic difference equations (ADE). We show that\nsubsequences of D-algebraic sequences, indexed by arithmetic progressions,\nsatisfy ADEs of the same orders as the original sequences. Additionally, we\nprovide algorithms for operations with D-algebraic sequences and discuss the\ndifference-algebraic nature of holonomic and $C^2$-finite sequences.\n</summary>\n    <author>\n      <name>Bertrand Teguia Tabuguia</name>\n    </author>\n    <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">19 pages, 1 figure</arxiv:comment>\n    <link href="http://arxiv.org/abs/2412.20630v1" rel="alternate" type="text/html"/>\n    <link title="pdf" href="http://arxiv.org/pdf/2412.20630v1" rel="related" type="application/pdf"/>\n    <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="cs.NA" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="cs.SC" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="math.NA" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="12H10, 68W30 (primary), 39-04, 13Pxx (secondary)" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="I.1.2; G.4" scheme="http://arxiv.org/schemas/atom"/>\n  </entry>\n  <entry>\n    <id>http://arxiv.org/abs/2412.20631v1</id>\n    <updated>2024-12-30T00:40:35Z</updated>\n    <published>2024-12-30T00:40:35Z</published>\n    <title>Slow Perception: Let\'s Perceive Geometric Figures Step-by-step</title>\n    <summary>  Recently, "visual o1" began to enter people\'s vision, with expectations that\nthis slow-thinking design can solve visual reasoning tasks, especially\ngeometric math problems. However, the reality is that current LVLMs (Large\nVision Language Models) can hardly even accurately copy a geometric figure, let\nalone truly understand the complex inherent logic and spatial relationships\nwithin geometric shapes. We believe accurate copying (strong perception) is the\nfirst step to visual o1. Accordingly, we introduce the concept of "slow\nperception" (SP), which guides the model to gradually perceive basic point-line\ncombinations, as our humans, reconstruct complex geometric structures\nprogressively. There are two-fold stages in SP: a) perception decomposition.\nPerception is not instantaneous. In this stage, complex geometric figures are\nbroken down into basic simple units to unify geometry representation. b)\nperception flow, which acknowledges that accurately tracing a line is not an\neasy task. This stage aims to avoid "long visu ...

# %%
data = pd.DataFrame(columns=['title', 'abstract', 'authors', 'published', 'link', 'category'])
namespace = {'atom': 'http://www.w3.org/2005/Atom'}

entries = []
for entry in root.findall('atom:entry', namespace):
    title = entry.find('atom:title', namespace).text.strip()
    abstract = entry.find('atom:summary', namespace).text.strip()
    authors = ', '.join([author.find('atom:name', namespace).text.strip() for author in entry.findall('atom:author', namespace)])
    published = entry.find('atom:published', namespace).text.strip()
    link = entry.find('atom:link[@rel="alternate"]', namespace).attrib['href']
    category = entry.find('atom:category', namespace).attrib['term']
    
    entries.append({'title': title, 'abstract': abstract, 'authors': authors, 'published': published, 'link': link, 'category': category})

data = pd.concat([data, pd.DataFrame(entries)], ignore_index=True)

print(data)
# Out:
#                                                 title  \
# 0                Computing with D-Algebraic Sequences
# 1   Slow Perception: Let's Perceive Geometric Figu...
# 2   EVOLVE: Emotion and Visual Output Learning via...
# 3   Graph Neural Networks for Next-Generation-IoT:...
# 4   NetFlowGen: Leveraging Generative Pre-training...
# 5   Knowledge Editing for Large Language Model wit...
# 6   Predicting Long Term Sequential Policy Value U...
# 7   SafeSynthDP: Leveraging Large Language Models ...
# 8   Uncertainty Herding: One Active Learning Metho...
# 9   YOLO-UniOW: Efficient Universal Open-World Obj...
# 10  Enhancing Visual Representation for Text-based...
# 11  Latent Drifting in Diffusion Models for Counte...
# 12  Impact of Cognitive Load on Human Trust in Hyb...
# 13  Environmental and Economic Impact of I/O Devic...
# 14  Overcoming Class Imbalance: Unified GNN Learni...
# 15  Diffgrasp: Whole-Body Grasping Synthesis Guide...
# 16  Nanosatellite Design Considerations for a Miss...
# 17         Energy Efficient LoRaWAN in LEO Satellites
# 18  Enhancing Table Recognition with Vision LLMs: ...
# 19  SM3Det: A Unified Model for Multi-Modal Remote...
# 20         Recurrence-based Vanishing Point Detection
# 21  Highway Managed Lane Usage and Tolling for Mix...
# 22  Prototypical Distillation and Debiased Tuning ...
# 23  Two Birds with One Stone: Improving Rumor Dete...
# 24  Blockchain-Empowered Cyber-Secure Federated Le...
# 25  Improved ICNN-LSTM Model Classification Based ...
# 26  Align Attention Heads Before Merging Them: An ...
# 27  Attention-Driven Metapath Encoding in Heteroge...
# 28  Differentiable Convex Optimization Layers in N...
# 29  Online Adaptive Platoon Control for Connected ...
# 30  Learning to Rank Pre-trained Vision-Language M...
# 31  MarsSQE: Stereo Quality Enhancement for Martia...
# 32  Powering the Future: Innovations in Electric V...
# 33  Revolutionizing Mobility:The Latest Advancemen...
# 34  Modeling and Simulating Agent-Based City Migra...
# 35  Test Adequacy for Metamorphic Testing: Criteri...
# 36  UBER: Uncertainty-Based Evolution with Large L...
# 37  CoCap: Coordinated motion Capture for multi-ac...
# 38  An inverse obstacle scattering problem with ra...
# 39  Air-Ground Collaborative Robots for Fire and R...
# 40      Optimal rolling of fair dice using fair coins
# 41  Open-Set Object Detection By Aligning Known Cl...
# 42  The Restricted Inverse Optimal Value Problem u...
# 43  HFI: A unified framework for training-free det...
# 44  Metadata-Enhanced Speech Emotion Recognition: ...
# 45  Residual Connection Networks in Medical Image ...
# 46  How to Balance the Load Online When Jobs and M...
# 47  Inverse medium problems, saddle point formulation
# 48  Effective and Efficient Intracortical Brain Si...
# 49  ChartAdapter: Large Vision-Language Model for ...
#
#                                              abstract  \
# 0   A sequence is difference algebraic (or D-algeb...
# 1   Recently, "visual o1" began to enter people's ...
# 2   Human acceptance of social robots is greatly e...
# 3   Graph Neural Networks (GNNs) have emerged as a...
# 4   Understanding the traffic dynamics in networks...
# 5   As real-world knowledge is constantly evolving...
# 6   Performing policy evaluation in education, hea...
# 7   Machine learning (ML) models frequently rely o...
# 8   Most active learning research has focused on m...
# 9   Traditional object detection models are constr...
# 10  Text-based person search aims to retrieve the ...
# 11  Scaling by training on large datasets has been...
# 12  Human trust plays a crucial role in the effect...
# 13  This paper analyzes the proportion of Input/ou...
# 14  Class imbalance is pervasive in real-world gra...
# 15  Generating high-quality whole-body human objec...
# 16  Sloshing Platform for In-Orbit Controller Expe...
# 17  LPWAN service's inexpensive cost and long rang...
# 18  Pre-trained foundation models have recently si...
# 19  With the rapid advancement of remote sensing t...
# 20  Classical approaches to Vanishing Point Detect...
# 21  This paper investigates managed lane (ML) toll...
# 22  Unsupervised domain adaptation aims to transfe...
# 23  The degraded performance and group unfairness ...
# 24  Federated Learning (FL) is a privacy-preservin...
# 25  Magnetic adhesion tracked climbing robots are ...
# 26  Large language models have been shown to perfo...
# 27  One of the emerging techniques in node classif...
# 28  The integration of optimization problems withi...
# 29  This paper introduces a physics enhanced resid...
# 30  Vision language models (VLMs) like CLIP show s...
# 31  Stereo images captured by Mars rovers are tran...
# 32  The global shift towards electric vehicles (EV...
# 33  Autonomous vehicle (AV) technology is transfor...
# 34  Agent-based modeling (ABM) has become a corner...
# 35  Metamorphic testing (MT) is a simple yet effec...
# 36  NP-hard problem-solving traditionally relies o...
# 37  Motion capture has become increasingly importa...
# 38  This work considers a time domain inverse acou...
# 39  Air-ground collaborative robots have shown gre...
# 40  In 1976, Knuth and Yao presented an algorithm ...
# 41  Open-Set Object Detection (OSOD) has emerged a...
# 42  We consider the Restricted Inverse Optimal Val...
# 43  Dramatic advances in the quality of the latent...
# 44  Speech Emotion Recognition (SER) involves anal...
# 45  Accurate identification and localisation of br...
# 46  In this paper, we study the classic optimizati...
# 47  In this paper we discuss inverse medium proble...
# 48  A brain-computer interface (BCI) facilitates d...
# 49  Chart summarization, which focuses on extracti...
#
#                                               authors             published  \
# 0                            Bertrand Teguia Tabuguia  2024-12-30T00:39:57Z
# 1   Haoran Wei, Youyang Yin, Yumeng Li, Jia Wang, ...  2024-12-30T00:40:35Z
# 2                Jordan Sinclair, Christopher Reardon  2024-12-30T00:43:31Z
# 3   Nguyen Xuan Tung, Le Tung Giang, Bui Duc Son, ...  2024-12-30T00:46:48Z
# 4   Jiawei Zhou, Woojeong Kim, Zhiying Xu, Alexand...  2024-12-30T00:47:49Z
# 5   Yongchang Li, Yujin Zhu, Tao Yan, Shijian Fan,...  2024-12-30T00:58:00Z
# 6   Hyunji Nam, Allen Nie, Ge Gao, Vasilis Syrgkan...  2024-12-30T01:01:15Z
# 7              Md Mahadi Hasan Nahid, Sadid Bin Hasan  2024-12-30T01:10:10Z
# 8   Wonho Bae, Gabriel L. Oliveira, Danica J. Suth...  2024-12-30T01:33:42Z
# 9   Lihao Liu, Juexiao Feng, Hui Chen, Ao Wang, Li...  2024-12-30T01:34:14Z
# 10  Wei Shen, Ming Fang, Yuxia Wang, Jiafeng Xiao,...  2024-12-30T01:38:14Z
# 11  Yousef Yeganeh, Ioannis Charisiadis, Marta Has...  2024-12-30T01:59:34Z
# 12  Hao Guo, Bangan Wu, Qi Li, Zhen Ding, Feng Jia...  2024-12-30T02:17:48Z
# 13              Patrick Gould, Guanqun Song, Ting Zhu  2024-12-30T02:20:36Z
# 14            Abdullah Alchihabi, Hao Yan, Yuhong Guo  2024-12-30T02:20:40Z
# 15  Yonghao Zhang, Qiang He, Yanguang Wan, Yinda Z...  2024-12-30T02:21:43Z
# 16  Michael fogel, Snigdha Sushil Mishra, Laurent ...  2024-12-30T02:28:40Z
# 17  Muskan Shergill, Zach Thompson, Guanqun Song, ...  2024-12-30T02:30:40Z
# 18  Yitong Zhou, Mingyue Cheng, Qingyang Mao, Qi L...  2024-12-30T02:40:19Z
# 19  Yuxuan Li, Xiang Li, Yunheng Li, Yicheng Zhang...  2024-12-30T02:47:51Z
# 20        Skanda Bharadwaj, Robert Collins, Yanxi Liu  2024-12-30T02:47:51Z
# 21                   Max T. M. Ng, Hani S. Mahmassani  2024-12-30T02:48:02Z
# 22       Jian Liang, Lijun Sheng, Hongmin Liu, Ran He  2024-12-30T02:48:34Z
# 23  Junyi Chen, Mengjia Wu, Qian Liu, Ying Ding, Y...  2024-12-30T02:51:57Z
# 24  Ervin Moore, Ahmed Imteaj, Md Zarif Hossain, S...  2024-12-30T02:58:18Z
# 25   Zhen Ma, He Xu, Jielong Dou, Yi Qin, Xueyu Zhang  2024-12-30T02:59:57Z
# 26  Qingyun Jin, Xiaohui Song, Feng Zhou, Zengchan...  2024-12-30T03:05:45Z
# 27                                      Calder Katyal  2024-12-30T03:15:25Z
# 28                                      Calder Katyal  2024-12-30T03:18:24Z
# 29  Peng Zhang, Heye Huang, Hang Zhou, Haotian Shi...  2024-12-30T03:21:44Z
# 30  Yuhe Ding, Bo Jiang, Aihua Zheng, Qin Xu, Jian...  2024-12-30T03:26:53Z
# 31  Mai Xu, Yinglin Zhu, Qunliang Xing, Jing Yang,...  2024-12-30T03:36:07Z
# 32  Venkata Sai Chandra Prasanth Narisetty, Tejasw...  2024-12-30T03:47:05Z
# 33  Venkata Sai Chandra Prasanth Narisetty, Tejasw...  2024-12-30T03:51:24Z
# 34                        Bruce Deng, Mayank Kejriwal  2024-12-30T03:59:30Z
# 35       An Fu, Chang-ai Sun, Jiaming Zhang, Huai Liu  2024-12-30T04:00:39Z
# 36  Zijie Chen, Zhanchao Zhou, Yu Lu, Renjun Xu, L...  2024-12-30T04:05:22Z
# 37    Aditya Rauniyar, Micah Corah, Sebastian Scherer  2024-12-30T04:06:19Z
# 38       Xiaoli Liu, Shixu Meng, Jialu Tian, Bo Zhang  2024-12-30T04:11:50Z
# 39  Ying Zhang, Haibao Yan, Danni Zhu, Jiankun Wan...  2024-12-30T04:24:31Z
# 40                           Mark Huber, Danny Vargas  2024-12-30T04:25:24Z
# 41  Hiran Sarkar, Vishal Chudasama, Naoyuki Onoe, ...  2024-12-30T04:26:56Z
# 42                   Qiao Zhang, Xiao Li, Xiucui Guan  2024-12-30T04:32:17Z
# 43  Sungik Choi, Sungwoo Park, Jaehoon Lee, Seungh...  2024-12-30T04:34:42Z
# 44  Zixiang Wan, Ziyue Qiu, Yiyang Liu, Wei-Qiang ...  2024-12-30T04:49:43Z
# 45               Peixin Dai, Jingsi Zhang, Zhitao Shu  2024-12-30T04:57:26Z
# 46             Wenqian Wang, Chenyang Xu, Yuhao Zhang  2024-12-30T04:58:42Z
# 47                                       Kazufumi Ito  2024-12-30T05:01:41Z
# 48  Haotian Fu, Peng Zhang, Song Yang, Herui Zhang...  2024-12-30T05:05:14Z
# 49                  Peixin Xu, Yujuan Ding, Wenqi Fan  2024-12-30T05:07:34Z
#
#                                  link category
# 0   http://arxiv.org/abs/2412.20630v1  math.AG
# 1   http://arxiv.org/abs/2412.20631v1    cs.CV
# 2   http://arxiv.org/abs/2412.20632v1    cs.RO
# 3   http://arxiv.org/abs/2412.20634v1    cs.IT
# 4   http://arxiv.org/abs/2412.20635v1    cs.LG
# 5   http://arxiv.org/abs/2412.20637v1    cs.CL
# 6   http://arxiv.org/abs/2412.20638v1    cs.AI
# 7   http://arxiv.org/abs/2412.20641v1    cs.LG
# 8   http://arxiv.org/abs/2412.20644v1    cs.LG
# 9   http://arxiv.org/abs/2412.20645v1    cs.CV
# 10  http://arxiv.org/abs/2412.20646v1    cs.CV
# 11  http://arxiv.org/abs/2412.20651v1    cs.CV
# 12  http://arxiv.org/abs/2412.20654v1    cs.RO
# 13  http://arxiv.org/abs/2412.20655v1    cs.CY
# 14  http://arxiv.org/abs/2412.20656v1    cs.LG
# 15  http://arxiv.org/abs/2412.20657v1    cs.CV
# 16  http://arxiv.org/abs/2412.20659v1  eess.SY
# 17  http://arxiv.org/abs/2412.20660v1    cs.ET
# 18  http://arxiv.org/abs/2412.20662v1    cs.CV
# 19  http://arxiv.org/abs/2412.20665v1    cs.CV
# 20  http://arxiv.org/abs/2412.20666v1    cs.CV
# 21  http://arxiv.org/abs/2412.20667v1  eess.SY
# 22  http://arxiv.org/abs/2412.20670v1    cs.LG
# 23  http://arxiv.org/abs/2412.20671v1    cs.SI
# 24  http://arxiv.org/abs/2412.20674v1    cs.DC
# 25  http://arxiv.org/abs/2412.20675v1    cs.RO
# 26  http://arxiv.org/abs/2412.20677v1    cs.CL
# 27  http://arxiv.org/abs/2412.20678v1    cs.LG
# 28  http://arxiv.org/abs/2412.20679v1    cs.LG
# 29  http://arxiv.org/abs/2412.20680v1    cs.RO
# 30  http://arxiv.org/abs/2412.20682v1    cs.CV
# 31  http://arxiv.org/abs/2412.20685v1  eess.IV
# 32  http://arxiv.org/abs/2412.20687v1    cs.CE
# 33  http://arxiv.org/abs/2412.20688v1    cs.CE
# 34  http://arxiv.org/abs/2412.20691v1    cs.CY
# 35  http://arxiv.org/abs/2412.20692v1    cs.SE
# 36  http://arxiv.org/abs/2412.20694v1    cs.NE
# 37  http://arxiv.org/abs/2412.20695v1    cs.RO
# 38  http://arxiv.org/abs/2412.20697v1  math.NA
# 39  http://arxiv.org/abs/2412.20699v1    cs.RO
# 40  http://arxiv.org/abs/2412.20700v1    cs.DS
# 41  http://arxiv.org/abs/2412.20701v1    cs.CV
# 42  http://arxiv.org/abs/2412.20703v1    cs.DS
# 43  http://arxiv.org/abs/2412.20704v1    cs.CV
# 44  http://arxiv.org/abs/2412.20707v1  eess.AS
# 45  http://arxiv.org/abs/2412.20709v1  eess.IV
# 46  http://arxiv.org/abs/2412.20711v1    cs.DS
# 47  http://arxiv.org/abs/2412.20713v1  math.NA
# 48  http://arxiv.org/abs/2412.20714v1    cs.HC
# 49  http://arxiv.org/abs/2412.20715v1    cs.MM

# %%
data
# Out:
#                                                 title  \
# 0                Computing with D-Algebraic Sequences
# 1   Slow Perception: Let's Perceive Geometric Figu...
# 2   EVOLVE: Emotion and Visual Output Learning via...
# 3   Graph Neural Networks for Next-Generation-IoT:...
# 4   NetFlowGen: Leveraging Generative Pre-training...
# 5   Knowledge Editing for Large Language Model wit...
# 6   Predicting Long Term Sequential Policy Value U...
# 7   SafeSynthDP: Leveraging Large Language Models ...
# 8   Uncertainty Herding: One Active Learning Metho...
# 9   YOLO-UniOW: Efficient Universal Open-World Obj...
# 10  Enhancing Visual Representation for Text-based...
# 11  Latent Drifting in Diffusion Models for Counte...
# 12  Impact of Cognitive Load on Human Trust in Hyb...
# 13  Environmental and Economic Impact of I/O Devic...
# 14  Overcoming Class Imbalance: Unified GNN Learni...
# 15  Diffgrasp: Whole-Body Grasping Synthesis Guide...
# 16  Nanosatellite Design Considerations for a Miss...
# 17         Energy Efficient LoRaWAN in LEO Satellites
# 18  Enhancing Table Recognition with Vision LLMs: ...
# 19  SM3Det: A Unified Model for Multi-Modal Remote...
# 20         Recurrence-based Vanishing Point Detection
# 21  Highway Managed Lane Usage and Tolling for Mix...
# 22  Prototypical Distillation and Debiased Tuning ...
# 23  Two Birds with One Stone: Improving Rumor Dete...
# 24  Blockchain-Empowered Cyber-Secure Federated Le...
# 25  Improved ICNN-LSTM Model Classification Based ...
# 26  Align Attention Heads Before Merging Them: An ...
# 27  Attention-Driven Metapath Encoding in Heteroge...
# 28  Differentiable Convex Optimization Layers in N...
# 29  Online Adaptive Platoon Control for Connected ...
# 30  Learning to Rank Pre-trained Vision-Language M...
# 31  MarsSQE: Stereo Quality Enhancement for Martia...
# 32  Powering the Future: Innovations in Electric V...
# 33  Revolutionizing Mobility:The Latest Advancemen...
# 34  Modeling and Simulating Agent-Based City Migra...
# 35  Test Adequacy for Metamorphic Testing: Criteri...
# 36  UBER: Uncertainty-Based Evolution with Large L...
# 37  CoCap: Coordinated motion Capture for multi-ac...
# 38  An inverse obstacle scattering problem with ra...
# 39  Air-Ground Collaborative Robots for Fire and R...
# 40      Optimal rolling of fair dice using fair coins
# 41  Open-Set Object Detection By Aligning Known Cl...
# 42  The Restricted Inverse Optimal Value Problem u...
# 43  HFI: A unified framework for training-free det...
# 44  Metadata-Enhanced Speech Emotion Recognition: ...
# 45  Residual Connection Networks in Medical Image ...
# 46  How to Balance the Load Online When Jobs and M...
# 47  Inverse medium problems, saddle point formulation
# 48  Effective and Efficient Intracortical Brain Si...
# 49  ChartAdapter: Large Vision-Language Model for ...
#
#                                              abstract  \
# 0   A sequence is difference algebraic (or D-algeb...
# 1   Recently, "visual o1" began to enter people's ...
# 2   Human acceptance of social robots is greatly e...
# 3   Graph Neural Networks (GNNs) have emerged as a...
# 4   Understanding the traffic dynamics in networks...
# 5   As real-world knowledge is constantly evolving...
# 6   Performing policy evaluation in education, hea...
# 7   Machine learning (ML) models frequently rely o...
# 8   Most active learning research has focused on m...
# 9   Traditional object detection models are constr...
# 10  Text-based person search aims to retrieve the ...
# 11  Scaling by training on large datasets has been...
# 12  Human trust plays a crucial role in the effect...
# 13  This paper analyzes the proportion of Input/ou...
# 14  Class imbalance is pervasive in real-world gra...
# 15  Generating high-quality whole-body human objec...
# 16  Sloshing Platform for In-Orbit Controller Expe...
# 17  LPWAN service's inexpensive cost and long rang...
# 18  Pre-trained foundation models have recently si...
# 19  With the rapid advancement of remote sensing t...
# 20  Classical approaches to Vanishing Point Detect...
# 21  This paper investigates managed lane (ML) toll...
# 22  Unsupervised domain adaptation aims to transfe...
# 23  The degraded performance and group unfairness ...
# 24  Federated Learning (FL) is a privacy-preservin...
# 25  Magnetic adhesion tracked climbing robots are ...
# 26  Large language models have been shown to perfo...
# 27  One of the emerging techniques in node classif...
# 28  The integration of optimization problems withi...
# 29  This paper introduces a physics enhanced resid...
# 30  Vision language models (VLMs) like CLIP show s...
# 31  Stereo images captured by Mars rovers are tran...
# 32  The global shift towards electric vehicles (EV...
# 33  Autonomous vehicle (AV) technology is transfor...
# 34  Agent-based modeling (ABM) has become a corner...
# 35  Metamorphic testing (MT) is a simple yet effec...
# 36  NP-hard problem-solving traditionally relies o...
# 37  Motion capture has become increasingly importa...
# 38  This work considers a time domain inverse acou...
# 39  Air-ground collaborative robots have shown gre...
# 40  In 1976, Knuth and Yao presented an algorithm ...
# 41  Open-Set Object Detection (OSOD) has emerged a...
# 42  We consider the Restricted Inverse Optimal Val...
# 43  Dramatic advances in the quality of the latent...
# 44  Speech Emotion Recognition (SER) involves anal...
# 45  Accurate identification and localisation of br...
# 46  In this paper, we study the classic optimizati...
# 47  In this paper we discuss inverse medium proble...
# 48  A brain-computer interface (BCI) facilitates d...
# 49  Chart summarization, which focuses on extracti...
#
#                                               authors             published  \
# 0                            Bertrand Teguia Tabuguia  2024-12-30T00:39:57Z
# 1   Haoran Wei, Youyang Yin, Yumeng Li, Jia Wang, ...  2024-12-30T00:40:35Z
# 2                Jordan Sinclair, Christopher Reardon  2024-12-30T00:43:31Z
# 3   Nguyen Xuan Tung, Le Tung Giang, Bui Duc Son, ...  2024-12-30T00:46:48Z
# 4   Jiawei Zhou, Woojeong Kim, Zhiying Xu, Alexand...  2024-12-30T00:47:49Z
# 5   Yongchang Li, Yujin Zhu, Tao Yan, Shijian Fan,...  2024-12-30T00:58:00Z
# 6   Hyunji Nam, Allen Nie, Ge Gao, Vasilis Syrgkan...  2024-12-30T01:01:15Z
# 7              Md Mahadi Hasan Nahid, Sadid Bin Hasan  2024-12-30T01:10:10Z
# 8   Wonho Bae, Gabriel L. Oliveira, Danica J. Suth...  2024-12-30T01:33:42Z
# 9   Lihao Liu, Juexiao Feng, Hui Chen, Ao Wang, Li...  2024-12-30T01:34:14Z
# 10  Wei Shen, Ming Fang, Yuxia Wang, Jiafeng Xiao,...  2024-12-30T01:38:14Z
# 11  Yousef Yeganeh, Ioannis Charisiadis, Marta Has...  2024-12-30T01:59:34Z
# 12  Hao Guo, Bangan Wu, Qi Li, Zhen Ding, Feng Jia...  2024-12-30T02:17:48Z
# 13              Patrick Gould, Guanqun Song, Ting Zhu  2024-12-30T02:20:36Z
# 14            Abdullah Alchihabi, Hao Yan, Yuhong Guo  2024-12-30T02:20:40Z
# 15  Yonghao Zhang, Qiang He, Yanguang Wan, Yinda Z...  2024-12-30T02:21:43Z
# 16  Michael fogel, Snigdha Sushil Mishra, Laurent ...  2024-12-30T02:28:40Z
# 17  Muskan Shergill, Zach Thompson, Guanqun Song, ...  2024-12-30T02:30:40Z
# 18  Yitong Zhou, Mingyue Cheng, Qingyang Mao, Qi L...  2024-12-30T02:40:19Z
# 19  Yuxuan Li, Xiang Li, Yunheng Li, Yicheng Zhang...  2024-12-30T02:47:51Z
# 20        Skanda Bharadwaj, Robert Collins, Yanxi Liu  2024-12-30T02:47:51Z
# 21                   Max T. M. Ng, Hani S. Mahmassani  2024-12-30T02:48:02Z
# 22       Jian Liang, Lijun Sheng, Hongmin Liu, Ran He  2024-12-30T02:48:34Z
# 23  Junyi Chen, Mengjia Wu, Qian Liu, Ying Ding, Y...  2024-12-30T02:51:57Z
# 24  Ervin Moore, Ahmed Imteaj, Md Zarif Hossain, S...  2024-12-30T02:58:18Z
# 25   Zhen Ma, He Xu, Jielong Dou, Yi Qin, Xueyu Zhang  2024-12-30T02:59:57Z
# 26  Qingyun Jin, Xiaohui Song, Feng Zhou, Zengchan...  2024-12-30T03:05:45Z
# 27                                      Calder Katyal  2024-12-30T03:15:25Z
# 28                                      Calder Katyal  2024-12-30T03:18:24Z
# 29  Peng Zhang, Heye Huang, Hang Zhou, Haotian Shi...  2024-12-30T03:21:44Z
# 30  Yuhe Ding, Bo Jiang, Aihua Zheng, Qin Xu, Jian...  2024-12-30T03:26:53Z
# 31  Mai Xu, Yinglin Zhu, Qunliang Xing, Jing Yang,...  2024-12-30T03:36:07Z
# 32  Venkata Sai Chandra Prasanth Narisetty, Tejasw...  2024-12-30T03:47:05Z
# 33  Venkata Sai Chandra Prasanth Narisetty, Tejasw...  2024-12-30T03:51:24Z
# 34                        Bruce Deng, Mayank Kejriwal  2024-12-30T03:59:30Z
# 35       An Fu, Chang-ai Sun, Jiaming Zhang, Huai Liu  2024-12-30T04:00:39Z
# 36  Zijie Chen, Zhanchao Zhou, Yu Lu, Renjun Xu, L...  2024-12-30T04:05:22Z
# 37    Aditya Rauniyar, Micah Corah, Sebastian Scherer  2024-12-30T04:06:19Z
# 38       Xiaoli Liu, Shixu Meng, Jialu Tian, Bo Zhang  2024-12-30T04:11:50Z
# 39  Ying Zhang, Haibao Yan, Danni Zhu, Jiankun Wan...  2024-12-30T04:24:31Z
# 40                           Mark Huber, Danny Vargas  2024-12-30T04:25:24Z
# 41  Hiran Sarkar, Vishal Chudasama, Naoyuki Onoe, ...  2024-12-30T04:26:56Z
# 42                   Qiao Zhang, Xiao Li, Xiucui Guan  2024-12-30T04:32:17Z
# 43  Sungik Choi, Sungwoo Park, Jaehoon Lee, Seungh...  2024-12-30T04:34:42Z
# 44  Zixiang Wan, Ziyue Qiu, Yiyang Liu, Wei-Qiang ...  2024-12-30T04:49:43Z
# 45               Peixin Dai, Jingsi Zhang, Zhitao Shu  2024-12-30T04:57:26Z
# 46             Wenqian Wang, Chenyang Xu, Yuhao Zhang  2024-12-30T04:58:42Z
# 47                                       Kazufumi Ito  2024-12-30T05:01:41Z
# 48  Haotian Fu, Peng Zhang, Song Yang, Herui Zhang...  2024-12-30T05:05:14Z
# 49                  Peixin Xu, Yujuan Ding, Wenqi Fan  2024-12-30T05:07:34Z
#
#                                  link category
# 0   http://arxiv.org/abs/2412.20630v1  math.AG
# 1   http://arxiv.org/abs/2412.20631v1    cs.CV
# 2   http://arxiv.org/abs/2412.20632v1    cs.RO
# 3   http://arxiv.org/abs/2412.20634v1    cs.IT
# 4   http://arxiv.org/abs/2412.20635v1    cs.LG
# 5   http://arxiv.org/abs/2412.20637v1    cs.CL
# 6   http://arxiv.org/abs/2412.20638v1    cs.AI
# 7   http://arxiv.org/abs/2412.20641v1    cs.LG
# 8   http://arxiv.org/abs/2412.20644v1    cs.LG
# 9   http://arxiv.org/abs/2412.20645v1    cs.CV
# 10  http://arxiv.org/abs/2412.20646v1    cs.CV
# 11  http://arxiv.org/abs/2412.20651v1    cs.CV
# 12  http://arxiv.org/abs/2412.20654v1    cs.RO
# 13  http://arxiv.org/abs/2412.20655v1    cs.CY
# 14  http://arxiv.org/abs/2412.20656v1    cs.LG
# 15  http://arxiv.org/abs/2412.20657v1    cs.CV
# 16  http://arxiv.org/abs/2412.20659v1  eess.SY
# 17  http://arxiv.org/abs/2412.20660v1    cs.ET
# 18  http://arxiv.org/abs/2412.20662v1    cs.CV
# 19  http://arxiv.org/abs/2412.20665v1    cs.CV
# 20  http://arxiv.org/abs/2412.20666v1    cs.CV
# 21  http://arxiv.org/abs/2412.20667v1  eess.SY
# 22  http://arxiv.org/abs/2412.20670v1    cs.LG
# 23  http://arxiv.org/abs/2412.20671v1    cs.SI
# 24  http://arxiv.org/abs/2412.20674v1    cs.DC
# 25  http://arxiv.org/abs/2412.20675v1    cs.RO
# 26  http://arxiv.org/abs/2412.20677v1    cs.CL
# 27  http://arxiv.org/abs/2412.20678v1    cs.LG
# 28  http://arxiv.org/abs/2412.20679v1    cs.LG
# 29  http://arxiv.org/abs/2412.20680v1    cs.RO
# 30  http://arxiv.org/abs/2412.20682v1    cs.CV
# 31  http://arxiv.org/abs/2412.20685v1  eess.IV
# 32  http://arxiv.org/abs/2412.20687v1    cs.CE
# 33  http://arxiv.org/abs/2412.20688v1    cs.CE
# 34  http://arxiv.org/abs/2412.20691v1    cs.CY
# 35  http://arxiv.org/abs/2412.20692v1    cs.SE
# 36  http://arxiv.org/abs/2412.20694v1    cs.NE
# 37  http://arxiv.org/abs/2412.20695v1    cs.RO
# 38  http://arxiv.org/abs/2412.20697v1  math.NA
# 39  http://arxiv.org/abs/2412.20699v1    cs.RO
# 40  http://arxiv.org/abs/2412.20700v1    cs.DS
# 41  http://arxiv.org/abs/2412.20701v1    cs.CV
# 42  http://arxiv.org/abs/2412.20703v1    cs.DS
# 43  http://arxiv.org/abs/2412.20704v1    cs.CV
# 44  http://arxiv.org/abs/2412.20707v1  eess.AS
# 45  http://arxiv.org/abs/2412.20709v1  eess.IV
# 46  http://arxiv.org/abs/2412.20711v1    cs.DS
# 47  http://arxiv.org/abs/2412.20713v1  math.NA
# 48  http://arxiv.org/abs/2412.20714v1    cs.HC
# 49  http://arxiv.org/abs/2412.20715v1    cs.MM

# %%
data['summary'] = np.nan

client_summary = Groq(
    api_key=os.environ['GROQ_API_KEY_1'],
)

for i in range(len(data)):
    content = data['abstract'][i]
    summary = client_summary.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "You need to provide a one line summary of the provided abstract. You should not fabricate any information. Please do not include any other text other than the requested content.",
            },
            
            {
                "role": "user",
                "content": content,
            }
        ],
        model="llama3-8b-8192",
        stream=False,
    )
    data['summary'][i] = summary.choices[0].message.content
# Out:
# /var/folders/tm/964hg0yn70x0ddsqcj4bsf8r0000gn/T/ipykernel_64034/1425578622.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['summary'][i] = summary.choices[0].message.content

# %%
data['keywords'] = np.nan

client_keywords = Groq(
    api_key= os.environ['GROQ_API_KEY_2'],
)

for i in range(len(data)):
    title = data['title'][i]
    keywords = client_keywords.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "You need to pick out 2-3 keywords from the provided title that are relevnt to the topic of the paper. Please do not include any other text explaining what is the response other than the requested content itself. No need to number the keywords.",
            },
            
            {
                "role": "user",
                "content": title,
            }
        ],
        model="llama3-8b-8192",
        stream=False,
    )
    data['keywords'][i] = keywords.choices[0].message.content
# Out:
# /var/folders/tm/964hg0yn70x0ddsqcj4bsf8r0000gn/T/ipykernel_64034/1749145193.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'][i] = keywords.choices[0].message.content

# %%
data['published'] = pd.to_datetime(data['published'])
data['published'] = data['published'].dt.date

# %%
category_replacements = {
    'CO': 'Cosmology and Nongalactic Astrophysics',
    'EP': 'Earth and Planetary Astrophysics',
    'GA': 'Astrophysics of Galaxies',
    'HE': 'High Energy Astrophysical Phenomena',
    'IM': 'Instrumentation and Methods for Astrophysics',
    'SR': 'Solar and Stellar Astrophysics'
}

def replace_category(category):
    category = category.removeprefix('astro-ph.')
    for key, value in category_replacements.items():
        category = category.replace(key, value)
    return category

data['category'] = data['category'].map(replace_category)

# %%
data['affiliation'] = np.nan

for i in range(len(data)):
    authors = data['authors'][i].split(', ')
    if len(authors) > 5:
        authors = authors[:5]
    
    print(authors)
    
    affiliation = []

    for j in range(len(authors)):
        print(authors[j])
        pg = ProxyGenerator()
        pg.FreeProxies()
        scholarly.use_proxy(pg)
        
        search_query = scholarly.search_author(authors[j])

        check = next(search_query, None)

        if check is None:
            affiliation.append('')
            continue
        
        # Retrieve all the details for the author
        author = scholarly.fill(check)
        if author is None:
            affiliation.append('')

        scholarly.pprint(author)
        affil = author['affiliation']
        print(affil)

        if ',' in affil:
            parts = affil.split(',')
            position = parts[0]
            a = ','.join(parts[1:]).strip()
        else:
            position = ''
            a = affil

        print(a)

        affiliation.append(a)
    
    print(affiliation)
    
    data['affiliation'][i] = affiliation
# Out:
# ['Bertrand Teguia Tabuguia']
# Bertrand Teguia Tabuguia
# ['']
# ['Haoran Wei', 'Youyang Yin', 'Yumeng Li', 'Jia Wang', 'Liang Zhao']
# Haoran Wei
# /var/folders/tm/964hg0yn70x0ddsqcj4bsf8r0000gn/T/ipykernel_64034/4254110372.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['affiliation'][i] = affiliation
# b"{'affiliation': 'Assistant Professor, University of Wisconsin\xe2\x80\x93Madison',\n 'citedby': 3398,\n 'citedby5y': 2188,\n 'cites_per_year': {2013: 22,\n                    2014: 49,\n                    2015: 154,\n                    2016: 163,\n                    2017: 214,\n                    2018: 290,\n                    2019: 309,\n                    2020: 367,\n                    2021: 455,\n                    2022: 446,\n                    2023: 448,\n                    2024: 450,\n                    2025: 21},\n 'coauthors': [{'affiliation': 'Professor of Civil and Environmental '\n                               'Engineering, Virginia Tech',\n                'filled': False,\n                'name': 'Peter Vikesland',\n                'scholar_id': 'utmwmjwAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'University Distinguished Professor, Charles P. '\n                               'Lunsford Professor, CEE, Virginia Tech',\n                'filled': False,\n                'name': 'Linsey C. Marr',\n                'scholar_id': '2t_FonoAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'University of British Columbia',\n                'filled': False,\n                'name': 'Scott Renneckar',\n                'scholar_id': '_tBWidEAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Yale University',\n                'filled': False,\n                'name': 'Jaehong Kim',\n                'scholar_id': 'q-csBcEAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Associate Professor of Electrical and Computer '\n                               'Engineering, Virginia Tech',\n                'filled': False,\n                'name': 'Wei Zhou',\n                'scholar_id': '-OSBSA8AAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Assistant Professor, McGill University',\n                'filled': False,\n                'name': 'Stephanie Loeb',\n                'scholar_id': 'ip5eR3cAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Ph.D. Student, University of Wisconsin\xe2\x80\x93Madison',\n                'filled': False,\n                'name': 'Seowon Cho',\n                'scholar_id': 'JjQUHWgAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'University of South Carolina',\n                'filled': False,\n                'name': 'Eric Vejerano',\n                'scholar_id': '8m_G02UAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Rice University',\n                'filled': False,\n                'name': 'N. J. Halas',\n                'scholar_id': 'nd8O1XQAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Fudan University',\n                'filled': False,\n                'name': 'Liwu Zhang',\n                'scholar_id': 'wkgBy4gAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Professor of Chemistry and Biomolecular '\n                               'Science, Clarkson University',\n                'filled': False,\n                'name': 'Silvana Andreescu',\n                'scholar_id': '1FheEykAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'U.S. Environmental Protection Agency (EPA)',\n                'filled': False,\n                'name': 'Mohamed Ateia (Ibrahim)',\n                'scholar_id': 'Ss5MnZUAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'University of Wisconsin, Madison',\n                'filled': False,\n                'name': 'K.G. Karthikeyan',\n                'scholar_id': 'J7ZLGAkAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Research Affiliate, University of Pennsy ...
# Assistant Professor, University of Wisconsin–Madison
# University of Wisconsin–Madison
# Youyang Yin
# Yumeng Li
# b"{'affiliation': 'Assistant Professor, Industrial and Enterprise Systems '\n                'Engineering, UIUC',\n 'citedby': 645,\n 'citedby5y': 555,\n 'cites_per_year': {2014: 6,\n                    2015: 8,\n                    2016: 13,\n                    2017: 7,\n                    2018: 18,\n                    2019: 37,\n                    2020: 50,\n                    2021: 28,\n                    2022: 83,\n                    2023: 147,\n                    2024: 228,\n                    2025: 19},\n 'coauthors': [{'affiliation': 'Virginia Tech',\n                'filled': False,\n                'name': 'Gary D. Seidel',\n                'scholar_id': 'MqAA3CsAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'Vanderbilt University',\n                'filled': False,\n                'name': 'Caglar Oskay',\n                'scholar_id': 'rPftKiAAAAAJ',\n                'source': 'CO_AUTHORS_LIST'},\n               {'affiliation': 'University of Wyoming',\n                'filled': False,\n                'name': 'Xiang Zhang (\xe5\xbc\xa0\xe7\xbf\x94)',\n                'scholar_id': 'tooWw_4AAAAJ',\n                'source': 'CO_AUTHORS_LIST'}],\n 'email_domain': '@illinois.edu',\n 'filled': True,\n 'hindex': 12,\n 'hindex5y': 12,\n 'i10index': 18,\n 'i10index5y': 16,\n 'interests': ['Multiscale Modeling',\n               'Multiphysics Simulation',\n               'Material Design',\n               'Physics-informed Machine Learning'],\n 'name': 'Yumeng Li',\n 'organization': 4497256714731484767,\n 'public_access': {'available': 18, 'not_available': 8},\n 'publications': [{'author_pub_id': 'nS5BktwAAAAJ:u5HHmVD_uO8C',\n                   'bib': {'citation': 'Modelling and Simulation in Materials '\n                                       'Science and Engineering 22 (2), '\n                                       '025023, 2014',\n                           'pub_year': '2014',\n                           'title': 'Multiscale modeling of the effects of '\n                                    'nanoscale load transfer on the effective '\n                                    'elastic properties of unfunctionalized '\n                                    'carbon nanotube\xe2\x80\x93polyethylene '\n                                    'nanocomposites'},\n                   'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2825746304666046153',\n                   'cites_id': ['2825746304666046153'],\n                   'filled': False,\n                   'num_citations': 87,\n                   'source': 'AUTHOR_PUBLICATION_ENTRY'},\n                  {'author_pub_id': 'nS5BktwAAAAJ:UeHWp8X0CEIC',\n                   'bib': {'citation': 'Computational Materials Science 153, '\n                                       '363-381, 2018',\n                           'pub_year': '2018',\n                           'title': 'Multiscale modeling of the interface '\n                                    'effects in CNT-epoxy nanocomposites'},\n                   'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16919561104691656521',\n                   'cites_id': ['16919561104691656521'],\n                   'filled': False,\n                   'num_citations': 75,\n                   'source': 'AUTHOR_PUBLICATION_ENTRY'},\n                  {'author_pub_id': 'nS5BktwAAAAJ:2osOgNQ5qMEC',\n                   'bib': {'citation': 'Computational Materials Science 107, '\n                                       '216-234, 2015',\n                           'pub_year': '2015',\n                           'title': 'Multiscale modeling of functionalized '\n                                    'interface effects on the effective '\n                                    'elastic material properties of '\n                                    'CNT\xe2\x80\x93polyethylene nanocomposites'},\n                   'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl ...
# Assistant Professor, Industrial and Enterprise Systems Engineering, UIUC
# Industrial and Enterprise Systems Engineering, UIUC
# Jia Wang
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Cell In[40], line 27
#      24     continue
#      26 # Retrieve all the details for the author
# ---> 27 author = scholarly.fill(check)
#      28 if author is None:
#      29     affiliation.append('')
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_scholarly.py:233, in _Scholarly.fill(self, object, sections, sortby, publication_limit)
#     231 if object['container_type'] == "Author":
#     232     author_parser = AuthorParser(self.__nav)
# --> 233     object = author_parser.fill(object, sections, sortby, publication_limit)
#     234     if object is False:
#     235         raise ValueError("Incorrect input")
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/author_parser.py:462, in AuthorParser.fill(self, author, sections, sortby, publication_limit)
#     460                 author['filled'].append(i)
#     461 except Exception as e:
# --> 462     raise(e)
#     464 return author
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/author_parser.py:454, in AuthorParser.fill(self, author, sections, sortby, publication_limit)
#     452     for i in self._sections:
#     453         if i not in author['filled']:
# --> 454             (getattr(self, f'_fill_{i}')(soup, author) if i != 'publications' else getattr(self, f'_fill_{i}')(soup, author, publication_limit, sortby_str))
#     455             author['filled'].append(i)
#     456 else:
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/author_parser.py:195, in AuthorParser._fill_publications(self, soup, author, publication_limit, sortby_str)
#     192     pubstart += _PAGESIZE
#     193     url = '{0}&cstart={1}&pagesize={2}'.format(
#     194         url_citations, pubstart, _PAGESIZE)
# --> 195     soup = self.nav._get_soup(url)
#     196 else:
#     197     break
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_navigator.py:239, in Navigator._get_soup(self, url)
#     237 def _get_soup(self, url: str) -> BeautifulSoup:
#     238     """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239     html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240     html = html.replace(u'\xa0', u' ')
#     241     res = BeautifulSoup(html, 'html.parser')
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_navigator.py:188, in Navigator._get_page(self, pagerequest, premium)
#     186 # If secondary proxy does not work, try again primary proxy.
#     187 if not premium:
# --> 188     return self._get_page(pagerequest, True)
#     189 else:
#     190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# File ~/Library/Python/3.11/lib/python/site-packages/scholarly/_navigator.py:190, in Navigator._get_page(self, pagerequest, premium)
#     188     return self._get_page(pagerequest, True)
#     189 else:
# --> 190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# MaxTriesExceededException: Cannot Fetch from Google Scholar.

# %%
data
# Out:
#                                                 title  \
# 0                Computing with D-Algebraic Sequences
# 1   Slow Perception: Let's Perceive Geometric Figu...
# 2   EVOLVE: Emotion and Visual Output Learning via...
# 3   Graph Neural Networks for Next-Generation-IoT:...
# 4   NetFlowGen: Leveraging Generative Pre-training...
# 5   Knowledge Editing for Large Language Model wit...
# 6   Predicting Long Term Sequential Policy Value U...
# 7   SafeSynthDP: Leveraging Large Language Models ...
# 8   Uncertainty Herding: One Active Learning Metho...
# 9   YOLO-UniOW: Efficient Universal Open-World Obj...
# 10  Enhancing Visual Representation for Text-based...
# 11  Latent Drifting in Diffusion Models for Counte...
# 12  Impact of Cognitive Load on Human Trust in Hyb...
# 13  Environmental and Economic Impact of I/O Devic...
# 14  Overcoming Class Imbalance: Unified GNN Learni...
# 15  Diffgrasp: Whole-Body Grasping Synthesis Guide...
# 16  Nanosatellite Design Considerations for a Miss...
# 17         Energy Efficient LoRaWAN in LEO Satellites
# 18  Enhancing Table Recognition with Vision LLMs: ...
# 19  SM3Det: A Unified Model for Multi-Modal Remote...
# 20         Recurrence-based Vanishing Point Detection
# 21  Highway Managed Lane Usage and Tolling for Mix...
# 22  Prototypical Distillation and Debiased Tuning ...
# 23  Two Birds with One Stone: Improving Rumor Dete...
# 24  Blockchain-Empowered Cyber-Secure Federated Le...
# 25  Improved ICNN-LSTM Model Classification Based ...
# 26  Align Attention Heads Before Merging Them: An ...
# 27  Attention-Driven Metapath Encoding in Heteroge...
# 28  Differentiable Convex Optimization Layers in N...
# 29  Online Adaptive Platoon Control for Connected ...
# 30  Learning to Rank Pre-trained Vision-Language M...
# 31  MarsSQE: Stereo Quality Enhancement for Martia...
# 32  Powering the Future: Innovations in Electric V...
# 33  Revolutionizing Mobility:The Latest Advancemen...
# 34  Modeling and Simulating Agent-Based City Migra...
# 35  Test Adequacy for Metamorphic Testing: Criteri...
# 36  UBER: Uncertainty-Based Evolution with Large L...
# 37  CoCap: Coordinated motion Capture for multi-ac...
# 38  An inverse obstacle scattering problem with ra...
# 39  Air-Ground Collaborative Robots for Fire and R...
# 40      Optimal rolling of fair dice using fair coins
# 41  Open-Set Object Detection By Aligning Known Cl...
# 42  The Restricted Inverse Optimal Value Problem u...
# 43  HFI: A unified framework for training-free det...
# 44  Metadata-Enhanced Speech Emotion Recognition: ...
# 45  Residual Connection Networks in Medical Image ...
# 46  How to Balance the Load Online When Jobs and M...
# 47  Inverse medium problems, saddle point formulation
# 48  Effective and Efficient Intracortical Brain Si...
# 49  ChartAdapter: Large Vision-Language Model for ...
#
#                                              abstract  \
# 0   A sequence is difference algebraic (or D-algeb...
# 1   Recently, "visual o1" began to enter people's ...
# 2   Human acceptance of social robots is greatly e...
# 3   Graph Neural Networks (GNNs) have emerged as a...
# 4   Understanding the traffic dynamics in networks...
# 5   As real-world knowledge is constantly evolving...
# 6   Performing policy evaluation in education, hea...
# 7   Machine learning (ML) models frequently rely o...
# 8   Most active learning research has focused on m...
# 9   Traditional object detection models are constr...
# 10  Text-based person search aims to retrieve the ...
# 11  Scaling by training on large datasets has been...
# 12  Human trust plays a crucial role in the effect...
# 13  This paper analyzes the proportion of Input/ou...
# 14  Class imbalance is pervasive in real-world gra...
# 15  Generating high-quality whole-body human objec...
# 16  Sloshing Platform for In-Orbit Controller Expe...
# 17  LPWAN service's inexpensive cost and long rang...
# 18  Pre-trained foundation models have recently si...
# 19  With the rapid advancement of remote sensing t...
# 20  Classical approaches to Vanishing Point Detect...
# 21  This paper investigates managed lane (ML) toll...
# 22  Unsupervised domain adaptation aims to transfe...
# 23  The degraded performance and group unfairness ...
# 24  Federated Learning (FL) is a privacy-preservin...
# 25  Magnetic adhesion tracked climbing robots are ...
# 26  Large language models have been shown to perfo...
# 27  One of the emerging techniques in node classif...
# 28  The integration of optimization problems withi...
# 29  This paper introduces a physics enhanced resid...
# 30  Vision language models (VLMs) like CLIP show s...
# 31  Stereo images captured by Mars rovers are tran...
# 32  The global shift towards electric vehicles (EV...
# 33  Autonomous vehicle (AV) technology is transfor...
# 34  Agent-based modeling (ABM) has become a corner...
# 35  Metamorphic testing (MT) is a simple yet effec...
# 36  NP-hard problem-solving traditionally relies o...
# 37  Motion capture has become increasingly importa...
# 38  This work considers a time domain inverse acou...
# 39  Air-ground collaborative robots have shown gre...
# 40  In 1976, Knuth and Yao presented an algorithm ...
# 41  Open-Set Object Detection (OSOD) has emerged a...
# 42  We consider the Restricted Inverse Optimal Val...
# 43  Dramatic advances in the quality of the latent...
# 44  Speech Emotion Recognition (SER) involves anal...
# 45  Accurate identification and localisation of br...
# 46  In this paper, we study the classic optimizati...
# 47  In this paper we discuss inverse medium proble...
# 48  A brain-computer interface (BCI) facilitates d...
# 49  Chart summarization, which focuses on extracti...
#
#                                               authors   published  \
# 0                            Bertrand Teguia Tabuguia  2024-12-30
# 1   Haoran Wei, Youyang Yin, Yumeng Li, Jia Wang, ...  2024-12-30
# 2                Jordan Sinclair, Christopher Reardon  2024-12-30
# 3   Nguyen Xuan Tung, Le Tung Giang, Bui Duc Son, ...  2024-12-30
# 4   Jiawei Zhou, Woojeong Kim, Zhiying Xu, Alexand...  2024-12-30
# 5   Yongchang Li, Yujin Zhu, Tao Yan, Shijian Fan,...  2024-12-30
# 6   Hyunji Nam, Allen Nie, Ge Gao, Vasilis Syrgkan...  2024-12-30
# 7              Md Mahadi Hasan Nahid, Sadid Bin Hasan  2024-12-30
# 8   Wonho Bae, Gabriel L. Oliveira, Danica J. Suth...  2024-12-30
# 9   Lihao Liu, Juexiao Feng, Hui Chen, Ao Wang, Li...  2024-12-30
# 10  Wei Shen, Ming Fang, Yuxia Wang, Jiafeng Xiao,...  2024-12-30
# 11  Yousef Yeganeh, Ioannis Charisiadis, Marta Has...  2024-12-30
# 12  Hao Guo, Bangan Wu, Qi Li, Zhen Ding, Feng Jia...  2024-12-30
# 13              Patrick Gould, Guanqun Song, Ting Zhu  2024-12-30
# 14            Abdullah Alchihabi, Hao Yan, Yuhong Guo  2024-12-30
# 15  Yonghao Zhang, Qiang He, Yanguang Wan, Yinda Z...  2024-12-30
# 16  Michael fogel, Snigdha Sushil Mishra, Laurent ...  2024-12-30
# 17  Muskan Shergill, Zach Thompson, Guanqun Song, ...  2024-12-30
# 18  Yitong Zhou, Mingyue Cheng, Qingyang Mao, Qi L...  2024-12-30
# 19  Yuxuan Li, Xiang Li, Yunheng Li, Yicheng Zhang...  2024-12-30
# 20        Skanda Bharadwaj, Robert Collins, Yanxi Liu  2024-12-30
# 21                   Max T. M. Ng, Hani S. Mahmassani  2024-12-30
# 22       Jian Liang, Lijun Sheng, Hongmin Liu, Ran He  2024-12-30
# 23  Junyi Chen, Mengjia Wu, Qian Liu, Ying Ding, Y...  2024-12-30
# 24  Ervin Moore, Ahmed Imteaj, Md Zarif Hossain, S...  2024-12-30
# 25   Zhen Ma, He Xu, Jielong Dou, Yi Qin, Xueyu Zhang  2024-12-30
# 26  Qingyun Jin, Xiaohui Song, Feng Zhou, Zengchan...  2024-12-30
# 27                                      Calder Katyal  2024-12-30
# 28                                      Calder Katyal  2024-12-30
# 29  Peng Zhang, Heye Huang, Hang Zhou, Haotian Shi...  2024-12-30
# 30  Yuhe Ding, Bo Jiang, Aihua Zheng, Qin Xu, Jian...  2024-12-30
# 31  Mai Xu, Yinglin Zhu, Qunliang Xing, Jing Yang,...  2024-12-30
# 32  Venkata Sai Chandra Prasanth Narisetty, Tejasw...  2024-12-30
# 33  Venkata Sai Chandra Prasanth Narisetty, Tejasw...  2024-12-30
# 34                        Bruce Deng, Mayank Kejriwal  2024-12-30
# 35       An Fu, Chang-ai Sun, Jiaming Zhang, Huai Liu  2024-12-30
# 36  Zijie Chen, Zhanchao Zhou, Yu Lu, Renjun Xu, L...  2024-12-30
# 37    Aditya Rauniyar, Micah Corah, Sebastian Scherer  2024-12-30
# 38       Xiaoli Liu, Shixu Meng, Jialu Tian, Bo Zhang  2024-12-30
# 39  Ying Zhang, Haibao Yan, Danni Zhu, Jiankun Wan...  2024-12-30
# 40                           Mark Huber, Danny Vargas  2024-12-30
# 41  Hiran Sarkar, Vishal Chudasama, Naoyuki Onoe, ...  2024-12-30
# 42                   Qiao Zhang, Xiao Li, Xiucui Guan  2024-12-30
# 43  Sungik Choi, Sungwoo Park, Jaehoon Lee, Seungh...  2024-12-30
# 44  Zixiang Wan, Ziyue Qiu, Yiyang Liu, Wei-Qiang ...  2024-12-30
# 45               Peixin Dai, Jingsi Zhang, Zhitao Shu  2024-12-30
# 46             Wenqian Wang, Chenyang Xu, Yuhao Zhang  2024-12-30
# 47                                       Kazufumi Ito  2024-12-30
# 48  Haotian Fu, Peng Zhang, Song Yang, Herui Zhang...  2024-12-30
# 49                  Peixin Xu, Yujuan Ding, Wenqi Fan  2024-12-30
#
#                                  link category  \
# 0   http://arxiv.org/abs/2412.20630v1  math.AG
# 1   http://arxiv.org/abs/2412.20631v1    cs.CV
# 2   http://arxiv.org/abs/2412.20632v1    cs.RO
# 3   http://arxiv.org/abs/2412.20634v1    cs.IT
# 4   http://arxiv.org/abs/2412.20635v1    cs.LG
# 5   http://arxiv.org/abs/2412.20637v1    cs.CL
# 6   http://arxiv.org/abs/2412.20638v1    cs.AI
# 7   http://arxiv.org/abs/2412.20641v1    cs.LG
# 8   http://arxiv.org/abs/2412.20644v1    cs.LG
# 9   http://arxiv.org/abs/2412.20645v1    cs.CV
# 10  http://arxiv.org/abs/2412.20646v1    cs.CV
# 11  http://arxiv.org/abs/2412.20651v1    cs.CV
# 12  http://arxiv.org/abs/2412.20654v1    cs.RO
# 13  http://arxiv.org/abs/2412.20655v1    cs.CY
# 14  http://arxiv.org/abs/2412.20656v1    cs.LG
# 15  http://arxiv.org/abs/2412.20657v1    cs.CV
# 16  http://arxiv.org/abs/2412.20659v1  eess.SY
# 17  http://arxiv.org/abs/2412.20660v1    cs.ET
# 18  http://arxiv.org/abs/2412.20662v1    cs.CV
# 19  http://arxiv.org/abs/2412.20665v1    cs.CV
# 20  http://arxiv.org/abs/2412.20666v1    cs.CV
# 21  http://arxiv.org/abs/2412.20667v1  eess.SY
# 22  http://arxiv.org/abs/2412.20670v1    cs.LG
# 23  http://arxiv.org/abs/2412.20671v1    cs.SI
# 24  http://arxiv.org/abs/2412.20674v1    cs.DC
# 25  http://arxiv.org/abs/2412.20675v1    cs.RO
# 26  http://arxiv.org/abs/2412.20677v1    cs.CL
# 27  http://arxiv.org/abs/2412.20678v1    cs.LG
# 28  http://arxiv.org/abs/2412.20679v1    cs.LG
# 29  http://arxiv.org/abs/2412.20680v1    cs.RO
# 30  http://arxiv.org/abs/2412.20682v1    cs.CV
# 31  http://arxiv.org/abs/2412.20685v1  eess.IV
# 32  http://arxiv.org/abs/2412.20687v1    cs.CE
# 33  http://arxiv.org/abs/2412.20688v1    cs.CE
# 34  http://arxiv.org/abs/2412.20691v1    cs.CY
# 35  http://arxiv.org/abs/2412.20692v1    cs.SE
# 36  http://arxiv.org/abs/2412.20694v1    cs.NE
# 37  http://arxiv.org/abs/2412.20695v1    cs.RO
# 38  http://arxiv.org/abs/2412.20697v1  math.NA
# 39  http://arxiv.org/abs/2412.20699v1    cs.RO
# 40  http://arxiv.org/abs/2412.20700v1    cs.DS
# 41  http://arxiv.org/abs/2412.20701v1    cs.CV
# 42  http://arxiv.org/abs/2412.20703v1    cs.DS
# 43  http://arxiv.org/abs/2412.20704v1    cs.CV
# 44  http://arxiv.org/abs/2412.20707v1  eess.AS
# 45  http://arxiv.org/abs/2412.20709v1  eess.IV
# 46  http://arxiv.org/abs/2412.20711v1    cs.DS
# 47  http://arxiv.org/abs/2412.20713v1  math.NA
# 48  http://arxiv.org/abs/2412.20714v1    cs.HC
# 49  http://arxiv.org/abs/2412.20715v1    cs.MM
#
#                                               summary  \
# 0   Subsequences of difference algebraic sequences...
# 1   The abstract introduces "slow perception" (SP)...
# 2   The development of large language models (LLMs...
# 3   This survey explores the application of Graph ...
# 4   Here is a one-line summary of the abstract:\n\...
# 5   A novel knowledge editing method called Knowle...
# 6   The authors develop methods to estimate the pe...
# 7   The paper investigates the use of Large Langua...
# 8   A new active learning approach, uncertainty co...
# 9   This work introduces Universial Open-World Obj...
# 10  The VFE-TPS model is proposed for text-based p...
# 11  The paper proposes a method called Latent Drif...
# 12  This study finds that cognitive load has a com...
# 13  The paper examines the proportion of input/out...
# 14  The abstract presents a novel framework called...
# 15  Our framework generates realistic whole-body h...
# 16  The SPICEsat mission is a student-run cubesat ...
# 17  LPWAN technology's limitations in maximizing b...
# 18  The proposed Neighbor-Guided Toolchain Reasone...
# 19  This paper introduces a new task called M2Det ...
# 20  An unsupervised approach, Recurrence-based Van...
# 21  This paper explores the optimal managed lane t...
# 22  ProDDing is a two-step framework for black-box...
# 23  The proposed two-step framework identifies con...
# 24  This paper proposes a cross-device federated l...
# 25  A new ICNN-LSTM network classification method ...
# 26  A low-cost method is proposed to prune MHA mod...
# 27  The paper presents a new node classification f...
# 28  This paper surveys the integration of optimiza...
# 29  The paper introduces a physics-enhanced residu...
# 30  The paper introduces the problem of unsupervis...
# 31  The paper presents MarsSQE, a novel stereo qua...
# 32  The recycling of electric vehicle batteries is...
# 33  The paper discusses the cutting-edge technolog...
# 34  A novel agent-based modeling framework is prop...
# 35  This paper proposes a new set of criteria and ...
# 36  UBER, a method that integrates uncertainty int...
# 37  Coordinated motion capture (CoCap) addresses t...
# 38  This work proposes a time-domain linear sampli...
# 39  This paper presents a comprehensive review of ...
# 40  The Knuth-Yao algorithm for sampling from a fi...
# 41  A new approach to Open-Set Object Detection (O...
# 42  The abstract presents the solution to two prob...
# 43  The abstract proposes HFI, a novel training-fr...
# 44  A novel approach is proposed for Speech Emotio...
# 45  This paper introduces ResUnet++, a hybrid neur...
# 46  The paper designs an online mechanism that is ...
# 47  The paper develops the direct sampling method ...
# 48  A novel spiking neural network framework, LSS-...
# 49  The authors propose ChartAdapter, a novel tran...
#
#                                              keywords affiliation
# 0                     Sequences D-Algebraic Computing          []
# 1                   slow perception geometric figures         NaN
# 2                              Emotion, Learning, LLM         NaN
# 3       Graph Neural Networks IoT Advances Challenges         NaN
# 4   generative pre-training, network traffic, dyna...         NaN
# 5                                    Knowledge Neural         NaN
# 6           Sequential Policy Value Softer Surrogates         NaN
# 7   Large Language Models, Synthetic Data, Differe...         NaN
# 8                 uncertainty herding active learning         NaN
# 9             Object Detection, Open-World, Efficient         NaN
# 10  Visual representation text-based person searching         NaN
# 11           diffusion models medical image synthesis         NaN
# 12         Cognitive Load, Human Trust, Collaboration         NaN
# 13  I/O Device Obsolescence Environmental Economic...         NaN
# 14                      Class Imbalance, GNN Learning         NaN
# 15      Whole-Body Grasping Synthesis Diffusion Model         NaN
# 16         Nanosatellite, Propellant Sloshing, Design         NaN
# 17                 LoRaWAN Satellite Energy Efficient         NaN
# 18          Table recognition, Vision LLMs, Benchmark         NaN
# 19                                 Multi-Modal Remote         NaN
# 20                         Recurrence Vanishing Point         NaN
# 21                         Managed Lanes Tolling CAVs         NaN
# 22          Prototypical Distillation Debiased Tuning         NaN
# 23              Rumor Detection, Fairness, Unfairness         NaN
# 24                  Blockchain Cyber-Secure Federated         NaN
# 25                               ICNN, LSTM, Attitude         NaN
# 26                                                MHA         NaN
# 27  Attention-Driven Metapath Encoding Heterogeneo...         NaN
# 28          Convex Optimization, Neural Architectures         NaN
# 29  Connected Vehicles, Adaptive Control, Residual...         NaN
# 30  Pre-trained Vision-Language Models Ranking Dow...         NaN
# 31                       MarsSQE, Bi-level, Attention         NaN
# 32  electric vehicle battery recycling innovations...         NaN
# 33                      Autonomous Vehicle Technology         NaN
# 34                agent-based migration Conway's Game         NaN
# 35  Test adequacy metamorphic testing criteria mea...         NaN
# 36                  Evolution, Uncertainty, Heuristic         NaN
# 37  Motion Capture, Coordinated, Outdoor Environments         NaN
# 38    inverse scattering, random sources, time domain         NaN
# 39                  Collaborative Robots, Fire Rescue         NaN
# 40                                       dice rolling         NaN
# 41                               Open-set Known Class         NaN
# 42           Restricted Inverse Optimal Value Problem         NaN
# 43                 HFI, watermarking, diffusion model         NaN
# 44  Keywords: Speech Emotion, Residual Integration...         NaN
# 45          ResUnet Residual Connection Medical Image         NaN
# 46                              Selfish Machines Load         NaN
# 47   Inverse medium problems saddle point formulation         NaN
# 48  Spiking Neural Networks Intracortical Brain Si...         NaN
# 49                Vision-Language Model Summarization         NaN

# %%
data.to_csv('astro-ph.csv', index=False)
