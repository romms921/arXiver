# %%
import os
import shutil
import time
import subprocess
import corner
import glob
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import numba as nb
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy import constants as const
from astropy.cosmology import FlatLambdaCDM,Planck15
from astropy.convolution import convolve, convolve_fft, Moffat2DKernel, Gaussian2DKernel
import pandas as pd
from scipy import signal
import scipy.ndimage as ndimage
from scipy.signal import find_peaks
from matplotlib.ticker import FuncFormatter
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath} \usepackage{bm}'
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
cosmo = Planck15
h = cosmo.H0.value/100

import matplotlib.ticker as mticker
import matplotlib as mpl
log_formatter = FuncFormatter(lambda y, _: '{:.16g}'.format(y))
#from matplotlib.ticker import StrMethodFormatter, NullFormatter

from numpy import unravel_index


def ds9_log(input_img):
    return np.log(1000*input_img+1)/np.log(1000)

def img_norm(input_img,min_v,max_v):
    input_img = np.where(input_img>=max_v, max_v, input_img)
    input_img = np.where(input_img<=min_v, min_v, input_img)
    input_img = (input_img-min_v)/(max_v-min_v)
    return input_img


def arcsec2pc(arcsec,z):
    length = arcsec*u.arcsec*(1/cosmo.arcsec_per_kpc_proper(z))
    length = length.to(u.pc)
    return length

def pc2arcsec(length,z):
    angular_length = length*u.pc*cosmo.arcsec_per_kpc_proper(z)
    angular_length = angular_length.to(u.arcsec)
    return angular_length

def saveFITS(image,Header,SavePath,FileName):
    hdu0 = fits.PrimaryHDU(image)
    #hdu_new = fits.HDUList([hdu0])
    hdu0.writeto(SavePath+FileName+'.fits',image, overwrite=True)
    return

def saveFITS_simple(image,SavePath,FileName):
    hdu0 = fits.PrimaryHDU(image)
    hdu_new = fits.HDUList([hdu0])
    hdu_new.writeto(SavePath+FileName+'.fits', overwrite=True)
    return

def Eq_Ellipse(x,y,x0,y0,a,b,theta):
    X = (x-x0)*np.cos(theta) + (y-y0)*np.sin(theta)
    Y = -(x-x0)*np.sin(theta) + (y-y0)*np.cos(theta)
    d = X**2/a**2 + Y**2/b**2
    return d

def Eq_Circle(x,y,x0,y0):
    X = (x-x0)
    Y = (y-y0)
    R = (X**2 + Y**2)**0.5
    return R
# Out:
# /Users/alexchow/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/alexchow/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
def get_Pos_1stGuess_old(mock_lens_data):
    #mock_lens_data = fits.open(mock_lens_path)[0].data[4]
    #peaks = detect_peaks(mock_lens_data)
    peaks_filter = mock_lens_data > np.std(mock_lens_data)*5
    peaks = np.where(peaks_filter==True)
    plt.scatter(peaks[0],peaks[1])
    x_list,y_list = peaks[1],peaks[0]

    imgs_x , imgs_y = [],[]
    imgs_x_sub , imgs_y_sub = [],[]
    for i in range(len(peaks[0])):
        if i == len(peaks[0])-1:
            dist_list = ((x_list[i]-x_list)**2 + (y_list[i]-y_list)**2)**0.5
            dist_list_mask = np.where(dist_list<8)
            for j in dist_list_mask:
                imgs_x_sub.append(x_list[j])
                imgs_y_sub.append(y_list[j])
        else:
            dist_list = ((x_list[i]-x_list)**2 + (y_list[i]-y_list)**2)**0.5
            dist_list_mask = np.where(dist_list<8)
            dist_list_next = ((x_list[i+1]-x_list)**2 + (y_list[i+1]-y_list)**2)**0.5
            dist_list_next_mask = np.where(dist_list_next<8)
            if dist_list_mask[0].shape!=dist_list_next_mask[0].shape:
                for j in dist_list_mask:
                    imgs_x_sub.append(x_list[j])
                    imgs_y_sub.append(y_list[j])
            else:
                if (dist_list_next_mask[0]!=dist_list_mask[0]).all():
                    for j in dist_list_mask:
                        imgs_x_sub.append(x_list[j])
                        imgs_y_sub.append(y_list[j])
        if len(imgs_x_sub)!=0:
            imgs_x.append(np.median(imgs_x_sub))
            imgs_y.append(np.median(imgs_y_sub))
        imgs_x_sub , imgs_y_sub = [],[]

    imgs_x , imgs_y = np.asarray(imgs_x) , np.asarray(imgs_y)
    
    return imgs_x , imgs_y

def get_Pos_1stGuess(mock_lens_data):
    image = mock_lens_data

    # Apply Gaussian Filter to Denoise
    smoothed_image = image # No smoothing this time #ndimage.gaussian_filter(image, sigma=2)

    # Find Local Maxima
    threshold = np.std(image)*10  # 5 sig above noise
    local_max = (smoothed_image == ndimage.maximum_filter(smoothed_image, size=5)) & (smoothed_image > threshold)

    # Get Peak Coordinates
    peaks = np.argwhere(local_max)
    imgs_x , imgs_y = peaks[:, 1], peaks[:, 0]
    imgs_x , imgs_y = np.asarray(imgs_x) , np.asarray(imgs_y)
    imgs_x , imgs_y = imgs_x+1 , imgs_y+1
    return imgs_x , imgs_y

# %%
def create_mask_circle(x,y,image,Radius=5):
    X = np.linspace(0,image.shape[1]-1,image.shape[1])
    Y = np.linspace(0,image.shape[0]-1,image.shape[0])
    
    XX,YY = np.meshgrid(X-x,Y-y)
    RR = (XX**2 + YY**2)**0.5

    mask = np.zeros(image.shape)
    mask = np.int64(np.where(RR>Radius,1,mask))
    return mask

# %%
def write_imfit_config_str(img_x , img_y , image):
    string = ''
    string += 'X0' + '\t' + str(img_x) + '\n'
    string += 'Y0' + '\t' + str(img_y) + '\n'
    string += 'FUNCTION Gaussian' + '\n'
    string += 'PA' + '\t' + str(0) + '\t' + 'fixed' + '\n'
    string += 'ell' + '\t' + str(0) + '\t' + 'fixed' + '\n'
    string += 'I_0' + '\t' + str(image[int(img_y)][int(img_x)]) + '\n'
    string += 'sigma' + '\t' + str(0.8) + ' \n'
    return string

# %%
def save_imfit_config(config_str,output_FilePath):
    with open(output_FilePath, "w") as text_file:
        text_file.write(config_str)
    return 

def Combine_MCMC_Chain(file_name, mcmc_path):
    f = open(mcmc_path+file_name+'.'+str(int(0+1))+'.txt', "r")
    lines = []
    for line in f:
        line = line.strip()
        lines.append(line)

    for i in range(len(lines)):
        line = lines[i].strip()
        if not line.startswith('#'):
            header_id = i-1
            break
        
    header_str = lines[header_id]
    f.close()
    header = header_str.split()
    header.remove('#')

    IMFIT_mcmc_all = []
    for i in range(len(glob.glob(mcmc_path+file_name+'.*.txt'))):
        IMFIT_mcmc_all.append(pd.read_csv(mcmc_path+file_name+'.'+str(int(i+1))+'.txt',comment='#',header=None,sep=r'\s+'))

    IMFIT_mcmc = pd.concat(IMFIT_mcmc_all)
    del IMFIT_mcmc_all
    IMFIT_mcmc.to_csv(mcmc_path+file_name+'.txt',index=False,sep='\t',header=header)
    return

# %%
main_folder_path = '/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/'
sub_folder_path = '80/398065/398065_dm/z-1/'
#sub_folder_path = '80/398065/v2/398065/z-1/'
lens_file_name = 'withLight_Mock_i1_SNIa_z1_Cusp'
mock_lens_path = main_folder_path + sub_folder_path +lens_file_name+'.fits'

mock_lens_data = fits.open(mock_lens_path)[0].data[4]
imgs_x , imgs_y = get_Pos_1stGuess(mock_lens_data)
print(imgs_x , imgs_y)

# Create a folder to store the fitting results
folder4imfitfiles = main_folder_path+sub_folder_path+lens_file_name
if os.path.exists(folder4imfitfiles) == False:
    os.mkdir(folder4imfitfiles)
if os.path.exists(folder4imfitfiles+'/imfit_ImgPos') == False:
    os.mkdir(folder4imfitfiles+'/imfit_ImgPos')
    
folder4imfitfiles
# Out:
# [517 507 532 509] [508 516 523 527]
# '/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp'

# %%
# Save a copy of the mock img and it's noisemap
saveFITS_simple(mock_lens_data,folder4imfitfiles+'/imfit_ImgPos/','mock_obs')
saveFITS_simple(fits.open(mock_lens_path)[0].data[5],folder4imfitfiles+'/imfit_ImgPos/','mock_obs_noisemap')

# Path to imfit program
imfit_PATH = '/Users/alexchow/Desktop/Lensing/imfit/'

# Run imfit 
for i in range(len(imgs_x)):
    # Create and save the masking map
    mask = create_mask_circle(imgs_x[i],imgs_y[i],mock_lens_data,Radius=5)
    saveFITS_simple(np.int8(mask),folder4imfitfiles+'/imfit_ImgPos/','mask_img_'+str(i+1))
    # Create and save the config file
    text = write_imfit_config_str(imgs_x[i] , imgs_y[i] , mock_lens_data)
    config_output_FilePath = folder4imfitfiles+'/imfit_ImgPos/'+'config_img_'+str(i+1)+'.txt'
    save_imfit_config(text,config_output_FilePath)
    # Print the command for running imfit
    imfit_cmd = (imfit_PATH+'./imfit ' +
                 folder4imfitfiles+'/imfit_ImgPos/mock_obs.fits' +
                 ' -mask ' + folder4imfitfiles+'/imfit_ImgPos/mask_img_'+str(i+1)+'.fits' + 
                ' -noise ' + folder4imfitfiles+'/imfit_ImgPos/mock_obs_noisemap.fits' + 
                ' -c ' + config_output_FilePath + 
                ' --save-params ' + folder4imfitfiles+'/imfit_ImgPos/'+'Pos_Img_'+str(i+1)+'_result.txt' + 
                ' --save-residual ' + folder4imfitfiles+'/imfit_ImgPos/'+'Pos_Img_'+str(i+1)+'_res.fits' )
    os.system(imfit_cmd)
# Out:
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_img_1.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_1.fits
# 	output residual (data - best-fit model) image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_1_res.fits
# 	output best-fit parameter file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_1_result.txt
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_1.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# 4 free parameters (77 degrees of freedom)
# Estimated memory use: 103634016 bytes (98.8 MB)
#
# Performing fit by minimizing chi^2 (data-based errors):
# Calling Levenberg-Marquardt solver ...
# 	mpfit iteration 1: fit statistic = 690.013115
# 	mpfit iteration 2: fit statistic = 72.227142
# 	mpfit iteration 3: fit statistic = 65.183094
# 	mpfit iteration 4: fit statistic = 65.173474
# 	mpfit iteration 5: fit statistic = 65.173464
# 	mpfit iteration 6: fit statistic = 65.173464
#
# *** mpfit status = 1 -- SUCCESS: Convergence in fit-statistic value.
#   CHI-SQUARE = 65.173464    (77 DOF)
#   INITIAL CHI^2 = 9926.002529
#         NPAR = 6
#        NFREE = 4
#      NPEGGED = 0
#      NITER = 7
#       NFEV = 31
#
# Reduced Chi^2 = 0.846409
# AIC = 73.699780, BIC = 82.751260
#
# X0		517.0539 # +/- 0.0087
# Y0		507.8099 # +/- 0.0088
# FUNCTION Gaussian
# PA		      0 # +/- 0
# ell		      0 # +/- 0
# I_0		30.5435 # +/- 0.41332
# sigma		0.824292 # +/- 0.0062427
#
# Saving best-fit parameters in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_1_result.txt"
# Saving residual (data - best-fit model) image in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_1_res.fits"
#
# (Elapsed time: 0.390450 sec for fit, 0.508136 sec total)
# Done!
#
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_img_2.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_2.fits
# 	output residual (data - best-fit model) image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_2_res.fits
# 	output best-fit parameter file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_2_result.txt
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_2.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# 4 free parameters (77 degrees of freedom)
# Estimated memory use: 103634016 bytes (98.8 MB)
#
# Performing fit by minimizing chi^2 (data-based errors):
# Calling Levenberg-Marquardt solver ...
# 	mpfit iteration 1: fit statistic = 4011.922052
# 	mpfit iteration 2: fit statistic = 465.489960
# 	mpfit iteration 3: fit statistic = 110.847277
# 	mpfit iteration 4: fit statistic = 97.169752
# 	mpfit iteration 5: fit statistic = 97.143734
# 	mpfit iteration 6: fit statistic = 97.143685
# 	mpfit iteration 7: fit statistic = 97.143685
#
# *** mpfit status = 1 -- SUCCESS: Convergence in fit-statistic value.
#   CHI-SQUARE = 97.143685    (77 DOF)
#   INITIAL CHI^2 = 8393.174673
#         NPAR = 6
#        NFREE = 4
#      NPEGGED = 0
#      NITER = 8
#       NFEV = 36
#
# Reduced Chi^2 = 1.261606
# AIC = 105.670001, BIC = 114.721482
#
# X0		507.3378 # +/- 0.0107
# Y0		515.4646 # +/- 0.0106
# FUNCTION Gaussian
# PA		      0 # +/- 0
# ell		      0 # +/- 0
# I_0		 23.653 # +/- 0.36513
# sigma		0.841645 # +/- 0.0074369
#
# Saving best-fit parameters in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_2_result.txt"
# Saving residual (data - best-fit model) image in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_2_res.fits"
#
# (Elapsed time: 0.472077 sec for fit, 0.574595 sec total)
# Done!
#
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_img_3.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_3.fits
# 	output residual (data - best-fit model) image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_3_res.fits
# 	output best-fit parameter file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_3_result.txt
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_3.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# 4 free parameters (77 degrees of freedom)
# Estimated memory use: 103634016 bytes (98.8 MB)
#
# Performing fit by minimizing chi^2 (data-based errors):
# Calling Levenberg-Marquardt solver ...
# 	mpfit iteration 1: fit statistic = 189.073362
# 	mpfit iteration 2: fit statistic = 92.819108
# 	mpfit iteration 3: fit statistic = 90.034450
# 	mpfit iteration 4: fit statistic = 90.016856
# 	mpfit iteration 5: fit statistic = 90.016843
# 	mpfit iteration 6: fit statistic = 90.016843
#
# *** mpfit status = 1 -- SUCCESS: Convergence in fit-statistic value.
#   CHI-SQUARE = 90.016843    (77 DOF)
#   INITIAL CHI^2 = 1433.981417
#         NPAR = 6
#        NFREE = 4
#      NPEGGED = 0
#      NITER = 7
#       NFEV = 31
#
# Reduced Chi^2 = 1.169050
# AIC = 98.543158, BIC = 107.594639
#
# X0		531.9532 # +/- 0.0269
# Y0		522.7796 # +/- 0.0270
# FUNCTION Gaussian
# PA		      0 # +/- 0
# ell		      0 # +/- 0
# I_0		7.78116 # +/- 0.30244
# sigma		0.798256 # +/- 0.019569
#
# Saving best-fit parameters in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_3_result.txt"
# Saving residual (data - best-fit model) image in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_3_res.fits"
#
# (Elapsed time: 0.377848 sec for fit, 0.542223 sec total)
# Done!
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_img_4.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_4.fits
# 	output residual (data - best-fit model) image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_4_res.fits
# 	output best-fit parameter file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_4_result.txt
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_4.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# 4 free parameters (77 degrees of freedom)
# Estimated memory use: 103634016 bytes (98.8 MB)
#
# Performing fit by minimizing chi^2 (data-based errors):
# Calling Levenberg-Marquardt solver ...
# 	mpfit iteration 1: fit statistic = 880.049051
# 	mpfit iteration 2: fit statistic = 135.054534
# 	mpfit iteration 3: fit statistic = 76.865068
# 	mpfit iteration 4: fit statistic = 76.257302
# 	mpfit iteration 5: fit statistic = 76.257219
# 	mpfit iteration 6: fit statistic = 76.257219
#
# *** mpfit status = 1 -- SUCCESS: Convergence in fit-statistic value.
#   CHI-SQUARE = 76.257219    (77 DOF)
#   INITIAL CHI^2 = 4816.439871
#         NPAR = 6
#        NFREE = 4
#      NPEGGED = 0
#      NITER = 7
#       NFEV = 31
#
# Reduced Chi^2 = 0.990353
# AIC = 84.783535, BIC = 93.835016
#
# X0		508.9239 # +/- 0.0148
# Y0		526.5940 # +/- 0.0149
# FUNCTION Gaussian
# PA		      0 # +/- 0
# ell		      0 # +/- 0
# I_0		15.5629 # +/- 0.32437
# sigma		0.851362 # +/- 0.010609
#
# Saving best-fit parameters in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_4_result.txt"
# Saving residual (data - best-fit model) image in file "/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/Pos_Img_4_res.fits"
#
# (Elapsed time: 0.373556 sec for fit, 0.582484 sec total)
# Done!

# %%
################################################################
####################    Perform MCMC    ########################
################################################################
#i = 1
for i in range(len(imgs_x)):
    imfit_Bestfit_Path = folder4imfitfiles+'/imfit_ImgPos/'+'Pos_Img_'+str(i+1)+'_result.txt'
    imfit_Bestfit = pd.read_csv(imfit_Bestfit_Path,comment='#',header=None,sep='\t')

    mcmc_config_text = ''
    for j in range(imfit_Bestfit.shape[0]):
        bestfit_para = imfit_Bestfit[2][j]
        para_name = imfit_Bestfit[0][j]
        if para_name in ['X0','Y0']:
            mcmc_config_text += para_name + '\t' + str(bestfit_para) + '\t' + str(bestfit_para-1/20) + ',' + str(bestfit_para+1/20) + '\n'
        elif para_name in ['FUNCTION Gaussian']:
            mcmc_config_text += para_name + '\n'
        elif para_name in ['PA','ell']:
            mcmc_config_text += para_name + '\t' + str(bestfit_para) + '\t' + 'fixed' + '\n'
        elif para_name in ['I_0']:
            mcmc_config_text += para_name + '\t' + str(bestfit_para) + '\t' + str(bestfit_para-1/2) + ',' + str(bestfit_para+1/2) + '\n'
        elif para_name in ['sigma']:
            mcmc_config_text += para_name + '\t' + str(bestfit_para) + '\t' + str(bestfit_para-1/20) + ',' + str(bestfit_para+1/20) + '\n'

    mcmc_config_output_FilePath = folder4imfitfiles+'/imfit_ImgPos/'+'config_mcmc_img_'+str(i+1)+'.txt'
    save_imfit_config(mcmc_config_text,mcmc_config_output_FilePath)

    imfit_mcmc_cmd = (imfit_PATH+'./imfit-mcmc ' +
                     folder4imfitfiles+'/imfit_ImgPos/mock_obs.fits' +
                     ' --mask ' + folder4imfitfiles+'/imfit_ImgPos/mask_img_'+str(i+1)+'.fits' + 
                    ' --noise ' + folder4imfitfiles+'/imfit_ImgPos/mock_obs_noisemap.fits' + 
                    ' -c ' + mcmc_config_output_FilePath + 
                    ' -o ' + folder4imfitfiles+'/imfit_ImgPos/'+'mcmc_result_img_'+str(i+1)+'_chain'+
                    ' --gaussian-offset 0.02 ')
    os.system(imfit_mcmc_cmd)
    
    print('###################################################')
    print('###################################################')
# Out:
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_mcmc_img_1.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_1.fits
# 	MCMC Gaussian-offset sigma = 0.020000
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_1.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# 4 free parameters (77 degrees of freedom)
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# Estimated memory use: 34544672 bytes (32.9 MB)
# Setting up MCMC-related arrays ...
# Fixed parameter detected (i = 2)
# Fixed parameter detected (i = 3)
# Setting nChains = 4 (nFreeParams)
#
# Start of MCMC processing...
# Beginning DREAM:
#               X0 = [   517.0,    517.1]
#               Y0 = [   507.8,    507.9]
#               PA = [     0.0,      0.0] -- FIXED
#       ###################################################
# ###################################################
#        ell = [     0.0,      0.0] -- FIXED
#              I_0 = [    30.0,     31.0]
#            sigma = [     0.8,      0.9]
# Collapse outliers: 1
# Latin hypercube sampling...
#   shuffling (6, 4)...done.
# Chain 0: likelihood = -69.54
# Chain 1: likelihood = -108.27
# Chain 2: likelihood = -60.43
# Chain 3: likelihood = -74.97
# [5000] exiting burn-in.
# [7420] Outlier chain detected [1] outside of burn-in. Moving to best chain [3] and re-entering burn-in.
# [12420] exiting burn-in.
# [17420] performing convergence diagnostics: GR (it 17420): [0]1.00517 [1]1.00535 [4]1.00751 [5]1.02716
# [22420] performing convergence diagnostics: GR (it 22420): [0]1.00166 [1]1.00050 [4]1.00726 [5]1.01704
# [27420] performing convergence diagnostics: GR (it 27420): [0]1.00164 [1]1.00118 [4]1.01179 [5]1.00466
# [32420] performing convergence diagnostics: GR (it 32420): [0]1.00049 [1]1.00098 [4]1.00604 [5]1.00330
# Convergence detected!
# 128409 likelihood function calls
#
# MCMC chains written to output files /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_1_chain.1.txt through /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_1_chain.4.txt
# (Elapsed time: 969.967063 sec)
#
# Done!
#
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_mcmc_img_2.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_2.fits
# 	MCMC Gaussian-offset sigma = 0.020000
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_2.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# 4 free parameters (77 degrees of freedom)
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# Estimated memory use: 34544672 bytes (32.9 MB)
# Setting up MCMC-related arrays ...
# Fixed parameter detected (i = 2)
# Fixed parameter detected (i = 3)
# Setting nChains = 4 (nFreeParams)
#
# Start of MCMC processing...
# Beginning DREAM:
#               X0 = [   507.3,    507.4]
#               Y0 = [   515.4,    515.5]
#               PA = [     0.0,      0.0] -- FIXED
#       ###################################################
# ###################################################
#        ell = [     0.0,      0.0] -- FIXED
#              I_0 = [    23.2,     24.2]
#            sigma = [     0.8,      0.9]
# Collapse outliers: 1
# Latin hypercube sampling...
#   shuffling (6, 4)...done.
# Chain 0: likelihood = -116.06
# Chain 1: likelihood = -71.68
# Chain 2: likelihood = -81.62
# Chain 3: likelihood = -54.13
# [5000] exiting burn-in.
# [6290] Outlier chain detected [3] outside of burn-in. Moving to best chain [0] and re-entering burn-in.
# [11290] exiting burn-in.
# [16290] performing convergence diagnostics: GR (it 16290): [0]1.00225 [1]1.01284 [4]1.00802 [5]1.01320
# [21290] performing convergence diagnostics: GR (it 21290): [0]1.00074 [1]1.00149 [4]1.01500 [5]1.00501
# [26290] performing convergence diagnostics: GR (it 26290): [0]1.00080 [1]1.00565 [4]1.00129 [5]1.00255
# Convergence detected!
# 110248 likelihood function calls
#
# MCMC chains written to output files /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_2_chain.1.txt through /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_2_chain.4.txt
# (Elapsed time: 880.015361 sec)
#
# Done!
#
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_mcmc_img_3.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_3.fits
# 	MCMC Gaussian-offset sigma = 0.020000
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_3.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# 4 free parameters (77 degrees of freedom)
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# Estimated memory use: 34544672 bytes (32.9 MB)
# Setting up MCMC-related arrays ...
# Fixed parameter detected (i = 2)
# Fixed parameter detected (i = 3)
# Setting nChains = 4 (nFreeParams)
#
# Start of MCMC processing...
# Beginning DREAM:
#               X0 = [   531.9,    532.0]
#               Y0 = [   522.7,    522.8]
#               PA = [     0.0,      0.0] -- FIXED
#              ell = [     0.0,      0.0] -- FIXED
#              I_0 = [     7.3,      8.3]
#            sigma = [     0.7,      0.8]
# Collapse outliers: 1
# Latin hypercube sampling...
#   shuffling (6, 4)...done.
# Chain 0: likelihood = -51.46
# Chain 1: likelihood = -47.42
# Chain 2: likelihood = -54.91
# Chain 3: likelihood = -58.66
# [5000] exiting burn-in.
# [5860] Outlier chain detected [3] outside of burn-in. Moving to best chain [0] and re-entering burn-in.
# [10860] exiting burn-in.
# [15860] performing convergence diagnostics: GR (it 15860): [0]1.00084 [1]1.00169 [4]1.00130 [5]1.00113
# Convergence detected!
# 68766 likelihood function calls
#
# MCMC chains written to output files /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_3_chain.1.txt through /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_3_chain.4.txt
# (Elapsed time: 597.890042 sec)
#
# Done!
#
# ###################################################
# ###################################################
# 	Image file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits
# 	configuration file = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/config_mcmc_img_4.txt
# 	noise image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits
# 	mask image = /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_4.fits
# 	MCMC Gaussian-offset sigma = 0.020000
# Reading data image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs.fits") ...
# naxis1 [# pixels/row] = 1039, naxis2 [# pixels/col] = 1039; nPixels_tot = 1079521
# Reading mask image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mask_img_4.fits") ...
# Reading noise image ("/Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mock_obs_noisemap.fits") ...
# * No PSF image supplied -- no image convolution will be done!
# ModelObject::AddMaskVector -- treating zero-valued pixels as good ...
# Function: Gaussian
# 6 total parameters
# 4 free parameters (77 degrees of freedom)
# Model Object: 1079521 data values (pixels)
# ModelObject: mask vector applied to weight vector. (81 valid pixels remain)
# Estimated memory use: 34544672 bytes (32.9 MB)
# Setting up MCMC-related arrays ...
# Fixed parameter detected (i = 2)
# Fixed parameter detected (i = 3)
# Setting nChains = 4 (nFreeParams)
#
# Start of MCMC processing...
# Beginning DREAM:
#               X0 = [   508.9,    509.0]
#               Y0 = [   526.5,    526.6]
#               PA = [     0.0,      0.0] -- FIXED
#              ell = [     0.0,      0.0] -- FIXED
#              I_0 = [    15.1,     16.1]
#            sigma = [     0.8,      0.9]
# Collapse outliers: 1
# Latin hypercube sampling...
#   shuffling (6, 4)...done.
# Chain 0: likelihood = -71.97
# Chain 1: likelihood = -41.94
# Chain 2: likelihood = -62.27
# Chain 3: likelihood = -44.15
# [5000] exiting burn-in.
# [10000] performing convergence diagnostics: GR (it 10000): [0]1.00026 [1]1.00074 [4]1.00616 [5]1.01467
# [11530] Outlier chain detected [0] outside of burn-in. Moving to best chain [2] and re-entering burn-in.
# [16530] exiting burn-in.
# [21530] performing convergence diagnostics: GR (it 21530): [0]1.00763 [1]1.00161 [4]1.01136 [5]1.01070
# [26530] performing convergence diagnostics: GR (it 26530): [0]1.00227 [1]1.00188 [4]1.00092 [5]1.00327
# Convergence detected!
# 105029 likelihood function calls
#
# MCMC chains written to output files /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_4_chain.1.txt through /Volumes/KINGSTON/Astro_Research/illutrisTNG_Lensing/snapshot/80/398065/398065_dm/z-1/withLight_Mock_i1_SNIa_z1_Cusp/imfit_ImgPos/mcmc_result_img_4_chain.4.txt
# (Elapsed time: 829.140455 sec)
#
# Done!
#
# ###################################################
# ###################################################

# %%
for i in range(len(imgs_x)):
    imfit_Bestfit_Path = folder4imfitfiles+'/imfit_ImgPos/'+'Pos_Img_'+str(i+1)+'_result.txt'
    imfit_Bestfit = pd.read_csv(imfit_Bestfit_Path,comment='#',header=None,sep='\t')
    bestfit_X0 = imfit_Bestfit[2][0]
    bestfit_Y0 = imfit_Bestfit[2][1]
    
    file_name = 'mcmc_result_img_'+str(i+1)+'_chain' # imfit output chain's file name
    mcmc_path = folder4imfitfiles+'/imfit_ImgPos/' # path to the folder containing the mcmc chain files
    Combine_MCMC_Chain(file_name,mcmc_path)
    data = pd.read_csv(mcmc_path+file_name+'.txt',sep='\s+')
    accpetance_rate = (data[data['accept']==1]).shape[0]/data.shape[0] * 100
    print('accpetance rate = '+ str(np.round(accpetance_rate,2)) + '%')
    data = data[data['accept']==1]
    data = data.drop(columns=['likelihood','burn-in','CR1','CR2','CR3','accept',
                             'PA_1','ell_1'])
    data['X0_1'] = (data['X0_1']-bestfit_X0)*0.04*1000
    data['Y0_1'] = (data['Y0_1']-bestfit_Y0)*0.04*1000
    data.to_numpy()
    # Plot it.
    figure = corner.corner(
        data,
        quantiles=[0.16, 0.5, 0.84],
        labels=list(data),
        show_titles=True,
        #title_kwargs={"fontsize": 16},
    )
# Out:
# accpetance rate = 20.01%
# accpetance rate = 20.85%
# accpetance rate = 28.59%
# accpetance rate = 24.36%
